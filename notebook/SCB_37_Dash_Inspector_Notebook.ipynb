# %% [markdown]
# * SCB_37_Dash_Inspector_Notebook - verkar inte vara problem
#
# * Issue [37](https://github.com/salgo60/SCB-Wikidata/issues/37)
# * denna Notebook [SCB_37_Dash_Inspector_Notebook.ipynb](https://github.com/salgo60/SCB-Wikidata/blob/main/notebook/SCB_37_Dash_Inspector_Notebook.ipynb)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-11-20 13:43:04

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SCB-Wikidata/notebook

# %%
# Notebook: Dash Inspector for Myndighetsregistret
# Läs in ALLA exporterade filer i underkatalogen "myndighetsreg/"
# Undersök vilka typer av bindestreck som förekommer i organisationsnummer
# Gruppera poster efter vilket Unicode-dash-tecken som används

import pandas as pd
import os
import re
from collections import defaultdict

# --- 1. Hitta alla filer i katalogen ---
DIR = 'myndighetsreg_export/20260112'
files = [os.path.join(DIR, f) for f in os.listdir(DIR) if f.lower().endswith('.txt')]
#today = date.today().strftime("%Y_%m_%d")

print("Hittade filer:")
for f in files:
    print(f)
# --- 2. Funktion: identifiera vilken typ av dash som används ---
DASH_MAP = {
    '-': 'ASCII hyphen (U+002D)',
    '\u2013': 'EN DASH (U+2013)',
    '\u2014': 'EM DASH (U+2014)',
    '\u2212': 'MINUS SIGN (U+2212)',
    '\u2010': 'HYPHEN (U+2010)',
    '\u2011': 'NON-BREAKING HYPHEN (U+2011)',
    '\ufe58': 'SMALL EM DASH (U+FE58)',
    '\u2043': 'HYPHEN BULLET (U+2043)'
}

ALL_DASHES = set(DASH_MAP.keys())


def find_dash_type(orgnr):
    """Returnerar en lista med vilka dash-tecken som förekommer i strängen."""
    if pd.isna(orgnr):
        return []

    s = str(orgnr)
    found = []
    for ch in s:
        if ch in ALL_DASHES:
            found.append(ch)
    return found

# --- 3. Läs in alla filer och samla dash-typer ---
groups = defaultdict(list)  # key = dash type, value = list of rows

for path in files:
    try:
        df = pd.read_csv(path, sep='\t', dtype=str, encoding='utf-8')
    except Exception as e:
        print('Fel vid läsning av', path, e)
        continue

    col = None
    for c in df.columns:
        if 'org' in c.lower():  # heuristik
            col = c
            break

    if not col:
        print('Ingen organisationsnummerkolumn hittad i', path)
        continue

    for i, row in df.iterrows():
        org = row[col]
        dash_types = find_dash_type(org)
        if not dash_types:
            groups['INGET DASH'].append((path, org))
        else:
            for d in dash_types:
                groups[DASH_MAP.get(d, f'UNKNOWN ({d})')].append((path, org))

# --- 4. Sammanställning ---
print("\n=== Sammanfattning av dash-typer ===")
for dash, rows in groups.items():
    print(f"{dash}: {len(rows)} poster")
# Out:
# Hittade filer:
# myndighetsreg_export/20260112/Statliga förvaltningsmyndigheter.txt
# myndighetsreg_export/20260112/Svenska utlandsmyndigheter.txt
# myndighetsreg_export/20260112/AP-fonder.txt
# myndighetsreg_export/20260112/Statliga affärsverk.txt
# myndighetsreg_export/20260112/Sveriges domstolar samt Domstolsverket.txt
# myndighetsreg_export/20260112/Myndigheter under riksdagen.txt
# Ingen organisationsnummerkolumn hittad i myndighetsreg_export/20260112/Svenska utlandsmyndigheter.txt
#
# === Sammanfattning av dash-typer ===
# ASCII hyphen (U+002D): 341 poster

# %% [markdown]
# ### Skapa en fil för hela databasen

# %%
import os
import pandas as pd

DIR = "Myndighetsreg_export/20260112"

# Hitta alla txt-filer
files = [os.path.join(DIR, f) for f in os.listdir(DIR) if f.lower().endswith('.txt')]

dfs = []

for file in files:
    # Justera sep beroende på filtyp: '\t', ';', ',' osv.
    df = pd.read_csv(file, sep="\t", encoding="utf-8")  
    dfs.append(df)

# Slå ihop till en enda DataFrame
merged = pd.concat(dfs, ignore_index=True)

# Spara som en CSV
merged.to_csv("Myndighetsreg_concat/Myndighetsreg_alla_20260112.csv", index=False, encoding="utf-8")

print("Klart! skapade sammanstallt 20260112.csv")
# Out:
# Klart! skapade sammanstallt 20260112.csv

# %%
import pandas as pd
import requests
from tqdm.notebook import tqdm

tqdm.pandas()   # aktiverar progress_apply()

def check_url(url):
    """Returnera HTTP-statuskod (eller None) och OK/Fail."""
    try:
        checkurl = "http://" + url.lstrip("/")
        r = requests.head(checkurl, allow_redirects=True, timeout=5)
        return r.status_code, (r.status_code < 400)
    except Exception:
        return None, False

# Progressbar visas automatiskt
merged["HTTP_Status"], merged["URL_OK"] = zip(*merged["Webbadress"].progress_apply(check_url))

# Filtrera trasiga länkar
broken = merged[~merged["URL_OK"]]

print("Antal trasiga länkar:", len(broken))

# Lista trasiga url:er
print("\n📌 Felaktiga URL:er:")
for r in broken.itertuples(index=False):
    print(r.HTTP_Status, r.Webbadress)

# Spara rapport
broken.to_csv("trasiga_webbadresser_20260112.csv", index=False)

display(broken)
# Out:
#   0%|          | 0/449 [00:00<?, ?it/s]
# Antal trasiga länkar: 52
#
# 📌 Felaktiga URL:er:
# nan www.bolagsverket.se
# nan www.csn.se
# nan nan
# nan www.domstol.se/domarnamnden
# 403.0 www.fmv.se
# 405.0 www.fra.se
# 403.0 www.forsvarsmakten.se
# nan nan
# 404.0 www.hb.se
# 404.0 www.imy.se
# nan www.kommerskollegium.se
# 403.0 www.konkurrensverket.se
# nan http://www.regeringen.se/myndigheter-med-flera/krigsforsakringsnamnden/
# 405.0 www.kriminalvarden.se
# 500.0 www.osthammar.se/sv/organisation/namnd/lokala-sakerhetsnamnden/
# 404.0 www.oskarshamn.se/mer-om-kommunen/karnenergi-och-karnavfall/lokala-sakerhetsnamnden-vid-oskarshamns-karnkraftverk-och-karnenergiberedskap/
# 403.0 www.mtfa.se
# nan www.domstol.se/Om-Sveriges-Domstolar/Notarienamnden
# nan https://npof.se
# nan www.bolagsverket.se/om/oss/fler/patentombud
# 403.0 www.pts.se
# 403.0 www.raa.se
# nan www.riksarkivet.se
# nan nan
# nan www.rymdstyrelsen.se
# nan www.domstol.se/rattshjalpsnamnden
# 403.0 www.sida.se
# 404.0 www.kammarkollegiet.se/kammarkollegiet/vi-arbetar-ocksa-med/naemndmyndigheter/skiljenaemnden-i-vissa-trygghetsfragor
# 500.0 www.lotteriinspektionen.se
# nan http://www.kammarkollegiet.se/n-mndmyndigheter/skaderegleringsn-mnden
# 404.0 www.kammarkollegiet.se/namndmyndigheter/statens-overklagandenamnd/om-namnden
# nan www.sgu.se
# nan nan
# nan www.vinnova.se
# nan www.kammarrattenisundsvall.se
# nan www.oks.se
# nan nan
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/afghanistan-kabul
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/angola-luanda
# nan www.swedenabroad.com (www.suecia.org.br)
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/burkina-faso-ouagadougou/
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/oecd-unesco/om-delegationen/delegationens-personal
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/oecd-unesco/om-delegationen/delegationens-personal
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/mali-bamako
# 404.0 www.swedenabroad.se/sv/utlandsmyndigheter/peru-lima
# nan www.apfond6.se
# nan www.lfv.se
# nan nan
# nan www.gotahovratt.se
# nan www.hogstadomstolen.se
# nan www.hogstaforvaltningsdomstolen.se
# nan www.kammarrattenisundsvall.se
#     Organisationsnr                                               Namn  \
# 10      202100-5489                                       BOLAGSVERKET
# 15      202100-1819                        CENTRALA STUDIESTÖDSNÄMNDEN
# 16      202100-6842  Delegationen för folkrättslig granskning av va...
# 18      202100-6081                                       Domarnämnden
# 37      202100-0340                            FÖRSVARETS MATERIELVERK
# 38      202100-0365                            FÖRSVARETS RADIOANSTALT
# 40      202100-4615                                     FÖRSVARSMAKTEN
# 43      202100-6859        Granskningsnämnden för försvarsuppfinningar
# 50      202100-3138                                  HÖGSKOLAN I BORÅS
# 66      202100-0050                       Integritetsskyddsmyndigheten
# 74      202100-2007                                   KOMMERSKOLLEGIUM
# 76      202100-4342                                   KONKURRENSVERKET
# 80      202100-5810                            Krigsförsäkringsnämnden
# 81      202100-0225                                     KRIMINALVÅRDEN
# 94      202100-6735               Lokala säkerhetsnämnden vid Forsmark
# 95      202100-6743             Lokala säkerhetsnämnden vid Oskarshamn
# 135     202100-7055                MYNDIGHETEN FÖR TOTALFÖRSVARSANALYS
# 144     202100-6032                                     Notarienämnden
# 146     202100-6933     Nämnden för prövning av oredlighet i forskning
# 151     202100-6370                                PATENTOMBUDSNÄMNDEN
# 155     202100-4359                            POST- OCH TELESTYRELSEN
# 158     202100-1090                              RIKSANTIKVARIEÄMBETET
# 159     202100-1074                                        RIKSARKIVET
# 161     202100-6784                              Riksvärderingsnämnden
# 162     202100-2585                                      RYMDSTYRELSEN
# 163     202100-6008                                  Rättshjälpnämnden
# 168     202100-4789                                               Sida
# 171     202100-5869              Skiljenämnden i vissa trygghetsfrågor
# 177     202100-3310                                   SPELINSPEKTIONEN
# 194     202100-5828                       Statens skaderegleringsnämnd
# 201     202100-4763                          Statens överklagandenämnd
# 214     202100-2528                   SVERIGES GEOLOGISKA UNDERSÖKNING
# 234     202100-6826              Utrikesförvaltningens antagningsnämnd
# 236     202100-5216                       VERKET FÖR INNOVATIONSSYSTEM
# 242     202100-6024         Överklagandenämnden för nämndemannauppdrag
# 243     202100-5273                 ÖVERKLAGANDENÄMNDEN FÖR STUDIESTÖD
# 244             NaN                                                NaN
# 245             NaN                            Sveriges ambassad Kabul
# 248             NaN                           Sveriges ambassad Luanda
# 259             NaN                         Sveriges ambassad Brasilia
# 260             NaN                      Sveriges ambassad Ouagadougou
# 273             NaN                    Sveriges delegation Paris, OECD
# 275             NaN                   Sveriges delegation UNESCO Paris
# 306             NaN                           Sveriges ambassad Bamako
# 316             NaN                             Sveriges ambassad Lima
# 356     855104-0721                                   SJÄTTE AP-FONDEN
# 358     202100-0795                                    LUFTFARTSVERKET
# 384     202100-2742                                GÄLLIVARE TINGSRÄTT
# 386     202100-2742                                       GÖTA HOVRÄTT
# 405     202100-2742                                   HÖGSTA DOMSTOLEN
# 406     202100-2742                       HÖGSTA FÖRVALTNINGSDOMSTOLEN
# 412     202100-2742                           KAMMARRÄTTEN I SUNDSVALL
#
#           PostAdress  PostNr     PostOrt             BesöksAdress  \
# 10               NaN  851 81   SUNDSVALL           STUVARVÄGEN 21
# 15               NaN  851 82   SUNDSVALL       NORRA TJÄRNGATAN 2
# 16               NaN  103 33   STOCKHOLM                      NaN
# 18          BOX 2330  103 18   STOCKHOLM      BIRGER JARLS TORG 5
# 37               NaN  115 88   STOCKHOLM            BANÉRGATAN 62
# 38           BOX 301  161 26      BROMMA            RÖRBYVÄGEN 20
# 40               NaN  107 85   STOCKHOLM          Lidingövägen 24
# 43               NaN  103 33   STOCKHOLM                      NaN
# 50               NaN  501 90       BORÅS              ALLÉGATAN 1
# 66          BOX 8114  104 20   STOCKHOLM          Fleminggatan 14
# 74          BOX 6803  113 86   STOCKHOLM         FLEMMINGGATAN 14
# 76     RINGVÄGEN 100  118 60   STOCKHOLM            RINGVÄGEN 100
# 80          Box 7821  103 97   STOCKHOLM                      NaN
# 81               NaN  601 80  NORRKÖPING           SLOTTSGATAN 78
# 94            BOX 66  742 21   ÖSTHAMMAR                      NaN
# 95           BOX 706  572 28  OSKARSHAMN                      NaN
# 135        BOX 24250  104 51   STOCKHOLM     Karlavägen 104  9 tr
# 144         Box 2203  550 02   JÖNKÖPING                      NaN
# 146         BOX 2110  750 02     UPPSALA  Dag Hammarskjölds väg 7
# 151           BOX 46  851 02   SUNDSVALL                      NaN
# 155         BOX 6101  102 32   STOCKHOLM         HÄLSINGEGATAN 38
# 158         BOX 1114  621 22       VISBY             STORGATAN 41
# 159         BOX 7223  187 13        TÄBY       Fyrverkarbacken 13
# 161              NaN  103 33   STOCKHOLM                      NaN
# 162         BOX 4006  171 04       SOLNA          Hemvärnsgatan 9
# 163          Box 170  851 03   SUNDSVALL       Södra Tjärngatan 2
# 168         BOX 2025  174 02  SUNDBYBERG          Rissneleden 110
# 171         Box 2218  103 15   STOCKHOLM                      NaN
# 177          BOX 199  645 23   STRÄNGNÄS       FINNINGEVÄGEN 54 B
# 194         Box 2218  103 15   STOCKHOLM                      NaN
# 201         BOX 2218  103 15   STOCKHOLM                      NaN
# 214          BOX 670  751 28     UPPSALA     Dragarbrunnsgatan 77
# 234              NaN  103 33   STOCKHOLM                      NaN
# 236              NaN  101 58   STOCKHOLM   MÄSTER SAMUELSGATAN 56
# 242          Box 714  851 21   SUNDSVALL       Södra Tjärngatan 2
# 243          BOX 110  871 23   HÄRNÖSAND              BACKGRÄND 9
# 244              NaN     NaN         NaN                      NaN
# 245              NaN     NaN         NaN                      NaN
# 248              NaN     NaN         NaN                      NaN
# 259              NaN     NaN         NaN                      NaN
# 260              NaN     NaN         NaN                      NaN
# 273              NaN     NaN         NaN                      NaN
# 275              NaN     NaN         NaN                      NaN
# 306              NaN     NaN         NaN                      NaN
# 316              NaN     NaN         NaN                      NaN
# 356  KÖPMANSGATAN 32  411 06    GÖTEBORG          KÖPMANSGATAN 32
# 358              NaN  601 79  NORRKÖPING        HOSPITALSGATAN 30
# 384           BOX 23  982 21   GÄLLIVARE        LASARETTSGATAN 22
# 386         BOX 2223  550 02   JÖNKÖPING             HAMNGATAN 11
# 405         BOX 2066  103 12   STOCKHOLM        RIDDARHUSTORGET 8
# 406         BOX 2293  103 17   STOCKHOLM     BIRGER JARLS TORG 13
# 412          BOX 714  851 21   SUNDSVALL       Södra Tjärngatan 2
#
#     BesöksPostNr  BesöksPostOrt                  Tfn                  Fax  \
# 10        852 29      SUNDSVALL          771670670.0                  NaN
# 15        852 33      SUNDSVALL           60186000.0                  NaN
# 16        000 00      STOCKHOLM                  NaN                  NaN
# 18        111 28      STOCKHOLM          856166950.0                  NaN
# 37        115 53      STOCKHOLM           87824000.0                  NaN
# 38        178 93  DROTTNINGHOLM          105574600.0                  NaN
# 40        115 57      STOCKHOLM           87887500.0                  NaN
# 43        000 00      STOCKHOLM                  NaN                  NaN
# 50        503 32          BORÅS          334354000.0                  NaN
# 66        112 26      STOCKHOLM           86576100.0                  NaN
# 74        112 26      STOCKHOLM           86904800.0                  NaN
# 76        118 60      STOCKHOLM           87001600.0                  NaN
# 80        000 00      STOCKHOLM           87878000.0                  NaN
# 81        602 22     NORRKÖPING          772280800.0                  NaN
# 94        000 00      ÖSTHAMMAR                  NaN                  NaN
# 95        000 00     OSKARSHAMN                  NaN                  NaN
# 135       115 23      STOCKHOLM          101605100.0                  NaN
# 144       000 00      JÖNKÖPING           36156800.0                  NaN
# 146       752 37        UPPSALA          104573320.0                  NaN
# 151          NaN            NaN          771670670.0                  NaN
# 155       113 43      STOCKHOLM                  NaN                  NaN
# 158       114 55      STOCKHOLM          851918000.0                  NaN
# 159       112 60      STOCKHOLM          104767000.0                  NaN
# 161       000 00      STOCKHOLM                  NaN                  NaN
# 162       171 54          SOLNA          840907700.0                  NaN
# 163       852 33      SUNDSVALL           60186891.0                  NaN
# 168       174 57     SUNDBYBERG           86985000.0                  NaN
# 171       000 00      STOCKHOLM           87000800.0                  NaN
# 177       645 42      STRÄNGNÄS          152650100.0                  NaN
# 194       000 00      STOCKHOLM           87000800.0                  NaN
# 201          NaN            NaN           87000800.0                  NaN
# 214       753 19        UPPSALA           18179000.0                  NaN
# 234       000 00      STOCKHOLM                  NaN                  NaN
# 236       101 58      STOCKHOLM           84733000.0                  NaN
# 242       852 33      SUNDSVALL           60186600.0                  NaN
# 243       871 32      HÄRNÖSAND          611347500.0                  NaN
# 244          NaN            NaN                  NaN                  NaN
# 245          NaN            NaN     +93 20 210 49 12                  NaN
# 248          NaN            NaN      +244 222 447522                  NaN
# 259          NaN            NaN  +55 (61) 3442 52 00  +55 (61) 3443 11 87
# 260          NaN            NaN     +226 50 49 61 70                  NaN
# 273          NaN            NaN    +33 1 44 18 88 00    +33 1 44 18 88 10
# 275          NaN            NaN    +33 1 45 68 34 50                  NaN
# 306          NaN            NaN     +223 20 70 70 00     +223 20 70 70 10
# 316          NaN            NaN         +511 5669240         +511 2210298
# 356       411 06       GÖTEBORG          317411000.0                  NaN
# 358       602 27     NORRKÖPING             11192000                  NaN
# 384       982 32      GÄLLIVARE           97075800.0                  NaN
# 386       553 16      JÖNKÖPING           36156900.0                  NaN
# 405       111 28      STOCKHOLM          856166600.0                  NaN
# 406       111 28      STOCKHOLM          856167600.0                  NaN
# 412       852 33      SUNDSVALL           60186600.0                  NaN
#
#      ...                               BesöksAdress1  \
# 10   ...                                         NaN
# 15   ...                                         NaN
# 16   ...                                         NaN
# 18   ...                                         NaN
# 37   ...                                         NaN
# 38   ...                                         NaN
# 40   ...                                         NaN
# 43   ...                                         NaN
# 50   ...                                         NaN
# 66   ...                                         NaN
# 74   ...                                         NaN
# 76   ...                                         NaN
# 80   ...                                         NaN
# 81   ...                                         NaN
# 94   ...                                         NaN
# 95   ...                                         NaN
# 135  ...                                         NaN
# 144  ...                                         NaN
# 146  ...                                         NaN
# 151  ...                                         NaN
# 155  ...                                         NaN
# 158  ...                                         NaN
# 159  ...                                         NaN
# 161  ...                                         NaN
# 162  ...                                         NaN
# 163  ...                                         NaN
# 168  ...                                         NaN
# 171  ...                                         NaN
# 177  ...                                         NaN
# 194  ...                                         NaN
# 201  ...                                         NaN
# 214  ...                                         NaN
# 234  ...                                         NaN
# 236  ...                                         NaN
# 242  ...                                         NaN
# 243  ...                                         NaN
# 244  ...                                         NaN
# 245  ...                           Sveriges Ambassad
# 248  ...                        Rua Garcia Neto nº 9
# 259  ...                Sveriges Ambassad i Brasilia
# 260  ...                           Sveriges ambassad
# 273  ...  La délégation de la Suède auprès de l'OCDE
# 275  ...                                         NaN
# 306  ...                          Ambassade de Suède
# 316  ...                    Calle La Santa María 120
# 356  ...                                         NaN
# 358  ...                                         NaN
# 384  ...                                         NaN
# 386  ...                                         NaN
# 405  ...                                         NaN
# 406  ...                                         NaN
# 412  ...                                         NaN
#
#                     BesöksAdress2       BesöksAdress3  \
# 10                            NaN                 NaN
# 15                            NaN                 NaN
# 16                            NaN                 NaN
# 18                            NaN                 NaN
# 37                            NaN                 NaN
# 38                            NaN                 NaN
# 40                            NaN                 NaN
# 43                            NaN                 NaN
# 50                            NaN                 NaN
# 66                            NaN                 NaN
# 74                            NaN                 NaN
# 76                            NaN                 NaN
# 80                            NaN                 NaN
# 81                            NaN                 NaN
# 94                            NaN                 NaN
# 95                            NaN                 NaN
# 135                           NaN                 NaN
# 144                           NaN                 NaN
# 146                           NaN                 NaN
# 151                           NaN                 NaN
# 155                           NaN                 NaN
# 158                           NaN                 NaN
# 159                           NaN                 NaN
# 161                           NaN                 NaN
# 162                           NaN                 NaN
# 163                           NaN                 NaN
# 168                           NaN                 NaN
# 171                           NaN                 NaN
# 177                           NaN                 NaN
# 194                           NaN                 NaN
# 201                           NaN                 NaN
# 214                           NaN                 NaN
# 234                           NaN                 NaN
# 236                           NaN                 NaN
# 242                           NaN                 NaN
# 243                           NaN                 NaN
# 244                           NaN                 NaN
# 245  MoI-Street, opposite the MoI          Shar-e Naw
# 248                       Miramar              Luanda
# 259           Avenida das Nações,     Qd.807, lote 29
# 260       Avenue de l'Europe, 187        Burkina Faso
# 273         17 rue Barbet-de-Jouy         75007 Paris
# 275                           NaN                 NaN
# 306     Immeuble UATT, 2eme etage  Quartier du Fleuve
# 316                    San Isidro                Lima
# 356                           NaN                 NaN
# 358                           NaN                 NaN
# 384                           NaN                 NaN
# 386                           NaN                 NaN
# 405                           NaN                 NaN
# 406                           NaN                 NaN
# 412                           NaN                 NaN
#
#                BesöksAdress4 BesöksAdress5 BesöksAdress6 BesöksAdress7 Sort  \
# 10                       NaN           NaN           NaN           NaN  NaN
# 15                       NaN           NaN           NaN           NaN  NaN
# 16                       NaN           NaN           NaN           NaN  NaN
# 18                       NaN           NaN           NaN           NaN  NaN
# 37                       NaN           NaN           NaN           NaN  NaN
# 38                       NaN           NaN           NaN           NaN  NaN
# 40                       NaN           NaN           NaN           NaN  NaN
# 43                       NaN           NaN           NaN           NaN  NaN
# 50                       NaN           NaN           NaN           NaN  NaN
# 66                       NaN           NaN           NaN           NaN  NaN
# 74                       NaN           NaN           NaN           NaN  NaN
# 76                       NaN           NaN           NaN           NaN  NaN
# 80                       NaN           NaN           NaN           NaN  NaN
# 81                       NaN           NaN           NaN           NaN  NaN
# 94                       NaN           NaN           NaN           NaN  NaN
# 95                       NaN           NaN           NaN           NaN  NaN
# 135                      NaN           NaN           NaN           NaN  NaN
# 144                      NaN           NaN           NaN           NaN  NaN
# 146                      NaN           NaN           NaN           NaN  NaN
# 151                      NaN           NaN           NaN           NaN  NaN
# 155                      NaN           NaN           NaN           NaN  NaN
# 158                      NaN           NaN           NaN           NaN  NaN
# 159                      NaN           NaN           NaN           NaN  NaN
# 161                      NaN           NaN           NaN           NaN  NaN
# 162                      NaN           NaN           NaN           NaN  NaN
# 163                      NaN           NaN           NaN           NaN  NaN
# 168                      NaN           NaN           NaN           NaN  NaN
# 171                      NaN           NaN           NaN           NaN  NaN
# 177                      NaN           NaN           NaN           NaN  NaN
# 194                      NaN           NaN           NaN           NaN  NaN
# 201                      NaN           NaN           NaN           NaN  NaN
# 214                      NaN           NaN           NaN           NaN  NaN
# 234                      NaN           NaN           NaN           NaN  NaN
# 236                      NaN           NaN           NaN           NaN  NaN
# 242                      NaN           NaN           NaN           NaN  NaN
# 243                      NaN           NaN           NaN           NaN  NaN
# 244                      NaN           NaN           NaN           NaN  NaN
# 245       Kabul, Afghanistan           NaN           NaN           NaN  NaN
# 248                      NaN           NaN           NaN           NaN  NaN
# 259  70419-900 Brasilia - DF           NaN           NaN           NaN  NaN
# 260                      NaN           NaN           NaN           NaN  NaN
# 273                      NaN           NaN           NaN           NaN  NaN
# 275                      NaN           NaN           NaN           NaN  NaN
# 306             Bamako, Mali           NaN           NaN           NaN  NaN
# 316                     Peru           NaN           NaN           NaN  NaN
# 356                      NaN           NaN           NaN           NaN  6.0
# 358                      NaN           NaN           NaN           NaN  NaN
# 384                      NaN           NaN           NaN           NaN  9.0
# 386                      NaN           NaN           NaN           NaN  9.0
# 405                      NaN           NaN           NaN           NaN  9.0
# 406                      NaN           NaN           NaN           NaN  9.0
# 412                      NaN           NaN           NaN           NaN  9.0
#
#     HTTP_Status URL_OK
# 10          NaN  False
# 15          NaN  False
# 16          NaN  False
# 18          NaN  False
# 37        403.0  False
# 38        405.0  False
# 40        403.0  False
# 43          NaN  False
# 50        404.0  False
# 66        404.0  False
# 74          NaN  False
# 76        403.0  False
# 80          NaN  False
# 81        405.0  False
# 94        500.0  False
# 95        404.0  False
# 135       403.0  False
# 144         NaN  False
# 146         NaN  False
# 151         NaN  False
# 155       403.0  False
# 158       403.0  False
# 159         NaN  False
# 161         NaN  False
# 162         NaN  False
# 163         NaN  False
# 168       403.0  False
# 171       404.0  False
# 177       500.0  False
# 194         NaN  False
# 201       404.0  False
# 214         NaN  False
# 234         NaN  False
# 236         NaN  False
# 242         NaN  False
# 243         NaN  False
# 244         NaN  False
# 245       404.0  False
# 248       404.0  False
# 259         NaN  False
# 260       404.0  False
# 273       404.0  False
# 275       404.0  False
# 306       404.0  False
# 316       404.0  False
# 356         NaN  False
# 358         NaN  False
# 384         NaN  False
# 386         NaN  False
# 405         NaN  False
# 406         NaN  False
# 412         NaN  False
#
# [52 rows x 32 columns]

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
