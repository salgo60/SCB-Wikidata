# %% [markdown]
# * SCB_37_Dash_Inspector_Notebook - verkar inte vara problem
#
# * Issue [37](https://github.com/salgo60/SCB-Wikidata/issues/37)
# * denna Notebook [SCB_37_Dash_Inspector_Notebook.ipynb](https://github.com/salgo60/SCB-Wikidata/blob/main/notebook/SCB_37_Dash_Inspector_Notebook.ipynb)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2025-11-20 13:43:04

# %%
# Notebook: Dash Inspector for Myndighetsregistret
# Läs in ALLA exporterade filer i underkatalogen "myndighetsreg/"
# Undersök vilka typer av bindestreck som förekommer i organisationsnummer
# Gruppera poster efter vilket Unicode-dash-tecken som används

import pandas as pd
import os
import re
from collections import defaultdict

# --- 1. Hitta alla filer i katalogen ---
DIR = 'myndighetsreg_export'
files = [os.path.join(DIR, f) for f in os.listdir(DIR) if f.lower().endswith('.txt')]

print("Hittade filer:")
for f in files:
    print(f)
# --- 2. Funktion: identifiera vilken typ av dash som används ---
DASH_MAP = {
    '-': 'ASCII hyphen (U+002D)',
    '\u2013': 'EN DASH (U+2013)',
    '\u2014': 'EM DASH (U+2014)',
    '\u2212': 'MINUS SIGN (U+2212)',
    '\u2010': 'HYPHEN (U+2010)',
    '\u2011': 'NON-BREAKING HYPHEN (U+2011)',
    '\ufe58': 'SMALL EM DASH (U+FE58)',
    '\u2043': 'HYPHEN BULLET (U+2043)'
}

ALL_DASHES = set(DASH_MAP.keys())


def find_dash_type(orgnr):
    """Returnerar en lista med vilka dash-tecken som förekommer i strängen."""
    if pd.isna(orgnr):
        return []

    s = str(orgnr)
    found = []
    for ch in s:
        if ch in ALL_DASHES:
            found.append(ch)
    return found

# --- 3. Läs in alla filer och samla dash-typer ---
groups = defaultdict(list)  # key = dash type, value = list of rows

for path in files:
    try:
        df = pd.read_csv(path, sep='\t', dtype=str, encoding='utf-8')
    except Exception as e:
        print('Fel vid läsning av', path, e)
        continue

    col = None
    for c in df.columns:
        if 'org' in c.lower():  # heuristik
            col = c
            break

    if not col:
        print('Ingen organisationsnummerkolumn hittad i', path)
        continue

    for i, row in df.iterrows():
        org = row[col]
        dash_types = find_dash_type(org)
        if not dash_types:
            groups['INGET DASH'].append((path, org))
        else:
            for d in dash_types:
                groups[DASH_MAP.get(d, f'UNKNOWN ({d})')].append((path, org))

# --- 4. Sammanställning ---
print("\n=== Sammanfattning av dash-typer ===")
for dash, rows in groups.items():
    print(f"{dash}: {len(rows)} poster")
# Out:
# Hittade filer:
# myndighetsreg_export/Statliga förvaltningsmyndigheter.txt
# myndighetsreg_export/Svenska utlandsmyndigheter.txt
# myndighetsreg_export/Statliga affärsverk.txt
# myndighetsreg_export/Sveriges domstolar samt Domstolsverket.txt
# myndighetsreg_export/Myndigheter under riksdagen.txt
# Ingen organisationsnummerkolumn hittad i myndighetsreg_export/Svenska utlandsmyndigheter.txt
#
# === Sammanfattning av dash-typer ===
# ASCII hyphen (U+002D): 341 poster

# %% [markdown]
# ### Skapa en fil för hela database

# %%
import os
import pandas as pd

DIR = "Myndighetsreg_export"

# Hitta alla txt-filer
files = [os.path.join(DIR, f) for f in os.listdir(DIR) if f.lower().endswith('.txt')]

dfs = []

for file in files:
    # Justera sep beroende på filtyp: '\t', ';', ',' osv.
    df = pd.read_csv(file, sep="\t", encoding="utf-8")  
    dfs.append(df)

# Slå ihop till en enda DataFrame
merged = pd.concat(dfs, ignore_index=True)

# Spara som en CSV
merged.to_csv("Myndighetsreg_concat/Myndighetsreg_alla.csv", index=False, encoding="utf-8")

print("Klart! skapade sammanstallt.csv")
# Out:
# Klart! skapade sammanstallt.csv

# %%
import pandas as pd
import requests
from tqdm.notebook import tqdm

tqdm.pandas()   # aktiverar progress_apply()

def check_url(url):
    """Returnera HTTP-statuskod (eller None) och OK/Fail."""
    try:
        checkurl = "http://" + url.lstrip("/")
        r = requests.head(checkurl, allow_redirects=True, timeout=5)
        return r.status_code, (r.status_code < 400)
    except Exception:
        return None, False

# Progressbar visas automatiskt
merged["HTTP_Status"], merged["URL_OK"] = zip(*merged["Webbadress"].progress_apply(check_url))

# Filtrera trasiga länkar
broken = merged[~merged["URL_OK"]]

print("Antal trasiga länkar:", len(broken))

# Lista trasiga url:er
print("\n📌 Felaktiga URL:er:")
for url in broken["Webbadress"]:
    print(url)

# Spara rapport
broken.to_csv("trasiga_webbadresser.csv", index=False)

display(broken)
# Out:
#   0%|          | 0/455 [00:00<?, ?it/s]
# Antal trasiga länkar: 54
#
# 📌 Felaktiga URL:er:
# www.bolagsverket.se
# www.csn.se
# nan
# www.domstol.se/domarnamnden
# www.fmv.se
# www.fra.se
# www.forsvarsmakten.se
# nan
# www.hb.se
# www.imy.se
# www.kommerskollegium.se
# www.konkurrensverket.se
# http://www.regeringen.se/myndigheter-med-flera/krigsforsakringsnamnden/
# www.kriminalvarden.se
# www.osthammar.se/sv/organisation/namnd/lokala-sakerhetsnamnden/
# www.oskarshamn.se/mer-om-kommunen/karnenergi-och-karnavfall/lokala-sakerhetsnamnden-vid-oskarshamns-karnkraftverk-och-karnenergiberedskap/
# www.mtfa.se
# www.domstol.se/Om-Sveriges-Domstolar/Notarienamnden
# https://npof.se
# www.bolagsverket.se/om/oss/fler/patentombud
# www.raa.se
# www.riksarkivet.se
# nan
# www.rymdstyrelsen.se
# www.domstol.se/rattshjalpsnamnden
# www.sida.se
# www.kammarkollegiet.se/kammarkollegiet/vi-arbetar-ocksa-med/naemndmyndigheter/skiljenaemnden-i-vissa-trygghetsfragor
# www.lotteriinspektionen.se
# www.sfhm.se
# http://www.kammarkollegiet.se/n-mndmyndigheter/skaderegleringsn-mnden
# www.kammarkollegiet.se/namndmyndigheter/statens-overklagandenamnd/om-namnden
# www.su.se
# www.sgu.se
# nan
# www.vinnova.se
# www.kammarrattenisundsvall.se
# www.oks.se
# nan
# www.swedenabroad.se/sv/utlandsmyndigheter/afghanistan-kabul
# www.swedenabroad.se/sv/utlandsmyndigheter/angola-luanda
# www.swedenabroad.se/sv/utlandsmyndigheter/europeiska-unionen
# www.swedenabroad.com (www.suecia.org.br)
# www.swedenabroad.se/sv/utlandsmyndigheter/burkina-faso-ouagadougou/
# www.swedenabroad.se/sv/utlandsmyndigheter/oecd-unesco/om-delegationen/delegationens-personal
# www.swedenabroad.se/sv/utlandsmyndigheter/oecd-unesco/om-delegationen/delegationens-personal
# www.swedenabroad.se/sv/utlandsmyndigheter/mali-bamako
# www.swedenabroad.se/sv/utlandsmyndigheter/peru-lima
# www.swedenabroad.se/sv/utlandsmyndigheter/usa-washington
# www.apfond6.se
# nan
# www.gotahovratt.se
# www.hogstadomstolen.se
# www.hogstaforvaltningsdomstolen.se
# www.kammarrattenisundsvall.se
#     Organisationsnr                                               Namn  \
# 10      202100-5489                                       BOLAGSVERKET
# 15      202100-1819                        CENTRALA STUDIESTÖDSNÄMNDEN
# 16      202100-6842  Delegationen för folkrättslig granskning av va...
# 18      202100-6081                                       Domarnämnden
# 38      202100-0340                            FÖRSVARETS MATERIELVERK
# 39      202100-0365                            FÖRSVARETS RADIOANSTALT
# 41      202100-4615                                     FÖRSVARSMAKTEN
# 44      202100-6859        Granskningsnämnden för försvarsuppfinningar
# 51      202100-3138                                  HÖGSKOLAN I BORÅS
# 67      202100-0050                       Integritetsskyddsmyndigheten
# 75      202100-2007                                   KOMMERSKOLLEGIUM
# 77      202100-4342                                   KONKURRENSVERKET
# 81      202100-5810                            Krigsförsäkringsnämnden
# 82      202100-0225                                     KRIMINALVÅRDEN
# 95      202100-6735               Lokala säkerhetsnämnden vid Forsmark
# 96      202100-6743             Lokala säkerhetsnämnden vid Oskarshamn
# 138     202100-7055                MYNDIGHETEN FÖR TOTALFÖRSVARSANALYS
# 147     202100-6032                                     Notarienämnden
# 149     202100-6933     Nämnden för prövning av oredlighet i forskning
# 154     202100-6370                                PATENTOMBUDSNÄMNDEN
# 161     202100-1090                              RIKSANTIKVARIEÄMBETET
# 162     202100-1074                                        RIKSARKIVET
# 164     202100-6784                              Riksvärderingsnämnden
# 165     202100-2585                                      RYMDSTYRELSEN
# 166     202100-6008                                  Rättshjälpnämnden
# 171     202100-4789                                               Sida
# 174     202100-5869              Skiljenämnden i vissa trygghetsfrågor
# 180     202100-3310                                   SPELINSPEKTIONEN
# 186     202100-0464                  STATENS FÖRSVARSHISTORISKA MUSEER
# 200     202100-5828                       Statens skaderegleringsnämnd
# 207     202100-4763                          Statens överklagandenämnd
# 211     202100-3062                             STOCKHOLMS UNIVERSITET
# 220     202100-2528                   SVERIGES GEOLOGISKA UNDERSÖKNING
# 240     202100-6826              Utrikesförvaltningens antagningsnämnd
# 242     202100-5216                       VERKET FÖR INNOVATIONSSYSTEM
# 248     202100-6024         Överklagandenämnden för nämndemannauppdrag
# 249     202100-5273                 ÖVERKLAGANDENÄMNDEN FÖR STUDIESTÖD
# 250             NaN                                                NaN
# 251             NaN                            Sveriges ambassad Kabul
# 254             NaN                           Sveriges ambassad Luanda
# 261             NaN                 Sveriges EU-representation Bryssel
# 265             NaN                         Sveriges ambassad Brasilia
# 266             NaN                      Sveriges ambassad Ouagadougou
# 279             NaN                    Sveriges delegation Paris, OECD
# 281             NaN                   Sveriges delegation UNESCO Paris
# 312             NaN                           Sveriges ambassad Bamako
# 322             NaN                             Sveriges ambassad Lima
# 350             NaN                       Sveriges ambassad Washington
# 362     855104-0721                                   SJÄTTE AP-FONDEN
# 390     202100-2742                                GÄLLIVARE TINGSRÄTT
# 392     202100-2742                                       GÖTA HOVRÄTT
# 411     202100-2742                                   HÖGSTA DOMSTOLEN
# 412     202100-2742                       HÖGSTA FÖRVALTNINGSDOMSTOLEN
# 418     202100-2742                           KAMMARRÄTTEN I SUNDSVALL
#
#           PostAdress  PostNr     PostOrt             BesöksAdress  \
# 10               NaN  851 81   SUNDSVALL           STUVARVÄGEN 21
# 15               NaN  851 82   SUNDSVALL       NORRA TJÄRNGATAN 2
# 16               NaN  103 33   STOCKHOLM                      NaN
# 18          BOX 2330  103 18   STOCKHOLM      BIRGER JARLS TORG 5
# 38               NaN  115 88   STOCKHOLM            BANÉRGATAN 62
# 39           BOX 301  161 26      BROMMA            RÖRBYVÄGEN 20
# 41               NaN  107 85   STOCKHOLM          Lidingövägen 24
# 44               NaN  103 33   STOCKHOLM                      NaN
# 51               NaN  501 90       BORÅS              ALLÉGATAN 1
# 67          BOX 8114  104 20   STOCKHOLM          Fleminggatan 14
# 75          BOX 6803  113 86   STOCKHOLM         FLEMMINGGATAN 14
# 77     RINGVÄGEN 100  118 60   STOCKHOLM            RINGVÄGEN 100
# 81          Box 7821  103 97   STOCKHOLM                      NaN
# 82               NaN  601 80  NORRKÖPING           SLOTTSGATAN 78
# 95            BOX 66  742 21   ÖSTHAMMAR                      NaN
# 96           BOX 706  572 28  OSKARSHAMN                      NaN
# 138        BOX 24250  104 51   STOCKHOLM     Karlavägen 104  9 tr
# 147         Box 2203  550 02   JÖNKÖPING                      NaN
# 149         BOX 2110  750 02     UPPSALA  Dag Hammarskjölds väg 7
# 154           BOX 46  851 02   SUNDSVALL                      NaN
# 161         BOX 1114  621 22       VISBY             STORGATAN 41
# 162         BOX 7223  187 13        TÄBY       Fyrverkarbacken 13
# 164              NaN  103 33   STOCKHOLM                      NaN
# 165         BOX 4006  171 04       SOLNA          Hemvärnsgatan 9
# 166          Box 170  851 03   SUNDSVALL       Södra Tjärngatan 2
# 171         BOX 2025  174 02  SUNDBYBERG          Rissneleden 110
# 174         Box 2218  103 15   STOCKHOLM                      NaN
# 180          BOX 199  645 23   STRÄNGNÄS       FINNINGEVÄGEN 54 B
# 186        BOX 14095  104 41   STOCKHOLM           RIDDARGATAN 13
# 200         Box 2218  103 15   STOCKHOLM                      NaN
# 207         BOX 2218  103 15   STOCKHOLM                      NaN
# 211              NaN  106 91   STOCKHOLM   UNIVERSITETSVÄGEN 10 A
# 220          BOX 670  751 28     UPPSALA     Dragarbrunnsgatan 77
# 240              NaN  103 33   STOCKHOLM                      NaN
# 242              NaN  101 58   STOCKHOLM   MÄSTER SAMUELSGATAN 56
# 248          Box 714  851 21   SUNDSVALL       Södra Tjärngatan 2
# 249          BOX 110  871 23   HÄRNÖSAND              BACKGRÄND 9
# 250              NaN     NaN         NaN                      NaN
# 251              NaN     NaN         NaN                      NaN
# 254              NaN     NaN         NaN                      NaN
# 261              NaN     NaN         NaN                      NaN
# 265              NaN     NaN         NaN                      NaN
# 266              NaN     NaN         NaN                      NaN
# 279              NaN     NaN         NaN                      NaN
# 281              NaN     NaN         NaN                      NaN
# 312              NaN     NaN         NaN                      NaN
# 322              NaN     NaN         NaN                      NaN
# 350              NaN     NaN         NaN                      NaN
# 362  KÖPMANSGATAN 32  411 06    GÖTEBORG          KÖPMANSGATAN 32
# 390           BOX 23  982 21   GÄLLIVARE        LASARETTSGATAN 22
# 392         BOX 2223  550 02   JÖNKÖPING             HAMNGATAN 11
# 411         BOX 2066  103 12   STOCKHOLM        RIDDARHUSTORGET 8
# 412         BOX 2293  103 17   STOCKHOLM     BIRGER JARLS TORG 13
# 418          BOX 714  851 21   SUNDSVALL       Södra Tjärngatan 2
#
#     BesöksPostNr  BesöksPostOrt                  Tfn                  Fax  \
# 10        852 29      SUNDSVALL          771670670.0                  NaN
# 15        852 33      SUNDSVALL           60186000.0                  NaN
# 16        000 00      STOCKHOLM                  NaN                  NaN
# 18        111 28      STOCKHOLM          856166950.0                  NaN
# 38        115 53      STOCKHOLM           87824000.0                  NaN
# 39        178 93  DROTTNINGHOLM          105574600.0                  NaN
# 41        115 57      STOCKHOLM           87887500.0                  NaN
# 44        000 00      STOCKHOLM                  NaN                  NaN
# 51        503 32          BORÅS          334354000.0                  NaN
# 67        112 26      STOCKHOLM           86576100.0                  NaN
# 75        112 26      STOCKHOLM           86904800.0                  NaN
# 77        118 60      STOCKHOLM           87001600.0                  NaN
# 81        000 00      STOCKHOLM           87878000.0                  NaN
# 82        602 22     NORRKÖPING          772280800.0                  NaN
# 95        000 00      ÖSTHAMMAR                  NaN                  NaN
# 96        000 00     OSKARSHAMN                  NaN                  NaN
# 138       115 23      STOCKHOLM          101605100.0                  NaN
# 147       000 00      JÖNKÖPING           36156800.0                  NaN
# 149       752 37        UPPSALA          104573320.0                  NaN
# 154          NaN            NaN          771670670.0                  NaN
# 161       114 55      STOCKHOLM          851918000.0                  NaN
# 162       112 60      STOCKHOLM          104767000.0                  NaN
# 164       000 00      STOCKHOLM                  NaN                  NaN
# 165       171 54          SOLNA          840907700.0                  NaN
# 166       852 33      SUNDSVALL           60186891.0                  NaN
# 171       174 57     SUNDBYBERG           86985000.0                  NaN
# 174       000 00      STOCKHOLM           87000800.0                  NaN
# 180       645 42      STRÄNGNÄS          152650100.0                  NaN
# 186       114 51      STOCKHOLM          851956310.0                  NaN
# 200       000 00      STOCKHOLM           87000800.0                  NaN
# 207          NaN            NaN           87000800.0                  NaN
# 211       114 18      STOCKHOLM            8162000.0                  NaN
# 220       753 19        UPPSALA           18179000.0                  NaN
# 240       000 00      STOCKHOLM                  NaN                  NaN
# 242       101 58      STOCKHOLM           84733000.0                  NaN
# 248       852 33      SUNDSVALL           60186600.0                  NaN
# 249       871 32      HÄRNÖSAND          611347500.0                  NaN
# 250          NaN            NaN                  NaN                  NaN
# 251          NaN            NaN     +93 20 210 49 12                  NaN
# 254          NaN            NaN      +244 222 447522                  NaN
# 261          NaN            NaN      +32 2 289 56 11      +32 2 289 56 00
# 265          NaN            NaN  +55 (61) 3442 52 00  +55 (61) 3443 11 87
# 266          NaN            NaN     +226 50 49 61 70                  NaN
# 279          NaN            NaN    +33 1 44 18 88 00    +33 1 44 18 88 10
# 281          NaN            NaN    +33 1 45 68 34 50                  NaN
# 312          NaN            NaN     +223 20 70 70 00     +223 20 70 70 10
# 322          NaN            NaN         +511 5669240         +511 2210298
# 350          NaN            NaN      +1 202 467 2600                  NaN
# 362       411 06       GÖTEBORG          317411000.0                  NaN
# 390       982 32      GÄLLIVARE           97075800.0                  NaN
# 392       553 16      JÖNKÖPING           36156900.0                  NaN
# 411       111 28      STOCKHOLM          856166600.0                  NaN
# 412       111 28      STOCKHOLM          856167600.0                  NaN
# 418       852 33      SUNDSVALL           60186600.0                  NaN
#
#      ...                                      BesöksAdress1  \
# 10   ...                                                NaN
# 15   ...                                                NaN
# 16   ...                                                NaN
# 18   ...                                                NaN
# 38   ...                                                NaN
# 39   ...                                                NaN
# 41   ...                                                NaN
# 44   ...                                                NaN
# 51   ...                                                NaN
# 67   ...                                                NaN
# 75   ...                                                NaN
# 77   ...                                                NaN
# 81   ...                                                NaN
# 82   ...                                                NaN
# 95   ...                                                NaN
# 96   ...                                                NaN
# 138  ...                                                NaN
# 147  ...                                                NaN
# 149  ...                                                NaN
# 154  ...                                                NaN
# 161  ...                                                NaN
# 162  ...                                                NaN
# 164  ...                                                NaN
# 165  ...                                                NaN
# 166  ...                                                NaN
# 171  ...                                                NaN
# 174  ...                                                NaN
# 180  ...                                                NaN
# 186  ...                                                NaN
# 200  ...                                                NaN
# 207  ...                                                NaN
# 211  ...                                                NaN
# 220  ...                                                NaN
# 240  ...                                                NaN
# 242  ...                                                NaN
# 248  ...                                                NaN
# 249  ...                                                NaN
# 250  ...                                                NaN
# 251  ...                                  Sveriges Ambassad
# 254  ...                               Rua Garcia Neto nº 9
# 261  ...  Sveriges ständiga representation vid Europeisk...
# 265  ...                       Sveriges Ambassad i Brasilia
# 266  ...                                  Sveriges ambassad
# 279  ...         La délégation de la Suède auprès de l'OCDE
# 281  ...                                                NaN
# 312  ...                                 Ambassade de Suède
# 322  ...                           Calle La Santa María 120
# 350  ...                                      2900 K Street
# 362  ...                                                NaN
# 390  ...                                                NaN
# 392  ...                                                NaN
# 411  ...                                                NaN
# 412  ...                                                NaN
# 418  ...                                                NaN
#
#                     BesöksAdress2       BesöksAdress3  \
# 10                            NaN                 NaN
# 15                            NaN                 NaN
# 16                            NaN                 NaN
# 18                            NaN                 NaN
# 38                            NaN                 NaN
# 39                            NaN                 NaN
# 41                            NaN                 NaN
# 44                            NaN                 NaN
# 51                            NaN                 NaN
# 67                            NaN                 NaN
# 75                            NaN                 NaN
# 77                            NaN                 NaN
# 81                            NaN                 NaN
# 82                            NaN                 NaN
# 95                            NaN                 NaN
# 96                            NaN                 NaN
# 138                           NaN                 NaN
# 147                           NaN                 NaN
# 149                           NaN                 NaN
# 154                           NaN                 NaN
# 161                           NaN                 NaN
# 162                           NaN                 NaN
# 164                           NaN                 NaN
# 165                           NaN                 NaN
# 166                           NaN                 NaN
# 171                           NaN                 NaN
# 174                           NaN                 NaN
# 180                           NaN                 NaN
# 186                           NaN                 NaN
# 200                           NaN                 NaN
# 207                           NaN                 NaN
# 211                           NaN                 NaN
# 220                           NaN                 NaN
# 240                           NaN                 NaN
# 242                           NaN                 NaN
# 248                           NaN                 NaN
# 249                           NaN                 NaN
# 250                           NaN                 NaN
# 251  MoI-Street, opposite the MoI          Shar-e Naw
# 254                       Miramar              Luanda
# 261            Square de Meeûs 30             Bryssel
# 265           Avenida das Nações,     Qd.807, lote 29
# 266       Avenue de l'Europe, 187        Burkina Faso
# 279         17 rue Barbet-de-Jouy         75007 Paris
# 281                           NaN                 NaN
# 312     Immeuble UATT, 2eme etage  Quartier du Fleuve
# 322                    San Isidro                Lima
# 350              N.W., Washington                 NaN
# 362                           NaN                 NaN
# 390                           NaN                 NaN
# 392                           NaN                 NaN
# 411                           NaN                 NaN
# 412                           NaN                 NaN
# 418                           NaN                 NaN
#
#                BesöksAdress4 BesöksAdress5 BesöksAdress6 BesöksAdress7 Sort  \
# 10                       NaN           NaN           NaN           NaN  NaN
# 15                       NaN           NaN           NaN           NaN  NaN
# 16                       NaN           NaN           NaN           NaN  NaN
# 18                       NaN           NaN           NaN           NaN  NaN
# 38                       NaN           NaN           NaN           NaN  NaN
# 39                       NaN           NaN           NaN           NaN  NaN
# 41                       NaN           NaN           NaN           NaN  NaN
# 44                       NaN           NaN           NaN           NaN  NaN
# 51                       NaN           NaN           NaN           NaN  NaN
# 67                       NaN           NaN           NaN           NaN  NaN
# 75                       NaN           NaN           NaN           NaN  NaN
# 77                       NaN           NaN           NaN           NaN  NaN
# 81                       NaN           NaN           NaN           NaN  NaN
# 82                       NaN           NaN           NaN           NaN  NaN
# 95                       NaN           NaN           NaN           NaN  NaN
# 96                       NaN           NaN           NaN           NaN  NaN
# 138                      NaN           NaN           NaN           NaN  NaN
# 147                      NaN           NaN           NaN           NaN  NaN
# 149                      NaN           NaN           NaN           NaN  NaN
# 154                      NaN           NaN           NaN           NaN  NaN
# 161                      NaN           NaN           NaN           NaN  NaN
# 162                      NaN           NaN           NaN           NaN  NaN
# 164                      NaN           NaN           NaN           NaN  NaN
# 165                      NaN           NaN           NaN           NaN  NaN
# 166                      NaN           NaN           NaN           NaN  NaN
# 171                      NaN           NaN           NaN           NaN  NaN
# 174                      NaN           NaN           NaN           NaN  NaN
# 180                      NaN           NaN           NaN           NaN  NaN
# 186                      NaN           NaN           NaN           NaN  NaN
# 200                      NaN           NaN           NaN           NaN  NaN
# 207                      NaN           NaN           NaN           NaN  NaN
# 211                      NaN           NaN           NaN           NaN  NaN
# 220                      NaN           NaN           NaN           NaN  NaN
# 240                      NaN           NaN           NaN           NaN  NaN
# 242                      NaN           NaN           NaN           NaN  NaN
# 248                      NaN           NaN           NaN           NaN  NaN
# 249                      NaN           NaN           NaN           NaN  NaN
# 250                      NaN           NaN           NaN           NaN  NaN
# 251       Kabul, Afghanistan           NaN           NaN           NaN  NaN
# 254                      NaN           NaN           NaN           NaN  NaN
# 261                      NaN           NaN           NaN           NaN  NaN
# 265  70419-900 Brasilia - DF           NaN           NaN           NaN  NaN
# 266                      NaN           NaN           NaN           NaN  NaN
# 279                      NaN           NaN           NaN           NaN  NaN
# 281                      NaN           NaN           NaN           NaN  NaN
# 312             Bamako, Mali           NaN           NaN           NaN  NaN
# 322                     Peru           NaN           NaN           NaN  NaN
# 350                      NaN           NaN           NaN           NaN  NaN
# 362                      NaN           NaN           NaN           NaN  6.0
# 390                      NaN           NaN           NaN           NaN  9.0
# 392                      NaN           NaN           NaN           NaN  9.0
# 411                      NaN           NaN           NaN           NaN  9.0
# 412                      NaN           NaN           NaN           NaN  9.0
# 418                      NaN           NaN           NaN           NaN  9.0
#
#     URL_OK HTTP_Status
# 10   False         NaN
# 15   False         NaN
# 16   False         NaN
# 18   False         NaN
# 38   False       403.0
# 39   False       405.0
# 41   False       403.0
# 44   False         NaN
# 51   False       404.0
# 67   False       404.0
# 75   False         NaN
# 77   False       403.0
# 81   False         NaN
# 82   False       405.0
# 95   False       500.0
# 96   False       404.0
# 138  False       403.0
# 147  False         NaN
# 149  False         NaN
# 154  False         NaN
# 161  False       403.0
# 162  False         NaN
# 164  False         NaN
# 165  False         NaN
# 166  False         NaN
# 171  False       403.0
# 174  False       404.0
# 180  False       500.0
# 186  False         NaN
# 200  False         NaN
# 207  False       404.0
# 211  False       403.0
# 220  False         NaN
# 240  False         NaN
# 242  False         NaN
# 248  False         NaN
# 249  False         NaN
# 250  False         NaN
# 251  False       404.0
# 254  False       404.0
# 261  False         NaN
# 265  False         NaN
# 266  False       404.0
# 279  False       404.0
# 281  False       404.0
# 312  False       404.0
# 322  False       404.0
# 350  False         NaN
# 362  False         NaN
# 390  False         NaN
# 392  False         NaN
# 411  False         NaN
# 412  False         NaN
# 418  False         NaN
#
# [54 rows x 32 columns]

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
