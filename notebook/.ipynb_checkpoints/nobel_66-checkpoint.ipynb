# %% [markdown]
# * Notebook [nobel_66.ipynb](https://github.com/salgo60/SCB-Wikidata/blob/main/notebook/nobel_66.ipynb)
# * [#66](https://github.com/salgo60/SCB-Wikidata/issues/66)
# * result
#    * [html](https://salgo60.github.io/SCB-Wikidata/notebook/resultsNobel/links_nobel_v1_2026_02_05.html)
#    * [csv](https://salgo60.github.io/SCB-Wikidata/notebook/resultsNobel/links_nobel_v1_2026_02_05.csv)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-02-14 21:21:28

# %%
SCRIPT_NAME = "nobel_66.ipynb"
SCRIPT_URL = (
    "https://github.com/salgo60/SCB-Wikidata/"
    "blob/master/notebook/nobel_66.ipynb"
)

# %%
def read_domains(file_path):
    print(f"[DEBUG] Reading domains from: {file_path}")
    df = pd.read_csv(file_path, header=0)   # <- skip header row
    domains_list = df.iloc[:, 0].dropna().unique().tolist()
    print(f"[DEBUG] Found {len(domains_list)} domains.")
    return domains_list

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60) salgo60@msn.com"
}


df_lang_fetch = fetch_sitematrix_df()
df_lang_fetch["closed"] = df_lang_fetch["closed"].fillna(False).astype(bool)

df_lang_wikipedia = df_lang_fetch[
    (df_lang_fetch["site_name"] == "Wikipedia") &
    (
        (df_lang_fetch["lang_name"].str.lower() != "special") |
        (df_lang_fetch["dbname"] == "wikidatawiki")
    )
]  
# Above also contains Wikidata 
# df_lang_fetch = fetch_sitematrix_df()
# df_lang_fetch["closed"] = df_lang_fetch["closed"].fillna(False).astype(bool)
#
# df_lang_wikipedia = df_lang_filtered = df_lang_fetch[
#    (df_lang_fetch["site_name"] == "Wikipedia") &
#    (df_lang_fetch["lang_name"].str.lower() != "special")]
# 
# 

#df_lang_wikipedia.to_csv("test.csv")
df_lang_wikipedia.info()
# Out:
# [DEBUG] Fetching sitematrix…
# <class 'pandas.core.frame.DataFrame'>
# Index: 186 entries, 0 to 1047
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  186 non-null    object
#  1   lang_name  185 non-null    object
#  2   project    0 non-null      object
#  3   url        186 non-null    object
#  4   dbname     186 non-null    object
#  5   site_name  186 non-null    object
#  6   closed     186 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 10.4+ KB

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SCB-Wikidata/notebook

# %%
import os
import time
import random
import requests
import pandas as pd
from urllib.parse import urlparse
from tqdm.notebook import tqdm
file_path_domain = "sources/domains_nobel.csv"
domains = read_domains(file_path_domain)
print(domains)
# Out:
# [DEBUG] Reading domains from: sources/domains_nobel.csv
# [DEBUG] Found 2 domains.
# ['nobelprize.se', 'nobelprize.org']

# %%
def resolve_api_base(lang):
    if lang == "special":
        # Wikidata (only valid "special" case in your pipeline)
        return "https://www.wikidata.org/w/api.php"

    return f"https://{lang}.wikipedia.org/w/api.php"

# %%
def request_timeout(lang):
    return 100 if lang == "special" else 10

# %%
# -----------------------------------------------------------
# Fetch exturlusage entries for one lang/domain
# -----------------------------------------------------------
def fetch_exturlusage(lang, domain):
    #base = f"https://{lang}.wikipedia.org/w/api.php"
    base = resolve_api_base(lang)
    params = {
        "action": "query",
        "format": "json",
        "list": "exturlusage",
        "euquery": domain,
        "eulimit": "max"
    }
    while True:
        #r = session.get(base, params=params, timeout=10)
        r = session.get(base, params=params, timeout=request_timeout(lang))        
        try:
            data = r.json()
        except ValueError:
            print(f"[WARN] {lang}: JSON decode failed")
            break

        for item in data.get("query", {}).get("exturlusage", []):
            yield {
                "lang": lang,
                "page_title": item.get("title"),
                "url": item.get("url"),
                "wiki_link": f"https://{lang}.wikipedia.org/wiki/{item.get('title').replace(' ', '_')}"
            }

        if "continue" not in data:
            break
        params.update(data["continue"])
        time.sleep(0.3)

# %%
# -------------------------
# Session & helpers
# -------------------------
session = requests.Session()
session.headers.update({"User-Agent": "SCB-LinkAudit/1.0 salgo60@msn.com"})

# we need some filtering  

print("Antal Språk:",len(df_lang_wikipedia ))
results = []
for _, row in df_lang_wikipedia.iterrows():
    lang = row["lang_code"]
    url  = row["url"]
    lang_name = row["lang_name"]
    before = len(results)
    #print(lang, url, lang_name,domains)
    for entry in fetch_exturlusage(lang, domains):
        results.append(entry)     
    after = len(results) 
    links = after-before
    print(lang, url, lang_name," - ", links)
# Out:
# Antal Språk: 186
# aa https://aa.wikipedia.org Qafár af  -  0
# ace https://ace.wikipedia.org Acèh  -  0
# af https://af.wikipedia.org Afrikaans  -  1004
# ak https://ak.wikipedia.org None  -  0
# ami https://ami.wikipedia.org Pangcah  -  0
# an https://an.wikipedia.org aragonés  -  31
# ast https://ast.wikipedia.org asturianu  -  946
# av https://av.wikipedia.org авар  -  2
# avk https://avk.wikipedia.org Kotava  -  0
# ay https://ay.wikipedia.org Aymar aru  -  11
# bar https://bar.wikipedia.org Boarisch  -  44
# bbc https://bbc.wikipedia.org Batak Toba  -  1
# bcl https://bcl.wikipedia.org Bikol Central  -  85
# bi https://bi.wikipedia.org Bislama  -  0
# bm https://bm.wikipedia.org bamanankan  -  0
# bo https://bo.wikipedia.org བོད་ཡིག  -  97
# br https://br.wikipedia.org brezhoneg  -  48
# bs https://bs.wikipedia.org bosanski  -  1150
# btm https://btm.wikipedia.org Batak Mandailing  -  5
# bug https://bug.wikipedia.org Basa Ugi  -  0
# bxr https://bxr.wikipedia.org буряад  -  10
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga  -  1
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄  -  0
# ceb https://ceb.wikipedia.org Cebuano  -  2
# ch https://ch.wikipedia.org Chamoru  -  0
# cho https://cho.wikipedia.org Chahta anumpa  -  0
# chr https://chr.wikipedia.org ᏣᎳᎩ  -  0
# co https://co.wikipedia.org corsu  -  1
# cr https://cr.wikipedia.org Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ  -  0
# csb https://csb.wikipedia.org kaszëbsczi  -  5
# da https://da.wikipedia.org dansk  -  1319
# de https://de.wikipedia.org Deutsch  -  3298
# din https://din.wikipedia.org Thuɔŋjäŋ  -  0
# diq https://diq.wikipedia.org Zazaki  -  19
# dtp https://dtp.wikipedia.org Kadazandusun  -  5
# dz https://dz.wikipedia.org ཇོང་ཁ  -  0
# ee https://ee.wikipedia.org eʋegbe  -  0
# eml https://eml.wikipedia.org emiliàn e rumagnòl  -  3
# [WARN] en: JSON decode failed
# en https://en.wikipedia.org English  -  11000
# [WARN] es: JSON decode failed
# es https://es.wikipedia.org español  -  0
# [WARN] eu: JSON decode failed
# eu https://eu.wikipedia.org euskara  -  0
# [WARN] fat: JSON decode failed
# fat https://fat.wikipedia.org mfantse  -  0
# [WARN] ff: JSON decode failed
# ff https://ff.wikipedia.org Fulfulde  -  0
# [WARN] fi: JSON decode failed
# fi https://fi.wikipedia.org suomi  -  0
# [WARN] fj: JSON decode failed
# fj https://fj.wikipedia.org Na Vosa Vakaviti  -  0
# [WARN] fo: JSON decode failed
# fo https://fo.wikipedia.org føroyskt  -  0
# [WARN] frr: JSON decode failed
# frr https://frr.wikipedia.org Nordfriisk  -  0
# [WARN] gl: JSON decode failed
# gl https://gl.wikipedia.org galego  -  0
# [WARN] glk: JSON decode failed
# glk https://glk.wikipedia.org گیلکی  -  0
# [WARN] gor: JSON decode failed
# gor https://gor.wikipedia.org Bahasa Hulontalo  -  0
# [WARN] got: JSON decode failed
# got https://got.wikipedia.org 𐌲𐌿𐍄𐌹𐍃𐌺  -  0
# [WARN] gpe: JSON decode failed
# gpe https://gpe.wikipedia.org Ghanaian Pidgin  -  0
# [WARN] gsw: JSON decode failed
# gsw https://als.wikipedia.org Alemannisch  -  0
# [WARN] guw: JSON decode failed
# guw https://guw.wikipedia.org gungbe  -  0
# [WARN] gv: JSON decode failed
# gv https://gv.wikipedia.org Gaelg  -  0
# [WARN] ha: JSON decode failed
# ha https://ha.wikipedia.org Hausa  -  0
# [WARN] hak: JSON decode failed
# hak https://hak.wikipedia.org 客家語 / Hak-kâ-ngî  -  0
# [WARN] haw: JSON decode failed
# haw https://haw.wikipedia.org Hawaiʻi  -  0
# [WARN] hif: JSON decode failed
# hif https://hif.wikipedia.org Fiji Hindi  -  0
# [WARN] ho: JSON decode failed
# ho https://ho.wikipedia.org Hiri Motu  -  0
# [WARN] hz: JSON decode failed
# hz https://hz.wikipedia.org Otsiherero  -  0
# [WARN] ia: JSON decode failed
# ia https://ia.wikipedia.org interlingua  -  0
# [WARN] iba: JSON decode failed
# iba https://iba.wikipedia.org Jaku Iban  -  0
# [WARN] id: JSON decode failed
# id https://id.wikipedia.org Bahasa Indonesia  -  0
# [WARN] ie: JSON decode failed
# ie https://ie.wikipedia.org Interlingue  -  0
# [WARN] ig: JSON decode failed
# ig https://ig.wikipedia.org Igbo  -  0
# [WARN] ii: JSON decode failed
# ii https://ii.wikipedia.org ꆇꉙ  -  0
# [WARN] ik: JSON decode failed
# ik https://ik.wikipedia.org Iñupiatun  -  0
# [WARN] ilo: JSON decode failed
# ilo https://ilo.wikipedia.org Ilokano  -  0
# [WARN] is: JSON decode failed
# is https://is.wikipedia.org íslenska  -  0
# [WARN] it: JSON decode failed
# it https://it.wikipedia.org italiano  -  0
# [WARN] ja: JSON decode failed
# ja https://ja.wikipedia.org 日本語  -  0
# [WARN] jbo: JSON decode failed
# jbo https://jbo.wikipedia.org la .lojban.  -  0
# [WARN] kaa: JSON decode failed
# kaa https://kaa.wikipedia.org Qaraqalpaqsha  -  0
# [WARN] kab: JSON decode failed
# kab https://kab.wikipedia.org Taqbaylit  -  0
# [WARN] kaj: JSON decode failed
# kaj https://kaj.wikipedia.org Jju  -  0
# [WARN] kcg: JSON decode failed
# kcg https://kcg.wikipedia.org Tyap  -  0
# [WARN] kg: JSON decode failed
# kg https://kg.wikipedia.org Kongo  -  0
# [WARN] ki: JSON decode failed
# ki https://ki.wikipedia.org Gĩkũyũ  -  0
# [WARN] kj: JSON decode failed
# kj https://kj.wikipedia.org Kwanyama  -  0
# [WARN] kl: JSON decode failed
# kl https://kl.wikipedia.org kalaallisut  -  0
# [WARN] knc: JSON decode failed
# knc https://knc.wikipedia.org Yerwa Kanuri  -  0
# kr https://kr.wikipedia.org kanuri  -  0
# ksh https://ksh.wikipedia.org Ripoarisch  -  1
# kv https://kv.wikipedia.org коми  -  0
# kw https://kw.wikipedia.org kernowek  -  1
# lb https://lb.wikipedia.org Lëtzebuergesch  -  82
# lg https://lg.wikipedia.org Luganda  -  0
# li https://li.wikipedia.org Limburgs  -  89
# lij https://lij.wikipedia.org Ligure  -  0
# lld https://lld.wikipedia.org Ladin  -  0
# lmo https://lmo.wikipedia.org lombard  -  5
# ln https://ln.wikipedia.org lingála  -  1
# mad https://mad.wikipedia.org Madhurâ  -  8
# map-bms https://map-bms.wikipedia.org Basa Banyumasan  -  9
# mg https://mg.wikipedia.org Malagasy  -  8
# mh https://mh.wikipedia.org Ebon  -  0
# mi https://mi.wikipedia.org Māori  -  0
# min https://min.wikipedia.org Minangkabau  -  11
# ms https://ms.wikipedia.org Bahasa Melayu  -  1948
# mus https://mus.wikipedia.org Mvskoke  -  0
# na https://na.wikipedia.org Dorerin Naoero  -  0
# nan https://zh-min-nan.wikipedia.org 閩南語 / Bân-lâm-gí  -  34
# nap https://nap.wikipedia.org Napulitano  -  1
# nds https://nds.wikipedia.org Plattdüütsch  -  532
# nds-nl https://nds-nl.wikipedia.org Nedersaksies  -  0
# new https://new.wikipedia.org नेपाल भाषा  -  21
# ng https://ng.wikipedia.org Oshiwambo  -  0
# nia https://nia.wikipedia.org Li Niha  -  1
# nl https://nl.wikipedia.org Nederlands  -  1298
# nn https://nn.wikipedia.org norsk nynorsk  -  849
# no https://no.wikipedia.org norsk  -  4375
# nov https://nov.wikipedia.org Novial  -  1
# nrm https://nrm.wikipedia.org Nouormand  -  0
# nso https://nso.wikipedia.org Sesotho sa Leboa  -  3
# nup https://nup.wikipedia.org Nupe  -  0
# nv https://nv.wikipedia.org Diné bizaad  -  0
# ny https://ny.wikipedia.org Chi-Chewa  -  2
# om https://om.wikipedia.org Oromoo  -  2
# pag https://pag.wikipedia.org Pangasinan  -  0
# pam https://pam.wikipedia.org Kapampangan  -  31
# pap https://pap.wikipedia.org Papiamentu  -  2
# pcd https://pcd.wikipedia.org Picard  -  0
# pcm https://pcm.wikipedia.org Naijá  -  0
# pdc https://pdc.wikipedia.org Deitsch  -  0
# pfl https://pfl.wikipedia.org Pälzisch  -  0
# pi https://pi.wikipedia.org पालि  -  1
# pih https://pih.wikipedia.org Norfuk / Pitkern  -  0
# pl https://pl.wikipedia.org polski  -  3494
# pms https://pms.wikipedia.org Piemontèis  -  2
# pwn https://pwn.wikipedia.org pinayuanan  -  1
# qu https://qu.wikipedia.org Runa Simi  -  83
# rm https://rm.wikipedia.org rumantsch  -  4
# rn https://rn.wikipedia.org ikirundi  -  0
# ro https://ro.wikipedia.org română  -  2772
# roa-tara https://roa-tara.wikipedia.org tarandíne  -  4
# [WARN] rup: JSON decode failed
# rup https://roa-rup.wikipedia.org armãneashti  -  0
# rw https://rw.wikipedia.org Ikinyarwanda  -  0
# sc https://sc.wikipedia.org sardu  -  13
# scn https://scn.wikipedia.org sicilianu  -  8
# sco https://sco.wikipedia.org Scots  -  119
# se https://se.wikipedia.org davvisámegiella  -  11
# sg https://sg.wikipedia.org Sängö  -  0
# sgs https://bat-smg.wikipedia.org žemaitėška  -  4
# shi https://shi.wikipedia.org Taclḥit  -  2
# simple https://simple.wikipedia.org Simple English  -  1284
# sm https://sm.wikipedia.org Gagana Samoa  -  0
# smn https://smn.wikipedia.org anarâškielâ  -  2633
# sn https://sn.wikipedia.org chiShona  -  0
# so https://so.wikipedia.org Soomaaliga  -  7
# sq https://sq.wikipedia.org shqip  -  341
# srn https://srn.wikipedia.org Sranantongo  -  0
# ss https://ss.wikipedia.org SiSwati  -  1
# st https://st.wikipedia.org Sesotho  -  1
# stq https://stq.wikipedia.org Seeltersk  -  0
# su https://su.wikipedia.org Sunda  -  33
# [WARN] sv: JSON decode failed
# sv https://sv.wikipedia.org svenska  -  1500
# [WARN] sw: JSON decode failed
# sw https://sw.wikipedia.org Kiswahili  -  0
# [WARN] szl: JSON decode failed
# szl https://szl.wikipedia.org ślůnski  -  0
# [WARN] tet: JSON decode failed
# tet https://tet.wikipedia.org tetun  -  0
# [WARN] tl: JSON decode failed
# tl https://tl.wikipedia.org Tagalog  -  0
# [WARN] tn: JSON decode failed
# tn https://tn.wikipedia.org Setswana  -  0
# [WARN] to: JSON decode failed
# to https://to.wikipedia.org lea faka-Tonga  -  0
# [WARN] tpi: JSON decode failed
# tpi https://tpi.wikipedia.org Tok Pisin  -  0
# [WARN] ts: JSON decode failed
# ts https://ts.wikipedia.org Xitsonga  -  0
# [WARN] tt: JSON decode failed
# tt https://tt.wikipedia.org татарча / tatarça  -  0
# [WARN] tum: JSON decode failed
# tum https://tum.wikipedia.org chiTumbuka  -  0
# [WARN] tw: JSON decode failed
# tw https://tw.wikipedia.org Twi  -  0
# [WARN] ty: JSON decode failed
# ty https://ty.wikipedia.org reo tahiti  -  0
# [WARN] ug: JSON decode failed
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche  -  0
# [WARN] ve: JSON decode failed
# ve https://ve.wikipedia.org Tshivenda  -  0
# [WARN] vec: JSON decode failed
# vec https://vec.wikipedia.org vèneto  -  0
# [WARN] vi: JSON decode failed
# vi https://vi.wikipedia.org Tiếng Việt  -  0
# [WARN] vls: JSON decode failed
# vls https://vls.wikipedia.org West-Vlams  -  0
# [WARN] vro: JSON decode failed
# vro https://fiu-vro.wikipedia.org võro  -  0
# [WARN] wa: JSON decode failed
# wa https://wa.wikipedia.org walon  -  0
# [WARN] war: JSON decode failed
# war https://war.wikipedia.org Winaray  -  0
# [WARN] wo: JSON decode failed
# wo https://wo.wikipedia.org Wolof  -  0
# [WARN] xal: JSON decode failed
# xal https://xal.wikipedia.org хальмг  -  0
# [WARN] xh: JSON decode failed
# xh https://xh.wikipedia.org isiXhosa  -  0
# [WARN] yo: JSON decode failed
# yo https://yo.wikipedia.org Yorùbá  -  0
# [WARN] za: JSON decode failed
# za https://za.wikipedia.org Vahcuengh  -  0
# [WARN] zea: JSON decode failed
# zea https://zea.wikipedia.org Zeêuws  -  0
# [WARN] zh: JSON decode failed
# zh https://zh.wikipedia.org 中文  -  0
# [WARN] zu: JSON decode failed
# zu https://zu.wikipedia.org isiZulu  -  0
# [WARN] special: JSON decode failed
# special https://www.wikidata.org special  -  0

# %%
df_nobel = pd.DataFrame(results)
df_nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40720 entries, 0 to 40719
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        40720 non-null  object
#  1   page_title  40720 non-null  object
#  2   url         40720 non-null  object
#  3   wiki_link   40720 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_nobel)
total_unique_links = df_nobel['url'].nunique()
num_languages = df_nobel['lang'].nunique()
langs_sorted = df_nobel['lang'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 40720
# Total unique links: 16033
# Number of languages: 70
#
# Languages with most links:
# lang
# en          11000
# no           4375
# pl           3494
# de           3298
# ro           2772
# smn          2633
# ms           1948
# sv           1500
# da           1319
# nl           1298
# simple       1284
# bs           1150
# af           1004
# ast           946
# nn            849
# nds           532
# sq            341
# sco           119
# bo             97
# li             89
# bcl            85
# qu             83
# lb             82
# br             48
# bar            44
# nan            34
# su             33
# an             31
# pam            31
# new            21
# diq            19
# sc             13
# ay             11
# se             11
# min            11
# bxr            10
# map-bms         9
# mad             8
# mg              8
# scn             8
# so              7
# lmo             5
# csb             5
# btm             5
# dtp             5
# roa-tara        4
# sgs             4
# rm              4
# nso             3
# eml             3
# shi             2
# pap             2
# pms             2
# av              2
# om              2
# ny              2
# ceb             2
# st              1
# ss              1
# cbk-zam         1
# bbc             1
# pwn             1
# pi              1
# nov             1
# nia             1
# ln              1
# kw              1
# ksh             1
# co              1
# nap             1

# %%
df_nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40720 entries, 0 to 40719
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        40720 non-null  object
#  1   page_title  40720 non-null  object
#  2   url         40720 non-null  object
#  3   wiki_link   40720 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
# --- Stats ---
total_links = len(df_nobel)
total_unique_links = df_nobel["url"].nunique()
langs_with_hits = sorted(df_nobel["lang"].unique())

num_languages_found = len(langs_with_hits)
num_languages_checked = len(df_lang_wikipedia)        # alla språk som genomsöktes
num_languages_found = df_nobel['lang'].nunique()

# %%
num_languages_checked
# Out:
# 186

# %%
import requests
from requests.exceptions import RequestException
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import pandas as pd
import time
import threading

# ==========================
# Konfiguration
# ==========================

OUTPUT = "checkpoint_links_nobel.parquet"
MAX_WORKERS = 12
REQUEST_TIMEOUT = 15
CHECKPOINT_EVERY = 1000

ROOT_CANONICAL = "https://www.nobelprize.org"

SOFT_404_PHRASES = [
    "Page Not Found",
    "sidan tagits bort",
    "felaktig adress",
    "kontakta registrator",
    "sidan finns inte",
    "den här sidan kan inte visas",
    "Hoppsan! Vi kunde tyvärr inte hitta sidan"
]

USER_AGENT = "LinkChecker/1.0 (research; salgo60@msn.com)"

# ==========================
# Session (thread-safe)
# ==========================

thread_local = threading.local()

def get_session():
    if not hasattr(thread_local, "session"):
        s = requests.Session()
        s.headers.update({"User-Agent": USER_AGENT})
        thread_local.session = s
    return thread_local.session


# ==========================
# Hjälpfunktioner
# ==========================

def norm(u: str) -> str:
    return u.rstrip("/").lower()


def looks_like_soft_404(response) -> bool:
    text = (response.text or "").lower()

    for phrase in SOFT_404_PHRASES:
        if phrase in text:
            return True

    if "<title>" in text:
        title = text.split("<title>", 1)[1].split("</title>", 1)[0]
        if "404" in title.lower():
            return True
        if "sidan finns inte" in title.lower():
            return True

    return False



# ==========================
# URL-check
# ==========================

def check_url(url: str) -> dict:
    session = get_session()

    try:
        # 1. HEAD först
        r = session.head(
            url,
            allow_redirects=True,
            timeout=REQUEST_TIMEOUT,
        )
    except RequestException as e:
        return {
            "url": url,
            "status": "error",
            "reason": str(e),
        }

    final_url = r.url
    status_code = r.status_code

    # Hard error
    if status_code >= 400:
        return {
            "url": url,
            "status": "dead",
            "reason": f"HTTP {status_code}",
            "final_url": final_url,
        }

    # Redirect till root
    if norm(final_url) == norm(ROOT_CANONICAL) and norm(url) != norm(final_url):
        return {
            "url": url,
            "status": "dead",
            "reason": "redirect_to_root",
            "final_url": final_url,
        }

    # 2. GET endast vid behov
    try:
        r = session.get(
            final_url,
            allow_redirects=True,
            timeout=REQUEST_TIMEOUT,
        )
    except RequestException as e:
        return {
            "url": url,
            "status": "error",
            "reason": str(e),
            "final_url": final_url,
        }

    if looks_like_soft_404(r):
        return {
            "url": url,
            "status": "dead",
            "reason": "soft_404",
            "final_url": final_url,
        }

    return {
        "url": url,
        "status": "ok",
        "final_url": final_url,
    }


# ==========================
# Internet Archive
# ==========================

def check_internet_archive(url: str) -> str | None:
    session = get_session()
    api = "https://archive.org/wayback/available"

    try:
        r = session.get(
            api,
            params={"url": url},
            timeout=10,
        )
        data = r.json()
    except Exception:
        return None

    snap = data.get("archived_snapshots", {}).get("closest")
    if snap and snap.get("available"):
        return snap.get("url")

    return None


# ==========================
# Worker
# ==========================

def process_url(url: str) -> dict:
    result = check_url(url)

    if result["status"] == "dead":
        ia_url = check_internet_archive(url)
        result["ia_url"] = ia_url
        result["ia_status"] = "available" if ia_url else "missing"
    else:
        result["ia_url"] = None
        result["ia_status"] = "skipped"

    return result


# ==========================
# Main
# ==========================

def run(df_nobel: pd.DataFrame) -> pd.DataFrame:
    urls = [
        u for u in df_nobel["url"].dropna().astype(str).unique()
    ]

    results = []
    start = time.time()

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = {executor.submit(process_url, u): u for u in urls}

        for i, future in enumerate(
            tqdm(as_completed(futures), total=len(futures), unit="link"),
            start=1
        ):
            result = future.result()
            results.append(result)

            if i % CHECKPOINT_EVERY == 0:
                pd.DataFrame(results).to_parquet(OUTPUT)

    df = pd.DataFrame(results)
    df.to_parquet(OUTPUT)

    elapsed = time.time() - start
    print(f"Klar på {elapsed/3600:.1f} timmar")

    return df

# %%
df_nobel
# Out:
#       lang               page_title  \
# 0       af                Nobelprys
# 1       af                Nobelprys
# 2       af          Theodor Mommsen
# 3       af    Bjørnstjerne Bjørnson
# 4       af          William Golding
# ...    ...                      ...
# 40715   sv             Max von Laue
# 40716   sv  William Bragg (fysiker)
# 40717   sv  William Bragg (fysiker)
# 40718   sv           Lawrence Bragg
# 40719   sv           Lawrence Bragg
#
#                                                      url  \
# 0                             http://www.nobelprize.org/
# 1      http://nobelprize.org/nobel/nobel-foundation/i...
# 2      http://nobelprize.org/literature/laureates/190...
# 3      http://nobelprize.org/literature/laureates/190...
# 4      http://nobelprize.org/literature/laureates/198...
# ...                                                  ...
# 40715  https://www.nobelprize.org/prizes/physics/1914...
# 40716  https://www.nobelprize.org/prizes/physics/1915...
# 40717  https://www.nobelprize.org/prizes/physics/1915...
# 40718  https://www.nobelprize.org/prizes/physics/1915...
# 40719  https://www.nobelprize.org/prizes/physics/1915...
#
#                                                wiki_link
# 0                https://af.wikipedia.org/wiki/Nobelprys
# 1                https://af.wikipedia.org/wiki/Nobelprys
# 2          https://af.wikipedia.org/wiki/Theodor_Mommsen
# 3      https://af.wikipedia.org/wiki/Bjørnstjerne_Bjø...
# 4          https://af.wikipedia.org/wiki/William_Golding
# ...                                                  ...
# 40715         https://sv.wikipedia.org/wiki/Max_von_Laue
# 40716  https://sv.wikipedia.org/wiki/William_Bragg_(f...
# 40717  https://sv.wikipedia.org/wiki/William_Bragg_(f...
# 40718       https://sv.wikipedia.org/wiki/Lawrence_Bragg
# 40719       https://sv.wikipedia.org/wiki/Lawrence_Bragg
#
# [40720 rows x 4 columns]

# %%
df_result = run(df_nobel)
# Out:
# 100%|███████████████████████████████████| 16033/16033 [20:38<00:00, 12.94link/s]
# Klar på 0.3 timmar

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16033 entries, 0 to 16032
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        16033 non-null  object
#  1   status     16033 non-null  object
#  2   final_url  16019 non-null  object
#  3   ia_url     489 non-null    object
#  4   ia_status  16033 non-null  object
#  5   reason     2995 non-null   object
# dtypes: object(6)
# memory usage: 751.7+ KB

# %%
df_nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40720 entries, 0 to 40719
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        40720 non-null  object
#  1   page_title  40720 non-null  object
#  2   url         40720 non-null  object
#  3   wiki_link   40720 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
print("len(results):", len(results))

print("df_result.shape:", df_result.shape)
print(df_result.head(2))
print(df_result.tail(2))
# Out:
# len(results): 40720
# df_result.shape: (16033, 6)
#                                                  url status  \
# 0  http://nobelprize.org/nobel_prizes/economics/l...     ok
# 1  http://www.nobelprize.org/nobel_prizes/physics...     ok
#
#                                            final_url ia_url ia_status reason
# 0  https://www.nobelprize.org/prizes/economic-sci...   None   skipped    NaN
# 1  https://www.nobelprize.org/prizes/physics/2011...   None   skipped    NaN
#                                                      url status  \
# 16031  https://www.nobelprize.org/prizes/physics/1944...     ok
# 16032  https://www.nobelprize.org/prizes/uncategorize...     ok
#
#                                                final_url ia_url ia_status  \
# 16031  https://www.nobelprize.org/prizes/physics/1944...   None   skipped
# 16032  https://www.nobelprize.org/about/the-nobel-com...   None   skipped
#
#       reason
# 16031    NaN
# 16032    NaN

# %%
print("len(results):", len(results))
print("first:", results[0])
print("last:", results[-1])
# Out:
# len(results): 40720
# first: {'lang': 'af', 'page_title': 'Nobelprys', 'url': 'http://www.nobelprize.org/', 'wiki_link': 'https://af.wikipedia.org/wiki/Nobelprys'}
# last: {'lang': 'sv', 'page_title': 'Lawrence Bragg', 'url': 'https://www.nobelprize.org/prizes/physics/1915/wl-bragg/biographical/', 'wiki_link': 'https://sv.wikipedia.org/wiki/Lawrence_Bragg'}

# %%
results[:3]
# Out:
# [{'lang': 'af',
#   'page_title': 'Nobelprys',
#   'url': 'http://www.nobelprize.org/',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Nobelprys'},
#  {'lang': 'af',
#   'page_title': 'Nobelprys',
#   'url': 'http://nobelprize.org/nobel/nobel-foundation/index.html',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Nobelprys'},
#  {'lang': 'af',
#   'page_title': 'Theodor Mommsen',
#   'url': 'http://nobelprize.org/literature/laureates/1902/index.html',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Theodor_Mommsen'}]

# %%
df_results = (
    pd.DataFrame(results)
    .drop_duplicates(subset="url", keep="last")
)
df_nobel = df_nobel.merge(
    df_result,
    on="url",
    how="left",
)

# %%
df_nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40720 entries, 0 to 40719
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        40720 non-null  object
#  1   page_title  40720 non-null  object
#  2   url         40720 non-null  object
#  3   wiki_link   40720 non-null  object
#  4   status      40720 non-null  object
#  5   final_url   40700 non-null  object
#  6   ia_url      1723 non-null   object
#  7   ia_status   40720 non-null  object
#  8   reason      6158 non-null   object
# dtypes: object(9)
# memory usage: 2.8+ MB

# %%
status_counts = df_nobel["status"].value_counts()

num_ok = status_counts.get("ok", 0)
num_dead = status_counts.get("dead", 0)
num_error = status_counts.get("error", 0)
num_total = len(status_counts)
print( "Ok ",num_ok) 
print( "Dead ",num_dead)
print( "Error ",num_error ) 
print( "Total ",num_total )
# Out:
# Ok  34562
# Dead  6138
# Error  20
# Total  3

# %%
df_nobel["reason"].value_counts()
# Out:
# reason
# HTTP 404                                                                                                                                                                                                                                                                                                                                                                                                                                                                        5808
# redirect_to_root                                                                                                                                                                                                                                                                                                                                                                                                                                                                 259
# HTTP 530                                                                                                                                                                                                                                                                                                                                                                                                                                                                          65
# HTTP 400                                                                                                                                                                                                                                                                                                                                                                                                                                                                           4
# HTTPSConnectionPool(host='assets.nobelprize.org', port=443): Max retries exceeded with url: /uploads/2018/06/kosterlitz-lecture.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x174b40c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                     2
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=George+Bernard+Shaw&i=en&x=0&y=0 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15b75fe00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                              2
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel2013/?i=en&charset=UTF-8&oenc=UTF-8&q=knisely (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15ae4a060>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                     2
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=atheist&i=en (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x169218590>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                  2
# HTTP 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                           2
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=Herczeg&i=en (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15a450290>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                  2
# HTTPConnectionPool(host='static.nobelprize.org', port=80): Max retries exceeded with url: /nobel_prizes/economics/laureates/2010/press.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16950d190>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                               2
# HTTPSConnectionPool(host='assets.nobelprize.org', port=443): Max retries exceeded with url: /uploads/2018/06/meer-lecture.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x15aa31730>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                           1
# HTTPConnectionPool(host='static.nobelprize.org', port=80): Max retries exceeded with url: /nobel_prizes/literature/laureates/2010/press.pdf/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x168e40320>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                             1
# HTTPConnectionPool(host='static.nobelprize.org', port=80): Max retries exceeded with url: /nobel_prizes/physics/laureates/2010/sciback_phy_10.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15a7dab10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                        1
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=troels+lund&i=en (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15b0542f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                              1
# HTTPSConnectionPool(host='assets.nobelprize.org', port=443): Max retries exceeded with url: /uploads/2018/06/kahnemann-lecture.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x15b09d940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                      1
# HTTPSConnectionPool(host='www.nobelprize.org', port=443): Read timed out. (read timeout=15)                                                                                                                                                                                                                                                                                                                                                                                        1
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=weigl&t=simple&ls=2&d=0&d1=01&d2=1&d3=1970&d4=12&d5=01&d6=2013&s=0&so=1&h=0&hn=10&hd=1&i=en&p=&b=3&c=0&t=s&l=0&ll=-2&f=0&ff=0&oenc=&ua=90026fc69709467036341905483cb57e (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x30650da60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))       1
# HTTPConnectionPool(host='search.nobelprize.org', port=80): Max retries exceeded with url: /search/nobel/?q=yunus&i=en&x=0&y=0 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x168e428a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                            1
# Name: count, dtype: int64

# %%
from datetime import date
import os

# Sätt datum
today = date.today().strftime("%Y_%m_%d")

# Se till att katalogen finns
os.makedirs("resultsNobel", exist_ok=True)

# Bygg filnamn
outfile = f"resultsNobel/links_nobel_v1_{today}.csv"

# Exportera
df_nobel.to_csv(outfile, index=False, encoding="utf-8")

print(f"[OK] Exported {len(df_nobel)} rows to {outfile}")
# Out:
# [OK] Exported 40720 rows to resultsNobel/links_nobel_v1_2026_02_14.csv

# %%
lang_stats = (
    df_nobel
    .groupby("lang")
    .agg(
        total_links=("url", "count"),
        broken_links=("status", lambda s: (s == "dead").sum()),
        archived_links=("ia_status", lambda s: (s == "available").sum()),
    )
    .reset_index()
)

lang_stats["broken_pct"] = (
    100 * lang_stats["broken_links"] / lang_stats["total_links"]
).round(1)

lang_stats["broken_lost"] = (
    lang_stats["broken_links"] - lang_stats["archived_links"])

top10_langs = (
    lang_stats
    .sort_values("total_links", ascending=False)
    .head(10)
)
top10_langs[
    [
        "lang",
        "total_links",
        "broken_links",
        "broken_pct",
        "archived_links",
        "broken_lost",
    ]
]
# Out:
#    lang  total_links  broken_links  broken_pct  archived_links  broken_lost
# 22   en        11000          2240        20.4             499         1741
# 41   no         4375           376         8.6              82          294
# 49   pl         3494           168         4.8              85           83
# 18   de         3298           431        13.1              71          360
# 54   ro         2772           439        15.8              92          347
# 63  smn         2633             0         0.0               0            0
# 33   ms         1948           504        25.9             175          329
# 69   sv         1500           296        19.7              66          230
# 17   da         1319           211        16.0             127           84
# 39   nl         1298           284        21.9              57          227

# %%
## Special till lang Wikidata  
df_nobel["lang"] = df_nobel["lang"].replace({"special": "Wikidata"})

# %%
from urllib.parse import urlparse

df = df_nobel.copy()

df["domain"] = df["url"].apply(
    lambda u: urlparse(u).netloc.lower() if pd.notna(u) else None
)
domain_stats = (
    df
    .groupby("domain")
    .agg(
        total_links=("url", "count"),
        broken_links=("status", lambda s: (s == "dead").sum()),
        error_links=("status", lambda s: (s == "error").sum()),
    )
    .reset_index()
)
domain_stats["broken_pct"] = (
    100 * domain_stats["broken_links"] / domain_stats["total_links"]
).round(1)

domain_stats["error_pct"] = (
    100 * domain_stats["error_links"] / domain_stats["total_links"]
).round(1)

# %%
domain_stats
# Out:
#                              domain  total_links  broken_links  error_links  \
# 0                api.nobelprize.org            9             0            0
# 1             assets.nobelprize.org            4             0            4
# 2               data.nobelprize.org           38             0            0
# 3   educationalgames.nobelprize.org            4             0            0
# 4      masterdataapi.nobelprize.org           18             0            0
# 5                    nobelprize.org        15110          4508            0
# 6                 nobelprize.org:80            1             1            0
# 7                old.nobelprize.org           65            65            0
# 8             search.nobelprize.org           11             0           11
# 9             static.nobelprize.org            4             0            4
# 10               www.nobelprize.org        25455          1563            1
# 11            www.nobelprize.org:80            1             1            0
#
#     broken_pct  error_pct
# 0          0.0        0.0
# 1          0.0      100.0
# 2          0.0        0.0
# 3          0.0        0.0
# 4          0.0        0.0
# 5         29.8        0.0
# 6        100.0        0.0
# 7        100.0        0.0
# 8          0.0      100.0
# 9          0.0      100.0
# 10         6.1        0.0
# 11       100.0        0.0

# %%
status_counts = df["status"].value_counts()

num_ok = int(status_counts.get("ok", 0))
num_dead = int(status_counts.get("dead", 0))
num_error = int(status_counts.get("error", 0))
num_total = len(df)

pct_ok = round(100 * num_ok / num_total, 1)
pct_dead = round(100 * num_dead / num_total, 1)
pct_error = round(100 * num_error / num_total, 1)

# Broken links: archived vs lost
num_dead_archived = df[
    (df["status"] == "dead") & (df["ia_status"] == "available")
].shape[0]

num_dead_lost = num_dead - num_dead_archived

# %%
top_domains = (
    domain_stats[domain_stats["total_links"] >= 5]
    .sort_values("total_links", ascending=False)
    .head(10)
)
domain_stats_html = "<ul>"
for _, r in top_domains.iterrows():
    domain_stats_html += (
        f"<li><strong>{r['domain']}</strong>: "
        f"{r['broken_links']} / {r['total_links']} broken "
        f"({r['broken_pct']}%)</li>"
    )
domain_stats_html += "</ul>"

# %%
from pathlib import Path
from datetime import date, datetime
from urllib.parse import quote
import pandas as pd



def is_qid(title):
    return isinstance(title, str) and title.startswith("Q") and title[1:].isdigit()

def save_sortable_html_df_nobel(
    df,
    out_dir="resultsNobel",
    domains=None,
    issue_url="https://github.com/salgo60/SCB-Wikidata/issues/66",
):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True)

    today = date.today().strftime("%Y_%m_%d")
    out_path = out_dir / f"links_nobel_v1_{today}.html"
    rerun_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

     # --- Förbered data ---
    df = df.copy()  
    status_counts = df["status"].value_counts()
    df["is_wikidata"] = df["page_title"].apply(is_qid)
    
    # Normalize lang
    df.loc[df["is_wikidata"], "lang"] = "wikidata"
    df["lang"] = df["lang"].replace({"special": None})

    num_ok = int(status_counts.get("ok", 0))
    num_dead = int(status_counts.get("dead", 0))
    num_error = int(status_counts.get("error", 0))
    num_total = len(df)
    
    pct_ok = round(100 * num_ok / num_total, 1)
    pct_dead = round(100 * num_dead / num_total, 1)
    pct_error = round(100 * num_error / num_total, 1)
    
    # Broken links: archived vs lost
    num_dead_archived = df[
        (df["status"] == "dead") & (df["ia_status"] == "available")
    ].shape[0]
    
    num_dead_lost = num_dead - num_dead_archived

    domains = domains or []
    from urllib.parse import urlparse
    
    df["domain"] = df["url"].apply(
        lambda u: urlparse(u).netloc.lower() if pd.notna(u) else None
    )

    domain_stats = (
        df
        .groupby("domain")
        .agg(
            total_links=("url", "count"),
            broken_links=("status", lambda s: (s == "dead").sum()),
            error_links=("status", lambda s: (s == "error").sum()),
        )
        .reset_index()
    )
    
    domain_stats["broken_pct"] = (
        100 * domain_stats["broken_links"] / domain_stats["total_links"]
    ).round(1)
    
    domain_stats["error_pct"] = (
        100 * domain_stats["error_links"] / domain_stats["total_links"]
    ).round(1)
    
    domain_stats["problem_pct"] = (
        100 * (domain_stats["broken_links"] + domain_stats["error_links"])
        / domain_stats["total_links"]
    ).round(1)
    

    domain_stats_html = "<ul>"
    for _, r in top_domains.iterrows():
        domain_stats_html += (
            f"<li><strong>{r['domain']}</strong>: "
            f"{r['broken_links']} / {r['total_links']} broken "
            f"({r['broken_pct']}%)</li>"
        )
    domain_stats_html += "</ul>"

    domain_table_html = (
        domain_stats
        .head(20)
        .to_html(
            classes="pivot",
            border=0,
            index=False,
        )
    )
    lang_stats = (
    df
        .groupby("lang")
        .agg(
            total_links=("url", "count"),
            broken_links=("status", lambda s: (s == "dead").sum()),
            error_links=("status", lambda s: (s == "error").sum()),
            broken_archived=("ia_status", lambda s: (s == "available").sum()),
        )
        .reset_index()
    )
    
    lang_stats["broken_lost"] = (
        lang_stats["broken_links"] - lang_stats["broken_archived"]
    )
    
    lang_stats["broken_pct"] = (
        100 * lang_stats["broken_links"] / lang_stats["total_links"]
    ).round(1)
    
    lang_stats["problem_pct"] = (
        100 * (lang_stats["broken_links"] + lang_stats["error_links"])
        / lang_stats["total_links"]
    ).round(1)

    lang_stats = lang_stats.sort_values(
        "broken_links",
        ascending=False
    )
 
    lang_stats_display = lang_stats[
        [
            "lang",
            "total_links",
            "broken_links",
            "broken_archived",
            "broken_lost",
            "broken_pct",
            "problem_pct",
        ]
    ]

    lang_table_html = (
        lang_stats_display
        .head(15)
        .to_html(
            classes="pivot",
            border=0,
            index=False,
        )
    )

    STATUS_ICON = {
        "ok":    ("fa-circle-check", "#2e7d32", "OK"),
        "dead":  ("fa-circle-xmark", "#c62828", "Broken link"),
        "error": ("fa-triangle-exclamation", "#ef6c00", "Request error"),
    }
    
    if "status" in df.columns:
        def render_status(r):
            icon, color, label = STATUS_ICON.get(
                r["status"], ("fa-question-circle", "#757575", "Unknown")
            )
            reason = r.get("reason", "")
            return (
                f'<span class="status-icon" '
                f'data-status="{r["status"]}" '
                f'title="{label}: {reason}" '
                f'style="color:{color}; font-size:14px; cursor:pointer;">'
                f'<i class="fa-solid {icon}"></i>'
                f'</span>'
            )
        df.insert(
            0,
            "status_icon",
            df.apply(render_status, axis=1)
        )

        def render_ia_icon(r):
            if r.get("ia_status") == "available" and r.get("ia_url"):
                return (
                    f'<a href="{r["ia_url"]}" target="_blank" '
                    f'title="Archived copy (Internet Archive)">'
                    f'<i class="fa-solid fa-box-archive" '
                    f'style="color:#1565c0;"></i>'
                    f'</a>'
                )
            return ""
        
        df.insert(
            1,
            "archive",
            df.apply(render_ia_icon, axis=1)
        )


    # Wikipedia: ikon + titel (byggd från lang + page_title)
    if {"lang", "page_title"}.issubset(df.columns):
    
        def render_page_link(r):
            title = r["page_title"]
    
            # --- Wikidata item ---
            if r.get("is_wikidata"):
                label = r.get("wd_label_sv")
                link_text = label if pd.notna(label) else title
    
                return (
                    f'<a href="https://www.wikidata.org/wiki/{title}" '
                    f'target="_blank" title="Wikidata">'
                    f'<i class="fa-solid fa-database" style="margin-right:6px;"></i>'
                    f'{link_text}</a>'
                )
    
            # --- Wikipedia article ---
            lang = r.get("lang")
            if pd.notna(lang) and pd.notna(title):
                return (
                    f'<a href="https://{lang}.wikipedia.org/wiki/{quote(str(title))}" '
                    f'target="_blank" title="Wikipedia ({lang})">'
                    f'<i class="fa-brands fa-wikipedia-w" style="margin-right:6px;"></i>'
                    f'{title}</a>'
                )
    
            return title

        df["page_title"] = df.apply(render_page_link, axis=1)

    # Externa länkar
    for col in ["Wikipedia-länk", "Extern länk", "url"]:
        if col in df.columns:
            df[col] = df[col].apply(
                lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
            )

    # --- HTML-tabell ---
    html_table = df.to_html(
        classes="pivot",
        border=0,
        escape=False,  # krävs för HTML-länkar
        index=False,
    )

    # --- CSS ---
    css = """
    <style>
      body {
        font-family: Arial, sans-serif;
        margin: 20px;
      }
      table.pivot {
        border-collapse: collapse;
        width: 100%;
        font-size: 12px;
      }
      table.pivot th, table.pivot td {
        border: 1px solid #999;
        padding: 6px 8px;
        text-align: left;
        vertical-align: top;
        white-space: normal;
      }
      table.pivot th {
        cursor: pointer;
        background: #f2f2f2;
      }
      table.pivot th:hover {
        background: #e2e2e2;
      }
      table.pivot thead th {
        position: sticky;
        top: 0;
        background: #f2f2f2;
        z-index: 2;
      }
      table.pivot th::after {
        content: "";
        float: right;
        opacity: 0.4;
      }
      table.pivot th.sorted-asc::after {
        content: " ▲";
      }
      table.pivot th.sorted-desc::after {
        content: " ▼";
      }
      /* Row coloring by status */
      table.pivot tr[data-status="dead"] {
         background-color: #fdecea;  /* light red */
      }
      table.pivot tr[data-status="dead"] td:nth-child(2) i {
          color: #1565c0;
        }

      table.pivot tr[data-status="error"] {
          background-color: #fff4e5;  /* light orange */
      }

      table.pivot td a {
        color: #0645ad;
        text-decoration: none;
      }
      table.pivot td a:hover {
        text-decoration: underline;
      }
      .meta {
        background: #f8f8f8;
        border: 1px solid #ccc;
        padding: 12px;
        margin-bottom: 20px;
        font-size: 13px;
      }
      .meta h2 {
        margin-top: 0;
      }
    </style>
    """

    # --- JavaScript (sortering) ---
    js = """
    <script>
    document.addEventListener('DOMContentLoaded', () => {
        // Propagate status from first cell to row
        document.querySelectorAll("table.pivot tbody tr").forEach(row => {
            const statusCell = row.querySelector(".status-icon");
            if (statusCell) {
                row.dataset.status = statusCell.dataset.status;
            }
        });
        let showOnlyBroken = false;

        document.querySelectorAll(".status-icon").forEach(icon => {
            icon.addEventListener("click", event => {
                event.stopPropagation(); // prevent column sort
                showOnlyBroken = !showOnlyBroken;
        
                document.querySelectorAll("table.pivot tbody tr").forEach(row => {
                    if (showOnlyBroken) {
                        row.style.display =
                            row.dataset.status === "dead" ? "" : "none";
                    } else {
                        row.style.display = "";
                    }
                });
            });
        });

        document.querySelectorAll("table.pivot th").forEach((header, colIndex) => {
            header.addEventListener("click", () => {
                const table = header.closest("table");
                const tbody = table.querySelector("tbody");
                const rows = Array.from(tbody.querySelectorAll("tr"));
                const asc = !header.classList.contains("sorted-asc");

                rows.sort((a, b) => {
                    const A = a.children[colIndex].innerText.trim();
                    const B = b.children[colIndex].innerText.trim();
                    const numA = parseFloat(A.replace(",", "."));
                    const numB = parseFloat(B.replace(",", "."));
                    if (!isNaN(numA) && !isNaN(numB)) {
                        return asc ? numA - numB : numB - numA;
                    }
                    return asc ? A.localeCompare(B) : B.localeCompare(A);
                });

                table.querySelectorAll("th").forEach(th =>
                    th.classList.remove("sorted-asc", "sorted-desc")
                );
                header.classList.add(asc ? "sorted-asc" : "sorted-desc");
                rows.forEach(row => tbody.appendChild(row));
            });
        });
    });
    </script>
    """
    status_counts = df["status"].value_counts()
    
    num_ok = status_counts.get("ok", 0)
    num_dead = status_counts.get("dead", 0)
    num_error = status_counts.get("error", 0)
    num_total = len(df)

    # --- Metadata ---
    meta_html = f"""
    <div class="meta">
      <h2>Summary</h2>
    
      <p><strong>Rerun:</strong> {rerun_ts}</p>
      <p><strong>Script:</strong>
         <a href="{SCRIPT_URL}" target="_blank">{SCRIPT_NAME}</a>
      </p>
    
      <p>
        <strong>Links checked:</strong> {num_total}<br>
        <strong style="color:#2e7d32;">OK:</strong> {num_ok} ({pct_ok}%)<br>
        <strong style="color:#c62828;">Broken:</strong> {num_dead} ({pct_dead}%)<br>
        &nbsp;&nbsp;↳ Archived: {num_dead_archived}<br>
        &nbsp;&nbsp;↳ Lost: {num_dead_lost}<br>
        <strong style="color:#ef6c00;">Errors:</strong> {num_error} ({pct_error}%)
      </p>
      <p><strong>Issue:</strong>
         <a href="{issue_url}" target="_blank">{issue_url.split("/")[-1]}</a>
      </p>
    
      <p><strong>Datakällor:</strong><br>
         Wikidata<br>
         MediaWiki API – exturlusage
      </p>
    
      <h2>Domains with broken links</h2>
      <p>Top domains ranked by broken-link impact.</p>
      {domain_table_html}
    </div>
    """


    # --- Slutlig HTML ---
    html = f"""
    <html>
    <head>
      <meta charset="utf-8">
      <title>nobelprize.org links in Wikipedia</title>
      <link rel="stylesheet"
            href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.1/css/all.min.css">
      {css}
    </head>
    <body>
      <h1>Wikipedia → nobelprize v1</h1>
      {meta_html}
      <p>Sorterbar tabell. Klicka på kolumnrubriker för sortering.</p>
      {html_table}
      {js}
      <h2>Broken-link summary by Wikipedia language</h2>
     <p>
       Languages ranked by broken-link impact (broken + error links).
     </p>
    {lang_table_html}
    </body>
    </html>
    """

    out_path.write_text(html, encoding="utf-8")
    print(f"✅ HTML skapad: {out_path}")

# %%
save_sortable_html_df_nobel(df_nobel)
# Out:
# ✅ HTML skapad: resultsNobel/links_nobel_v1_2026_02_14.html

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
# Out:
# Date: 2026-02-14 21:44:01
# Total time elapsed: 22 minutes 32.42 seconds
