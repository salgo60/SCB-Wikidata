# %% [markdown]
# * Notebook [riksdagen_60.ipynb](https://github.com/salgo60/SCB-Wikidata/blob/main/notebook/riksdagen_60.ipynb)
# * [#60](https://github.com/salgo60/SCB-Wikidata/issues/60)
# * result
#    * [html](https://salgo60.github.io/SCB-Wikidata/notebook/resultsRiksdagen/links_riksdagen_v1_2026_01_17.html)
#    * [csv](https://salgo60.github.io/SCB-Wikidata/notebook/resultsRiksdagen/links_Riksdagen_v1_2026_01_17.csv)
#
# ----
# * add Wikidata param

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-01-17 16:47:30

# %%
WikidataInclude = False
SCRIPT_NAME = "riksdagen_60.ipynb"
SCRIPT_URL = (
    "https://github.com/salgo60/SCB-Wikidata/"
    "blob/master/notebook/riksdagen_60.ipynb"
)

# %%
def read_domains(file_path):
    print(f"[DEBUG] Reading domains from: {file_path}")
    df = pd.read_csv(file_path, header=0)   # <- skip header row
    domains_list = df.iloc[:, 0].dropna().unique().tolist()
    print(f"[DEBUG] Found {len(domains_list)} domains.")
    return domains_list

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60) salgo60@msn.com"
}


df_lang_fetch = fetch_sitematrix_df()
df_lang_fetch["closed"] = df_lang_fetch["closed"].fillna(False).astype(bool)

df_lang_wikipedia = df_lang_fetch[
    (df_lang_fetch["site_name"] == "Wikipedia") &
    (
        (df_lang_fetch["lang_name"].str.lower() != "special") |
        (df_lang_fetch["dbname"] == "wikidatawiki")
    )
]  

#df_lang_wikipedia.to_csv("test.csv")
df_lang_wikipedia.info()
# Out:
# [DEBUG] Fetching sitematrix…
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 1045
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  185 non-null    object
#  1   lang_name  184 non-null    object
#  2   project    0 non-null      object
#  3   url        185 non-null    object
#  4   dbname     185 non-null    object
#  5   site_name  185 non-null    object
#  6   closed     185 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 10.3+ KB

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SCB-Wikidata/notebook

# %%
import os
import time
import random
import requests
import pandas as pd
from urllib.parse import urlparse
from tqdm.notebook import tqdm
file_path_domain = "sources/domains_riksdagen.csv"
domains = read_domains(file_path_domain)
print(domains)
# Out:
# [DEBUG] Reading domains from: sources/domains_riksdagen.csv
# [DEBUG] Found 1 domains.
# ['riksdagen.se']

# %%
def resolve_api_base(lang):
    if lang == "special":
        # Wikidata (only valid "special" case in your pipeline)
        return "https://www.wikidata.org/w/api.php"

    return f"https://{lang}.wikipedia.org/w/api.php"

# %%
def request_timeout(lang):
    return 100 if lang == "special" else 10

# %%
# -----------------------------------------------------------
# Fetch exturlusage entries for one lang/domain
# -----------------------------------------------------------
def fetch_exturlusage(lang, domain):
    #base = f"https://{lang}.wikipedia.org/w/api.php"
    base = resolve_api_base(lang)
    params = {
        "action": "query",
        "format": "json",
        "list": "exturlusage",
        "euquery": domain,
        "eulimit": "max"
    }
    while True:
        #r = session.get(base, params=params, timeout=10)
        r = session.get(base, params=params, timeout=request_timeout(lang))        
        try:
            data = r.json()
        except ValueError:
            print(f"[WARN] {lang}: JSON decode failed")
            break

        for item in data.get("query", {}).get("exturlusage", []):
            yield {
                "lang": lang,
                "page_title": item.get("title"),
                "url": item.get("url"),
                "wiki_link": f"https://{lang}.wikipedia.org/wiki/{item.get('title').replace(' ', '_')}"
            }

        if "continue" not in data:
            break
        params.update(data["continue"])
        time.sleep(0.3)

# %%
df_lang_wikipedia.info
# Out:
# <bound method DataFrame.info of      lang_code  lang_name project                        url        dbname  \
# 0           aa   Qafár af    None   https://aa.wikipedia.org        aawiki
# 5          ace       Acèh    None  https://ace.wikipedia.org       acewiki
# 7           af  Afrikaans    None   https://af.wikipedia.org        afwiki
# 11          ak       None    None   https://ak.wikipedia.org        akwiki
# 18         ami    Pangcah    None  https://ami.wikipedia.org       amiwiki
# ...        ...        ...     ...                        ...           ...
# 922         za  Vahcuengh    None   https://za.wikipedia.org        zawiki
# 926        zea     Zeêuws    None  https://zea.wikipedia.org       zeawiki
# 929         zh         中文    None   https://zh.wikipedia.org        zhwiki
# 937         zu    isiZulu    None   https://zu.wikipedia.org        zuwiki
# 1045   special    special    None   https://www.wikidata.org  wikidatawiki
#
#       site_name  closed
# 0     Wikipedia   False
# 5     Wikipedia   False
# 7     Wikipedia   False
# 11    Wikipedia   False
# 18    Wikipedia   False
# ...         ...     ...
# 922   Wikipedia   False
# 926   Wikipedia   False
# 929   Wikipedia   False
# 937   Wikipedia   False
# 1045  Wikipedia   False
#
# [185 rows x 7 columns]>

# %%
len(df_lang_wikipedia )
# Out:
# 185

# %%
if not WikidataInclude:
    df_lang_wikipedia = df_lang_wikipedia[df_lang_wikipedia["lang_code"] != "special"]

len(df_lang_wikipedia )
# Out:
# 184

# %%
# -------------------------
# Session & helpers
# -------------------------
session = requests.Session()
session.headers.update({"User-Agent": "SCB-LinkAudit/1.0 salgo60@msn.com"})


print("Antal Språk:",len(df_lang_wikipedia ))
print("Wikidata included" if WikidataInclude else "Not Wikidata")


results = []
for _, row in df_lang_wikipedia.iterrows():
    lang = row["lang_code"]
    url  = row["url"]
    lang_name = row["lang_name"]
    before = len(results)
    #print(lang, url, lang_name,domains)
    for entry in fetch_exturlusage(lang, domains):
        results.append(entry)     
    after = len(results) 
    links = after-before
    print(lang, url, lang_name," - ", links)
# Out:
# Antal Språk: 184
# Not Wikidata
# aa https://aa.wikipedia.org Qafár af  -  0
# ace https://ace.wikipedia.org Acèh  -  0
# af https://af.wikipedia.org Afrikaans  -  9
# ak https://ak.wikipedia.org None  -  0
# ami https://ami.wikipedia.org Pangcah  -  0
# an https://an.wikipedia.org aragonés  -  0
# ast https://ast.wikipedia.org asturianu  -  2
# av https://av.wikipedia.org авар  -  0
# avk https://avk.wikipedia.org Kotava  -  0
# ay https://ay.wikipedia.org Aymar aru  -  0
# bar https://bar.wikipedia.org Boarisch  -  0
# bbc https://bbc.wikipedia.org Batak Toba  -  0
# bcl https://bcl.wikipedia.org Bikol Central  -  3
# bi https://bi.wikipedia.org Bislama  -  0
# bm https://bm.wikipedia.org bamanankan  -  0
# bo https://bo.wikipedia.org བོད་ཡིག  -  0
# br https://br.wikipedia.org brezhoneg  -  0
# bs https://bs.wikipedia.org bosanski  -  6
# btm https://btm.wikipedia.org Batak Mandailing  -  0
# bug https://bug.wikipedia.org Basa Ugi  -  0
# bxr https://bxr.wikipedia.org буряад  -  0
# cbk-zam https://cbk-zam.wikipedia.org Chavacano de Zamboanga  -  0
# cdo https://cdo.wikipedia.org 閩東語 / Mìng-dĕ̤ng-ngṳ̄  -  0
# ceb https://ceb.wikipedia.org Cebuano  -  0
# ch https://ch.wikipedia.org Chamoru  -  0
# cho https://cho.wikipedia.org Chahta anumpa  -  0
# chr https://chr.wikipedia.org ᏣᎳᎩ  -  0
# co https://co.wikipedia.org corsu  -  0
# cr https://cr.wikipedia.org Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ  -  0
# csb https://csb.wikipedia.org kaszëbsczi  -  1
# da https://da.wikipedia.org dansk  -  111
# de https://de.wikipedia.org Deutsch  -  473
# din https://din.wikipedia.org Thuɔŋjäŋ  -  0
# diq https://diq.wikipedia.org Zazaki  -  0
# dtp https://dtp.wikipedia.org Kadazandusun  -  0
# dz https://dz.wikipedia.org ཇོང་ཁ  -  0
# ee https://ee.wikipedia.org eʋegbe  -  0
# eml https://eml.wikipedia.org emiliàn e rumagnòl  -  0
# en https://en.wikipedia.org English  -  2598
# es https://es.wikipedia.org español  -  142
# eu https://eu.wikipedia.org euskara  -  6
# fat https://fat.wikipedia.org mfantse  -  0
# szl https://szl.wikipedia.org ślůnski  -  0
# tet https://tet.wikipedia.org tetun  -  0
# tl https://tl.wikipedia.org Tagalog  -  0
# tn https://tn.wikipedia.org Setswana  -  0
# to https://to.wikipedia.org lea faka-Tonga  -  0
# tpi https://tpi.wikipedia.org Tok Pisin  -  2
# ts https://ts.wikipedia.org Xitsonga  -  0
# tt https://tt.wikipedia.org татарча / tatarça  -  6
# tum https://tum.wikipedia.org chiTumbuka  -  0
# tw https://tw.wikipedia.org Twi  -  1
# ty https://ty.wikipedia.org reo tahiti  -  0
# ug https://ug.wikipedia.org ئۇيغۇرچە / Uyghurche  -  0
# ve https://ve.wikipedia.org Tshivenda  -  0
# vec https://vec.wikipedia.org vèneto  -  0
# vi https://vi.wikipedia.org Tiếng Việt  -  59
# vls https://vls.wikipedia.org West-Vlams  -  0
# vro https://fiu-vro.wikipedia.org võro  -  0
# wa https://wa.wikipedia.org walon  -  0
# war https://war.wikipedia.org Winaray  -  0
# wo https://wo.wikipedia.org Wolof  -  0
# xal https://xal.wikipedia.org хальмг  -  0
# xh https://xh.wikipedia.org isiXhosa  -  0
# yo https://yo.wikipedia.org Yorùbá  -  0
# za https://za.wikipedia.org Vahcuengh  -  0
# zea https://zea.wikipedia.org Zeêuws  -  0
# zh https://zh.wikipedia.org 中文  -  61
# zu https://zu.wikipedia.org isiZulu  -  0

# %%
df_riksdagen = pd.DataFrame(results)
df_riksdagen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23959 entries, 0 to 23958
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        23959 non-null  object
#  1   page_title  23959 non-null  object
#  2   url         23959 non-null  object
#  3   wiki_link   23959 non-null  object
# dtypes: object(4)
# memory usage: 748.8+ KB

# %%
import pandas as pd

# --- Stats ---
total_links = len(df_riksdagen)
total_unique_links = df_riksdagen['url'].nunique()
num_languages = df_riksdagen['lang'].nunique()
langs_sorted = df_riksdagen['lang'].value_counts()

print("Total links:", total_links)
print("Total unique links:", total_unique_links)
print("Number of languages:", num_languages)
print("Wikidata included" if WikidataInclude else "Not Wikidata")
print("\nLanguages with most links:")
print(langs_sorted.to_string())
# Out:
# Total links: 23959
# Total unique links: 14524
# Number of languages: 44
# Not Wikidata
#
# Languages with most links:
# lang
# sv        18743
# en         2598
# no          677
# de          473
# pl          324
# fi          289
# es          142
# da          111
# id          101
# ro           85
# it           79
# zh           61
# vi           59
# ja           34
# nl           22
# ms           20
# simple       18
# sq           16
# nn           14
# gl           12
# sco           9
# af            9
# ha            9
# fo            9
# eu            6
# bs            6
# tt            6
# bcl           3
# ig            3
# gv            3
# tpi           2
# sw            2
# ast           2
# se            2
# lld           1
# smn           1
# csb           1
# su            1
# is            1
# knc           1
# lb            1
# tw            1
# min           1
# lij           1

# %%
# --- Stats ---
total_links = len(df_riksdagen)
total_unique_links = df_riksdagen["url"].nunique()
langs_with_hits = sorted(df_riksdagen["lang"].unique())

num_languages_found = len(langs_with_hits)
num_languages_checked = len(df_lang_wikipedia)        # alla språk som genomsöktes
num_languages_found = df_riksdagen['lang'].nunique()

# %%
num_languages_checked
# Out:
# 184

# %% [markdown]
# ### Check url

# %%
import requests
from requests.exceptions import RequestException
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import pandas as pd
import time
import threading

# ==========================
# Konfiguration
# ==========================

MAX_WORKERS = 12
REQUEST_TIMEOUT = 15
CHECKPOINT_EVERY = 1000

ROOT_CANONICAL = "https://www.riksdagen.se"

SOFT_404_PHRASES = [
    "sidan kan inte hittas",
    "sidan tagits bort",
    "felaktig adress",
    "kontakta registrator",
    "sidan finns inte på riksdagen.se",
    "sidan finns inte",
    "den här sidan kan inte visas",
]

USER_AGENT = "LinkChecker/1.0 (research; salgo60@msn.com)"

# ==========================
# Session (thread-safe)
# ==========================

thread_local = threading.local()

def get_session():
    if not hasattr(thread_local, "session"):
        s = requests.Session()
        s.headers.update({"User-Agent": USER_AGENT})
        thread_local.session = s
    return thread_local.session


# ==========================
# Hjälpfunktioner
# ==========================

def norm(u: str) -> str:
    return u.rstrip("/").lower()


def looks_like_soft_404(response) -> bool:
    text = (response.text or "").lower()

    for phrase in SOFT_404_PHRASES:
        if phrase in text:
            return True

    if "<title>" in text:
        title = text.split("<title>", 1)[1].split("</title>", 1)[0]
        if "404" in title.lower():
            return True
        if "sidan finns inte" in title.lower():
            return True

    return False


def is_worth_checking(url: str) -> bool:
    if not url.startswith("http"):
        return False
    if "riksdagen.se" not in url:
        return False
    return True


# ==========================
# URL-check
# ==========================

def check_url(url: str) -> dict:
    session = get_session()

    try:
        # 1. HEAD först
        r = session.head(
            url,
            allow_redirects=True,
            timeout=REQUEST_TIMEOUT,
        )
    except RequestException as e:
        return {
            "url": url,
            "status": "error",
            "reason": str(e),
        }

    final_url = r.url
    status_code = r.status_code

    # Hard error
    if status_code >= 400:
        return {
            "url": url,
            "status": "dead",
            "reason": f"HTTP {status_code}",
            "final_url": final_url,
        }

    # Redirect till root
    if norm(final_url) == norm(ROOT_CANONICAL) and norm(url) != norm(final_url):
        return {
            "url": url,
            "status": "dead",
            "reason": "redirect_to_root",
            "final_url": final_url,
        }

    # 2. GET endast vid behov
    try:
        r = session.get(
            final_url,
            allow_redirects=True,
            timeout=REQUEST_TIMEOUT,
        )
    except RequestException as e:
        return {
            "url": url,
            "status": "error",
            "reason": str(e),
            "final_url": final_url,
        }

    if looks_like_soft_404(r):
        return {
            "url": url,
            "status": "dead",
            "reason": "soft_404",
            "final_url": final_url,
        }

    return {
        "url": url,
        "status": "ok",
        "final_url": final_url,
    }


# ==========================
# Internet Archive
# ==========================

def check_internet_archive(url: str) -> str | None:
    session = get_session()
    api = "https://archive.org/wayback/available"

    try:
        r = session.get(
            api,
            params={"url": url},
            timeout=10,
        )
        data = r.json()
    except Exception:
        return None

    snap = data.get("archived_snapshots", {}).get("closest")
    if snap and snap.get("available"):
        return snap.get("url")

    return None


# ==========================
# Worker
# ==========================

def process_url(url: str) -> dict:
    result = check_url(url)

    if result["status"] == "dead":
        ia_url = check_internet_archive(url)
        result["ia_url"] = ia_url
        result["ia_status"] = "available" if ia_url else "missing"
    else:
        result["ia_url"] = None
        result["ia_status"] = "skipped"

    return result


# ==========================
# Main
# ==========================

def run(df_riksdagen: pd.DataFrame) -> pd.DataFrame:
    urls = [
        u for u in df_riksdagen["url"].dropna().astype(str).unique()
        if is_worth_checking(u)
    ]

    results = []
    start = time.time()

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = {executor.submit(process_url, u): u for u in urls}

        for i, future in enumerate(
            tqdm(as_completed(futures), total=len(futures), unit="link"),
            start=1
        ):
            result = future.result()
            results.append(result)

            if i % CHECKPOINT_EVERY == 0:
                pd.DataFrame(results).to_parquet("checkpoint_links.parquet")

    df = pd.DataFrame(results)
    df.to_parquet("riksdagen_links_checked.parquet")

    elapsed = time.time() - start
    print(f"Klar på {elapsed/3600:.1f} timmar")

    return df

# %%
df_result = run(df_riksdagen)
# Out:
#  73%|█████████████████████████▌         | 10629/14524 [47:57<33:49,  1.92link/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 100%|█████████████████████████████████| 14524/14524 [1:09:20<00:00,  3.49link/s]
# Klar på 1.2 timmar

# %%
df_riksdagen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23959 entries, 0 to 23958
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        23959 non-null  object
#  1   page_title  23959 non-null  object
#  2   url         23959 non-null  object
#  3   wiki_link   23959 non-null  object
#  4   status      23959 non-null  object
#  5   final_url   23894 non-null  object
#  6   ia_url      1109 non-null   object
#  7   ia_status   23959 non-null  object
#  8   reason      3855 non-null   object
# dtypes: object(9)
# memory usage: 1.6+ MB

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14524 entries, 0 to 14523
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        14524 non-null  object
#  1   status     14524 non-null  object
#  2   final_url  14472 non-null  object
#  3   ia_url     605 non-null    object
#  4   ia_status  14524 non-null  object
#  5   reason     2586 non-null   object
# dtypes: object(6)
# memory usage: 680.9+ KB

# %%
df_result[
    (df_result["status"] == "dead") &
    (df_result["ia_status"] != "available")
].shape[0]
# Out:
# 1928

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14524 entries, 0 to 14523
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        14524 non-null  object
#  1   status     14524 non-null  object
#  2   final_url  14472 non-null  object
#  3   ia_url     605 non-null    object
#  4   ia_status  14524 non-null  object
#  5   reason     2586 non-null   object
# dtypes: object(6)
# memory usage: 680.9+ KB

# %%
results[:3]
# Out:
# [{'lang': 'af',
#   'page_title': 'Sweedse kroon',
#   'url': 'http://www.riksdagen.se/Webbnav/index.aspx?nid=7160&datum=3/25/2009',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Sweedse_kroon'},
#  {'lang': 'af',
#   'page_title': 'Gebruiker:Napakaira/Sandput',
#   'url': 'http://www.riksdagen.se/templates/R_Page____10320.aspx',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Gebruiker:Napakaira/Sandput'},
#  {'lang': 'af',
#   'page_title': 'Meänkieli',
#   'url': 'http://www.riksdagen.se/templates/R_Page____10320.aspx',
#   'wiki_link': 'https://af.wikipedia.org/wiki/Meänkieli'}]

# %%
#df_results = pd.DataFrame(results)  
df_riksdagen = df_riksdagen.merge(
    df_result,
    on="url",
    how="left",
)

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14524 entries, 0 to 14523
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        14524 non-null  object
#  1   status     14524 non-null  object
#  2   final_url  14472 non-null  object
#  3   ia_url     605 non-null    object
#  4   ia_status  14524 non-null  object
#  5   reason     2586 non-null   object
# dtypes: object(6)
# memory usage: 680.9+ KB

# %%
df_riksdagen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23959 entries, 0 to 23958
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lang        23959 non-null  object
#  1   page_title  23959 non-null  object
#  2   url         23959 non-null  object
#  3   wiki_link   23959 non-null  object
#  4   status      23959 non-null  object
#  5   final_url   23894 non-null  object
#  6   ia_url      1109 non-null   object
#  7   ia_status   23959 non-null  object
#  8   reason      3855 non-null   object
# dtypes: object(9)
# memory usage: 1.6+ MB

# %%
status_counts = df_riksdagen["status"].value_counts()

num_ok = status_counts.get("ok", 0)
num_dead = status_counts.get("dead", 0)
num_error = status_counts.get("error", 0)
num_total = len(status_counts)
print( "Ok ",num_ok) 
print( "Dead ",num_dead)
print( "Error ",num_error ) 
print( "Total ",num_total )
# Out:
# Ok  20104
# Dead  3789
# Error  66
# Total  3

# %%
df_riksdagen["reason"].value_counts()
# Out:
# reason
# HTTP 404                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3779
# HTTPSConnectionPool(host='www.riksdagen.se', port=443): Read timed out. (read timeout=15)                                                                                                                                                                                                                                                                                                                                                                                                                                            20
# soft_404                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              6
# HTTP 502                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              3
# HTTPConnectionPool(host='www.samhallsguiden.riksdagen.se', port=80): Max retries exceeded with url: /templates/R_Page____774.aspx (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x14c8ba240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                           3
# HTTPConnectionPool(host='www.samhallsguiden.riksdagen.se', port=80): Max retries exceeded with url: /templates/R_Page____10934.aspx (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x120f9cdd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                         3
# HTTPConnectionPool(host='rixlex.riksdagen.se', port=80): Max retries exceeded with url: /webbnav/index.aspx?nid=3911&bet=1810:0926 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31690fc50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                          3
# HTTPSConnectionPool(host='utveckling.riksdagen.se', port=443): Max retries exceeded with url: /2011/samlade-synpunkter-och-kommentarer-fran-beta-riksdagen-se/ (Caused by SSLError(CertificateError("hostname 'utveckling.riksdagen.se' doesn't match either of 'www.riksdagen.se', 'firademokratin.riksdagen.se', 'parleu2023.riksdagen.se', 'riksdagen.se', 'beta.riksdagen.se', 'eu.riksdagen.se', 'data.riksdagen.se'")))                                                                                                         2
# HTTPConnectionPool(host='beta.riksdagen.se', port=80): Max retries exceeded with url: /sv/Dokument-Lagar/Forslag/Motioner/Vag-181-mellan-Falkoping-och-Vargarda_GN02T372/?text=true (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x317463a40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                         2
# HTTPConnectionPool(host='beta.riksdagen.se', port=80): Max retries exceeded with url: /sv/Dokument-Lagar/Forslag/Motioner/Forbud-mot-rasistiska-organisa_GR02K298/?text=true (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31b6f8290>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                2
# HTTPConnectionPool(host='beta.riksdagen.se', port=80): Max retries exceeded with url: /PageFiles/67146/Prst5556del1.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x120eaaba0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                                     1
# HTTPConnectionPool(host='rundvandring.riksdagen.se', port=80): Max retries exceeded with url: /en/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x14f570c20>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                                                          1
# HTTP 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# HTTPConnectionPool(host='rixlex.riksdagen.se', port=80): Max retries exceeded with url: /htbin/thw?$%7BHTML%7D=SFST_LST&$%7BOOHTML%7D=SFST_DOK&$%7BSNHTML%7D=SFST_ERR&$%7BMAXPAGE%7D=26&$%7BTRIPSHOW%7D=format%3DTHW&$%7BBASE%7D=SFST&$%7BFREETEXT%7D=&BET=&RUB=namnlag&ORG= (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x126c203b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                1
# HTTPConnectionPool(host='rixlex.riksdagen.se', port=80): Max retries exceeded with url:
Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x14c8175c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                                                                                                             1
# HTTPConnectionPool(host='rixlex.riksdagen.se', port=80): Max retries exceeded with url: /htbin/thw?$%7BHTML%7D=MOT_LST&$%7BOOHTML%7D=MOT_DOK&$%7BSNHTML%7D=MOT_ERR&$%7BMAXPAGE%7D=26&$%7BTRIPSHOW%7D=format%3Dthw&$%7BCCL%7D=define+reverse&$%7BBASE%7D=MOTARKIV0102&$%7BFREETEXT%7D=2001/02:K297&MRUB=&USK=&NR=&PARTI=&MSLUT=&MSLUT= (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x14f370f80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))       1
# HTTPConnectionPool(host='rixlex.riksdagen.se', port=80): Max retries exceeded with url: /htbin/thw?$%7BOOHTML%7D=SFST_DOK&$%7BSNHTML%7D=SFSR_ERR&$%7BBASE%7D=SFST&BET=2000:832&$%7BTRIPSHOW%7D=format%3DTHW (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x3abe386b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))                                                                                                                                 1
# Name: count, dtype: int64

# %%
from datetime import date
import os

# Sätt datum
today = date.today().strftime("%Y_%m_%d")

# Se till att katalogen finns
os.makedirs("resultsRiksdagen", exist_ok=True)

# Bygg filnamn
if WikidataInclude:
    outfile = f"resultsRiksdagen/links_Riksdagen_v1_Wikidata_{today}.csv"
else:
    outfile = f"resultsRiksdagen/links_Riksdagen_v1_{today}.csv"
    
# Exportera
df_riksdagen.to_csv(outfile, index=False, encoding="utf-8")

print(f"[OK] Exported {len(df_riksdagen)} rows to {outfile}")
# Out:
# [OK] Exported 23959 rows to resultsRiksdagen/links_Riksdagen_v1_2026_01_17.csv

# %%
lang_stats = (
    df_riksdagen
    .groupby("lang")
    .agg(
        total_links=("url", "count"),
        broken_links=("status", lambda s: (s == "dead").sum()),
        archived_links=("ia_status", lambda s: (s == "available").sum()),
    )
    .reset_index()
)

lang_stats["broken_pct"] = (
    100 * lang_stats["broken_links"] / lang_stats["total_links"]
).round(1)

lang_stats["broken_lost"] = (
    lang_stats["broken_links"] - lang_stats["archived_links"])

top10_langs = (
    lang_stats
    .sort_values("total_links", ascending=False)
    .head(10)
)
top10_langs[
    [
        "lang",
        "total_links",
        "broken_links",
        "broken_pct",
        "archived_links",
        "broken_lost",
    ]
]
# Out:
#    lang  total_links  broken_links  broken_pct  archived_links  broken_lost
# 37   sv        18743          2082        11.1             533         1549
# 7    en         2598          1003        38.6             247          756
# 28   no          677           143        21.1              75           68
# 6    de          473            96        20.3              60           36
# 29   pl          324            21         6.5              16            5
# 10   fi          289            64        22.1              38           26
# 8    es          142            78        54.9              25           53
# 5    da          111            32        28.8              30            2
# 15   id          101            73        72.3              14           59
# 30   ro           85            19        22.4               5           14

# %%
from urllib.parse import urlparse

df = df_riksdagen.copy()

df["domain"] = df["url"].apply(
    lambda u: urlparse(u).netloc.lower() if pd.notna(u) else None
)
domain_stats = (
    df
    .groupby("domain")
    .agg(
        total_links=("url", "count"),
        broken_links=("status", lambda s: (s == "dead").sum()),
        error_links=("status", lambda s: (s == "error").sum()),
    )
    .reset_index()
)
domain_stats["broken_pct"] = (
    100 * domain_stats["broken_links"] / domain_stats["total_links"]
).round(1)

domain_stats["error_pct"] = (
    100 * domain_stats["error_links"] / domain_stats["total_links"]
).round(1)

# %%
domain_stats
# Out:
#                              domain  total_links  broken_links  error_links  \
# 0                 beta.riksdagen.se            5             0            5
# 1                 data.riksdagen.se         4916            91            0
# 2                   eu.riksdagen.se           18             0            0
# 3       firademokratin.riksdagen.se            7             1            0
# 4                      riksdagen.se          652           134            1
# 5               rixlex.riksdagen.se           29             0           29
# 6         rundvandring.riksdagen.se            1             0            1
# 7       samhallsguiden.riksdagen.se            1             0            1
# 8             storning.riksdagen.se            1             0            0
# 9           utveckling.riksdagen.se            3             0            3
# 10                 www.riksdagen.se        18318          3562           19
# 11              www.riksdagen.se:80            1             1            0
# 12  www.samhallsguiden.riksdagen.se            7             0            7
#
#     broken_pct  error_pct
# 0          0.0      100.0
# 1          1.9        0.0
# 2          0.0        0.0
# 3         14.3        0.0
# 4         20.6        0.2
# 5          0.0      100.0
# 6          0.0      100.0
# 7          0.0      100.0
# 8          0.0        0.0
# 9          0.0      100.0
# 10        19.4        0.1
# 11       100.0        0.0
# 12         0.0      100.0

# %%
status_counts = df["status"].value_counts()

num_ok = int(status_counts.get("ok", 0))
num_dead = int(status_counts.get("dead", 0))
num_error = int(status_counts.get("error", 0))
num_total = len(df)

pct_ok = round(100 * num_ok / num_total, 1)
pct_dead = round(100 * num_dead / num_total, 1)
pct_error = round(100 * num_error / num_total, 1)

# Broken links: archived vs lost
num_dead_archived = df[
    (df["status"] == "dead") & (df["ia_status"] == "available")
].shape[0]

num_dead_lost = num_dead - num_dead_archived

# %%
top_domains = (
    domain_stats[domain_stats["total_links"] >= 5]
    .sort_values("total_links", ascending=False)
    .head(10)
)
domain_stats_html = "<ul>"
for _, r in top_domains.iterrows():
    domain_stats_html += (
        f"<li><strong>{r['domain']}</strong>: "
        f"{r['broken_links']} / {r['total_links']} broken "
        f"({r['broken_pct']}%)</li>"
    )
domain_stats_html += "</ul>"

# %%
from pathlib import Path
from datetime import date, datetime
from urllib.parse import quote
import pandas as pd


def save_sortable_html_df_riksdagen(
    df,
    out_dir="resultsRiksdagen",
    domains=None,
    issue_url="https://github.com/salgo60/SCB-Wikidata/issues/60",
):
    out_dir = Path(out_dir)
    out_dir.mkdir(exist_ok=True)

    today = date.today().strftime("%Y_%m_%d")
    
    out_path = out_dir / f"links_riksdagen_v1_{today}.html"
    rerun_ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

     # --- Förbered data ---
    df = df.copy()  
    status_counts = df["status"].value_counts()

    num_ok = int(status_counts.get("ok", 0))
    num_dead = int(status_counts.get("dead", 0))
    num_error = int(status_counts.get("error", 0))
    num_total = len(df)
    
    pct_ok = round(100 * num_ok / num_total, 1)
    pct_dead = round(100 * num_dead / num_total, 1)
    pct_error = round(100 * num_error / num_total, 1)
    
    # Broken links: archived vs lost
    num_dead_archived = df[
        (df["status"] == "dead") & (df["ia_status"] == "available")
    ].shape[0]
    
    num_dead_lost = num_dead - num_dead_archived

    domains = domains or []
    from urllib.parse import urlparse
    
    df["domain"] = df["url"].apply(
        lambda u: urlparse(u).netloc.lower() if pd.notna(u) else None
    )

    domain_stats = (
        df
        .groupby("domain")
        .agg(
            total_links=("url", "count"),
            broken_links=("status", lambda s: (s == "dead").sum()),
            error_links=("status", lambda s: (s == "error").sum()),
        )
        .reset_index()
    )
    
    domain_stats["broken_pct"] = (
        100 * domain_stats["broken_links"] / domain_stats["total_links"]
    ).round(1)
    
    domain_stats["error_pct"] = (
        100 * domain_stats["error_links"] / domain_stats["total_links"]
    ).round(1)
    
    domain_stats["problem_pct"] = (
        100 * (domain_stats["broken_links"] + domain_stats["error_links"])
        / domain_stats["total_links"]
    ).round(1)
    

    domain_stats_html = "<ul>"
    for _, r in top_domains.iterrows():
        domain_stats_html += (
            f"<li><strong>{r['domain']}</strong>: "
            f"{r['broken_links']} / {r['total_links']} broken "
            f"({r['broken_pct']}%)</li>"
        )
    domain_stats_html += "</ul>"

    domain_table_html = (
        domain_stats
        .head(20)
        .to_html(
            classes="pivot",
            border=0,
            index=False,
        )
    )
    lang_stats = (
    df
        .groupby("lang")
        .agg(
            total_links=("url", "count"),
            broken_links=("status", lambda s: (s == "dead").sum()),
            error_links=("status", lambda s: (s == "error").sum()),
            broken_archived=("ia_status", lambda s: (s == "available").sum()),
        )
        .reset_index()
    )
    
    lang_stats["broken_lost"] = (
        lang_stats["broken_links"] - lang_stats["broken_archived"]
    )
    
    lang_stats["broken_pct"] = (
        100 * lang_stats["broken_links"] / lang_stats["total_links"]
    ).round(1)
    
    lang_stats["problem_pct"] = (
        100 * (lang_stats["broken_links"] + lang_stats["error_links"])
        / lang_stats["total_links"]
    ).round(1)

    lang_stats = lang_stats.sort_values(
        "broken_links",
        ascending=False
    )
 
    lang_stats_display = lang_stats[
        [
            "lang",
            "total_links",
            "broken_links",
            "broken_archived",
            "broken_lost",
            "broken_pct",
            "problem_pct",
        ]
    ]

    lang_table_html = (
        lang_stats_display
        .head(15)
        .to_html(
            classes="pivot",
            border=0,
            index=False,
        )
    )

    STATUS_ICON = {
        "ok":    ("fa-circle-check", "#2e7d32", "OK"),
        "dead":  ("fa-circle-xmark", "#c62828", "Broken link"),
        "error": ("fa-triangle-exclamation", "#ef6c00", "Request error"),
    }
    
    if "status" in df.columns:
        def render_status(r):
            icon, color, label = STATUS_ICON.get(
                r["status"], ("fa-question-circle", "#757575", "Unknown")
            )
            reason = r.get("reason", "")
            return (
                f'<span class="status-icon" '
                f'data-status="{r["status"]}" '
                f'title="{label}: {reason}" '
                f'style="color:{color}; font-size:14px; cursor:pointer;">'
                f'<i class="fa-solid {icon}"></i>'
                f'</span>'
            )
        df.insert(
            0,
            "status_icon",
            df.apply(render_status, axis=1)
        )

        def render_ia_icon(r):
            if r.get("ia_status") == "available" and r.get("ia_url"):
                return (
                    f'<a href="{r["ia_url"]}" target="_blank" '
                    f'title="Archived copy (Internet Archive)">'
                    f'<i class="fa-solid fa-box-archive" '
                    f'style="color:#1565c0;"></i>'
                    f'</a>'
                )
            return ""
        
        df.insert(
            1,
            "archive",
            df.apply(render_ia_icon, axis=1)
        )


    # Wikipedia: ikon + titel (byggd från lang + page_title)
    if {"lang", "page_title"}.issubset(df.columns):
        df["page_title"] = df.apply(
            lambda r: (
                f'<a href="https://{r["lang"]}.wikipedia.org/wiki/{quote(str(r["page_title"]))}" '
                f'target="_blank" title="Wikipedia ({r["lang"]})">'
                f'<i class="fa-brands fa-wikipedia-w" style="margin-right:6px;"></i>'
                f'{r["page_title"]}</a>'
                if pd.notna(r["lang"]) and pd.notna(r["page_title"])
                else r["page_title"]
            ),
            axis=1,
        )

    # Externa länkar
    for col in ["Wikipedia-länk", "Extern länk", "url"]:
        if col in df.columns:
            df[col] = df[col].apply(
                lambda x: f'<a href="{x}" target="_blank">{x}</a>' if pd.notna(x) else ""
            )

    # --- HTML-tabell ---
    html_table = df.to_html(
        classes="pivot",
        border=0,
        escape=False,  # krävs för HTML-länkar
        index=False,
    )

    # --- CSS ---
    css = """
    <style>
      body {
        font-family: Arial, sans-serif;
        margin: 20px;
      }
      table.pivot {
        border-collapse: collapse;
        width: 100%;
        font-size: 12px;
      }
      table.pivot th, table.pivot td {
        border: 1px solid #999;
        padding: 6px 8px;
        text-align: left;
        vertical-align: top;
        white-space: normal;
      }
      table.pivot th {
        cursor: pointer;
        background: #f2f2f2;
      }
      table.pivot th:hover {
        background: #e2e2e2;
      }
      table.pivot thead th {
        position: sticky;
        top: 0;
        background: #f2f2f2;
        z-index: 2;
      }
      table.pivot th::after {
        content: "";
        float: right;
        opacity: 0.4;
      }
      table.pivot th.sorted-asc::after {
        content: " ▲";
      }
      table.pivot th.sorted-desc::after {
        content: " ▼";
      }
      /* Row coloring by status */
      table.pivot tr[data-status="dead"] {
         background-color: #fdecea;  /* light red */
      }
      table.pivot tr[data-status="dead"] td:nth-child(2) i {
          color: #1565c0;
        }

      table.pivot tr[data-status="error"] {
          background-color: #fff4e5;  /* light orange */
      }

      table.pivot td a {
        color: #0645ad;
        text-decoration: none;
      }
      table.pivot td a:hover {
        text-decoration: underline;
      }
      .meta {
        background: #f8f8f8;
        border: 1px solid #ccc;
        padding: 12px;
        margin-bottom: 20px;
        font-size: 13px;
      }
      .meta h2 {
        margin-top: 0;
      }
    </style>
    """

    # --- JavaScript (sortering) ---
    js = """
    <script>
    document.addEventListener('DOMContentLoaded', () => {
        // Propagate status from first cell to row
        document.querySelectorAll("table.pivot tbody tr").forEach(row => {
            const statusCell = row.querySelector(".status-icon");
            if (statusCell) {
                row.dataset.status = statusCell.dataset.status;
            }
        });
        let showOnlyBroken = false;

        document.querySelectorAll(".status-icon").forEach(icon => {
            icon.addEventListener("click", event => {
                event.stopPropagation(); // prevent column sort
                showOnlyBroken = !showOnlyBroken;
        
                document.querySelectorAll("table.pivot tbody tr").forEach(row => {
                    if (showOnlyBroken) {
                        row.style.display =
                            row.dataset.status === "dead" ? "" : "none";
                    } else {
                        row.style.display = "";
                    }
                });
            });
        });

        document.querySelectorAll("table.pivot th").forEach((header, colIndex) => {
            header.addEventListener("click", () => {
                const table = header.closest("table");
                const tbody = table.querySelector("tbody");
                const rows = Array.from(tbody.querySelectorAll("tr"));
                const asc = !header.classList.contains("sorted-asc");

                rows.sort((a, b) => {
                    const A = a.children[colIndex].innerText.trim();
                    const B = b.children[colIndex].innerText.trim();
                    const numA = parseFloat(A.replace(",", "."));
                    const numB = parseFloat(B.replace(",", "."));
                    if (!isNaN(numA) && !isNaN(numB)) {
                        return asc ? numA - numB : numB - numA;
                    }
                    return asc ? A.localeCompare(B) : B.localeCompare(A);
                });

                table.querySelectorAll("th").forEach(th =>
                    th.classList.remove("sorted-asc", "sorted-desc")
                );
                header.classList.add(asc ? "sorted-asc" : "sorted-desc");
                rows.forEach(row => tbody.appendChild(row));
            });
        });
    });
    </script>
    """
    status_counts = df["status"].value_counts()
    
    num_ok = status_counts.get("ok", 0)
    num_dead = status_counts.get("dead", 0)
    num_error = status_counts.get("error", 0)
    num_total = len(df)

    # --- Metadata ---
    meta_html = f"""
    <div class="meta">
      <h2>Summary</h2>
    
      <p><strong>Rerun:</strong> {rerun_ts}</p>
      <p><strong>Script:</strong>
         <a href="{SCRIPT_URL}" target="_blank">{SCRIPT_NAME}</a>
      </p>
    
      <p>
        <strong>Links checked:</strong> {num_total}<br>
        <strong style="color:#2e7d32;">OK:</strong> {num_ok} ({pct_ok}%)<br>
        <strong style="color:#c62828;">Broken:</strong> {num_dead} ({pct_dead}%)<br>
        &nbsp;&nbsp;↳ Archived: {num_dead_archived}<br>
        &nbsp;&nbsp;↳ Lost: {num_dead_lost}<br>
        <strong style="color:#ef6c00;">Errors:</strong> {num_error} ({pct_error}%)
      </p>
      <p><strong>Issue:</strong>
         <a href="{issue_url}" target="_blank">{issue_url.split("/")[-1]}</a>
      </p>
    
      <p><strong>Datakällor:</strong><br>
         Wikidata<br>
         MediaWiki API – exturlusage
      </p>
    
      <h2>Domains with broken links</h2>
      <p>Top domains ranked by broken-link impact.</p>
      {domain_table_html}
    </div>
    """


    # --- Slutlig HTML ---
    html = f"""
    <html>
    <head>
      <meta charset="utf-8">
      <title>riksdagen.se links in Wikipedia</title>
      <link rel="stylesheet"
            href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.1/css/all.min.css">
      {css}
    </head>
    <body>
      <h1>Wikipedia → Riksdagen v1</h1>
      {meta_html}
      <p>Sorterbar tabell. Klicka på kolumnrubriker för sortering.</p>
      {html_table}
      {js}
      <h2>Broken-link summary by Wikipedia language</h2>
     <p>
       Languages ranked by broken-link impact (broken + error links).
     </p>
    {lang_table_html}
    </body>
    </html>
    """

    out_path.write_text(html, encoding="utf-8")
    print(f"✅ HTML skapad: {out_path}")

# %%
save_sortable_html_df_riksdagen(df_riksdagen)
# Out:
# ✅ HTML skapad: resultsRiksdagen/links_riksdagen_v1_2026_01_17.html

# %%
 # End timer and calculate duration
end_time = time.time()
elapsed_time = end_time - start_time# Bygg audit-lager för den här etappen

# Print current date and total time
print("Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
minutes, seconds = divmod(elapsed_time, 60)
print("Total time elapsed: {:02.0f} minutes {:05.2f} seconds".format(minutes, seconds))
# Out:
# Date: 2026-01-17 17:58:37
# Total time elapsed: 71 minutes 07.23 seconds
