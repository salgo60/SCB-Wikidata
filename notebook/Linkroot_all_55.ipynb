# %% [markdown]
# * #55
# * [#55](https://github.com/salgo60/SCB-Wikidata/issues/55)
# * Notebook [Linkroot_all_55.ipynb](http://localhost:8888/notebooks/SCB-Wikidata/notebook/Linkroot_all_55.ipynb)

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-01-10 15:43:38

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SCB-Wikidata/notebook

# %%
import time

from datetime import datetime

now = datetime.now()
timestamp = now.timestamp()

start_time = time.time()
print("Start:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start: 2026-01-10 15:42:01

# %%
SCRIPT_NAME = "Linkroot_all_55.ipynb"
SCRIPT_URL = (
    "https://github.com/salgo60/SCB-Wikidata/"
    "blob/master/notebook/Linkroot_all_55.ipynb"
)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/salgo/Documents/GitHub/SCB-Wikidata/notebook

# %%
import requests

def fetch_sitematrix_df():
    url = "https://meta.wikimedia.org/w/api.php"
    params = {
        "action": "sitematrix",
        "format": "json"
    }
    headers = {
        "User-Agent": "salgo60-language-fetcher/1.0 (salgo60@msn.com)"
    }

    print("[DEBUG] Fetching sitematrix…")
    r = requests.get(url, params=params, headers=headers)
    r.raise_for_status()

    if "application/json" not in r.headers.get("Content-Type", ""):
        raise ValueError("Server returned non-JSON response")

    data = r.json()["sitematrix"]

    rows = []

    # --- language-specific sites ---
    for key, lang_block in data.items():
        if not key.isdigit():
            continue  # skip "count", "specials"

        lang_code = lang_block.get("code")
        lang_name = lang_block.get("name")

        for site in lang_block.get("site", []):
            rows.append({
                "lang_code": lang_code,
                "lang_name": lang_name,
                "project": site.get("project"),
                "url": site.get("url"),
                "dbname": site.get("dbname"),
                "site_name": site.get("sitename"),
                "closed": site.get("closed", False)
            })

    # --- special wikis (Wikidata, Commons, Meta, etc.) ---
    for site in data.get("specials", []):
        rows.append({
            "lang_code": "special",
            "lang_name": "special",
            "project": site.get("project"),
            "url": site.get("url"),
            "dbname": site.get("dbname"),
            "site_name": site.get("sitename"),
            "closed": site.get("closed", False)
        })

    return pd.DataFrame(rows)

# %%
import requests
import pandas as pd


HEADERS = {
    "User-Agent": "salgo60-language-fetcher/2.0 (https://github.com/salgo60)"
}


df_lang_fetch = fetch_sitematrix_df()
df_lang_fetch["closed"] = df_lang_fetch["closed"].fillna(False).astype(bool)

df_lang_wikipedia = df_lang_filtered = df_lang_fetch[
    (df_lang_fetch["site_name"] == "Wikipedia") &
    (df_lang_fetch["lang_name"].str.lower() != "special")]

#df_lang_wikipedia.to_csv("test.csv")
df_lang_wikipedia.info()
# Out:
# [DEBUG] Fetching sitematrix…
# <class 'pandas.core.frame.DataFrame'>
# Index: 184 entries, 0 to 937
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lang_code  184 non-null    object
#  1   lang_name  183 non-null    object
#  2   project    0 non-null      object
#  3   url        184 non-null    object
#  4   dbname     184 non-null    object
#  5   site_name  184 non-null    object
#  6   closed     184 non-null    bool
# dtypes: bool(1), object(6)
# memory usage: 10.2+ KB

# %%
import requests
import pandas as pd
import re

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"

SPARQL = """
SELECT ?k ?kLabel ?web ?insLabel WHERE {
  VALUES ?ins { wd:Q16296141 wd:Q127448 wd:Q68295960 wd:Q107407151 }
  # ?k wdt:P31 ?ins .
  # ?k wdt:P17 wd:Q34 .
  OPTIONAL { ?k wdt:P856 ?web }
  MINUS { ?k wdt:P576 ?diss }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en,mul". }
}
ORDER BY ?kLabel
"""

def extract_se_domain(url):
    if not url:
        return None

    url = url.lower()

    # remove protocol
    url = re.sub(r"^https?://", "", url)

    # remove path, params, fragments
    url = url.split("/")[0]

    # remove www.
    url = re.sub(r"^www\.", "", url)

    # keep only xxxx.se
    m = re.search(r"([a-z0-9\-]+\.se)$", url)
    if m:
        return m.group(1)

    return None

# %%
def read_domains_from_wikidata():
    headers = {
        "Accept": "application/sparql-results+json",
        "User-Agent": "ESV-domain-audit/1.0 (https://github.com/salgo60)"
    }

    r = requests.get(
        WIKIDATA_ENDPOINT,
        params={"query": SPARQL, "format": "json"},
        headers=headers,
        timeout=60
    )

    if r.status_code != 200 or not r.text.strip().startswith("{"):
        raise RuntimeError("Wikidata did not return JSON:\n" + r.text[:300])

    data = r.json()

    rows = []
    for b in data["results"]["bindings"]:
        website = b.get("web", {}).get("value")

        rows.append({
            "wikidata": b["k"]["value"],
            "label": b["kLabel"]["value"],
            "type": b["insLabel"]["value"],
            "website": website,
            "domain_se": extract_se_domain(website)
        })

    df = pd.DataFrame(rows)

    # Remove rows without a usable .se domain
    df = df[df["domain_se"].notna()]

    # Deduplicate on domain
    df = df.drop_duplicates(subset="domain_se").sort_values("domain_se")

    return df

# %%
domains = read_domains_from_wikidata()
domains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505 entries, 565 to 559
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   wikidata   505 non-null    object
#  1   label      505 non-null    object
#  2   type       505 non-null    object
#  3   website    505 non-null    object
#  4   domain_se  505 non-null    object
# dtypes: object(5)
# memory usage: 23.7+ KB

# %%
session = requests.Session()
session.headers.update({
    "User-Agent": "SCB-LinkAudit/1.0 salgo60@msn.com)"
})

# %%
domains.head()
# Out:
#                                     wikidata               label  \
# 565  http://www.wikidata.org/entity/Q3406485  Åklagarmyndigheten
# 0     http://www.wikidata.org/entity/Q498470          Ale kommun
# 1     http://www.wikidata.org/entity/Q503162     Alingsås kommun
# 560   http://www.wikidata.org/entity/Q254799     Älmhults kommun
# 561   http://www.wikidata.org/entity/Q123855    Älvdalens kommun
#
#                          type                   website    domain_se
# 565  svensk statlig myndighet    http://www.aklagare.se  aklagare.se
# 0                      kommun         http://www.ale.se       ale.se
# 1                      kommun  https://www.alingsas.se/  alingsas.se
# 560                    kommun     http://www.almhult.se   almhult.se
# 561                    kommun    http://www.alvdalen.se  alvdalen.se

# %%
authority_domains = set(domains["domain_se"])

print("Antal myndighetsdomäner:", len(authority_domains))
# Out:
# Antal myndighetsdomäner: 505

# %%
authority_domains
# Out:
# {'aklagare.se',
#  'ale.se',
#  'alingsas.se',
#  'almhult.se',
#  'alvdalen.se',
#  'alvesta.se',
#  'alvkarleby.se',
#  'alvsbyn.se',
#  'amal.se',
#  'aneby.se',
#  'ange.se',
#  'angelholm.se',
#  'arbetsformedlingen.se',
#  'arbetsgivarverket.se',
#  'arboga.se',
#  'are.se',
#  'arjang.se',
#  'arjeplog.se',
#  'arkdes.se',
#  'arn.se',
#  'arvidsjaur.se',
#  'arvika.se',
#  'arvsfonden.se',
#  'asele.se',
#  'askersund.se',
#  'astorp.se',
#  'atvidaberg.se',
#  'av.se',
#  'avesta.se',
#  'barnombudsmannen.se',
#  'bastad.se',
#  'bengtsfors.se',
#  'berg.se',
#  'bfn.se',
#  'bjurholm.se',
#  'bjuv.se',
#  'boden.se',
#  'bolagsverket.se',
#  'bollebygd.se',
#  'bollnas.se',
#  'boras.se',
#  'borgholm.se',
#  'borlange.se',
#  'botkyrka.se',
#  'boverket.se',
#  'boxholm.se',
#  'bra.se',
#  'bracke.se',
#  'bromolla.se',
#  'brottsoffermyndigheten.se',
#  'bth.se',
#  'burlov.se',
#  'cdfn.se',
#  'csn.se',
#  'dalsed.se',
#  'danderyd.se',
#  'degerfors.se',
#  'digg.se',
#  'do.se',
#  'domstol.se',
#  'dorotea.se',
#  'du.se',
#  'eda.se',
#  'ehalsomyndigheten.se',
#  'ei.se',
#  'ekero.se',
#  'ekn.se',
#  'ekobrottsmyndigheten.se',
#  'eksjo.se',
#  'elsakerhetsverket.se',
#  'emmaboda.se',
#  'energimyndigheten.se',
#  'enkoping.se',
#  'epn.se',
#  'esf.se',
#  'eskilstuna.se',
#  'eslov.se',
#  'essunga.se',
#  'etikprovning.se',
#  'fagersta.se',
#  'falkenberg.se',
#  'falkoping.se',
#  'falun.se',
#  'fargelanda.se',
#  'fba.se',
#  'fhs.se',
#  'fi.se',
#  'filipstad.se',
#  'finspang.se',
#  'flen.se',
#  'fmi.se',
#  'fmv.se',
#  'foi.se',
#  'folkhalsomyndigheten.se',
#  'formas.se',
#  'forsakringskassan.se',
#  'forshaga.se',
#  'forskarskattenamnden.se',
#  'forsvarsmakten.se',
#  'forte.se',
#  'fortifikationsverket.se',
#  'fpr.se',
#  'fra.se',
#  'ftn.se',
#  'gagnef.se',
#  'gavle.se',
#  'gellivare.se',
#  'genteknik.se',
#  'gih.se',
#  'gislaved.se',
#  'gnesta.se',
#  'gnosjo.se',
#  'goteborg.se',
#  'gotene.se',
#  'gotland.se',
#  'government.se',
#  'grastorp.se',
#  'grums.se',
#  'gu.se',
#  'gullspang.se',
#  'habo.se',
#  'habokommun.se',
#  'hagfors.se',
#  'hallsberg.se',
#  'hallstahammar.se',
#  'halmstad.se',
#  'hammaro.se',
#  'han.se',
#  'haninge.se',
#  'haparanda.se',
#  'harnosand.se',
#  'harpsund.se',
#  'harryda.se',
#  'hassleholm.se',
#  'havochvatten.se',
#  'hb.se',
#  'heby.se',
#  'hedemora.se',
#  'hellefors.se',
#  'helsingborg.se',
#  'herjedalen.se',
#  'herrljunga.se',
#  'hh.se',
#  'hig.se',
#  'his.se',
#  'hjo.se',
#  'hkr.se',
#  'hofors.se',
#  'hoganas.se',
#  'hogsby.se',
#  'hoor.se',
#  'horby.se',
#  'hsan.se',
#  'huddinge.se',
#  'hudiksvall.se',
#  'hultsfred.se',
#  'hv.se',
#  'hylte.se',
#  'iaf.se',
#  'ifau.se',
#  'imy.se',
#  'inspsf.se',
#  'irf.se',
#  'isof.se',
#  'isp.se',
#  'ivo.se',
#  'jamstalldhetsmyndigheten.se',
#  'jarfalla.se',
#  'jk.se',
#  'jo.se',
#  'jokkmokk.se',
#  'jonkoping.se',
#  'jordbruksverket.se',
#  'kalix.se',
#  'kalmar.se',
#  'kammarkollegiet.se',
#  'karlsborg.se',
#  'karlshamn.se',
#  'karlskoga.se',
#  'karlskrona.se',
#  'karlstad.se',
#  'karnavfallsfonden.se',
#  'katrineholm.se',
#  'kau.se',
#  'kavlinge.se',
#  'kb.se',
#  'kemi.se',
#  'ki.se',
#  'kil.se',
#  'kinda.se',
#  'kiruna.se',
#  'kkh.se',
#  'klimatpolitiskaradet.se',
#  'klippan.se',
#  'kmh.se',
#  'knivsta.se',
#  'kommerskollegium.se',
#  'konj.se',
#  'konkurrensverket.se',
#  'konstfack.se',
#  'konstnarsnamnden.se',
#  'konsumentverket.se',
#  'koping.se',
#  'kramfors.se',
#  'kriminalvarden.se',
#  'kristianstad.se',
#  'kristinehamn.se',
#  'krokom.se',
#  'kronofogden.se',
#  'kth.se',
#  'kulturanalys.se',
#  'kulturradet.se',
#  'kumla.se',
#  'kungalv.se',
#  'kungsbacka.se',
#  'kungsor.se',
#  'kustbevakningen.se',
#  'lagradet.se',
#  'laholm.se',
#  'lakemedelsverket.se',
#  'landskrona.se',
#  'lansstyrelsen.se',
#  'lantmateriet.se',
#  'laxa.se',
#  'lekeberg.se',
#  'leksand.se',
#  'lerum.se',
#  'lessebo.se',
#  'levandehistoria.se',
#  'lfv.se',
#  'lidingo.se',
#  'lidkoping.se',
#  'lillaedet.se',
#  'lindesberg.se',
#  'linkoping.se',
#  'liu.se',
#  'livsmedelsverket.se',
#  'ljungby.se',
#  'ljusdal.se',
#  'ljusnarsberg.se',
#  'lnu.se',
#  'lomma.se',
#  'lotteriinspektionen.se',
#  'ltu.se',
#  'lu.se',
#  'ludvika.se',
#  'lulea.se',
#  'lund.se',
#  'lycksele.se',
#  'lysekil.se',
#  'mala.se',
#  'malmo.se',
#  'malung-salen.se',
#  'mariestad.se',
#  'mark.se',
#  'markaryd.se',
#  'mau.se',
#  'mcf.se',
#  'mdu.se',
#  'mediemyndigheten.se',
#  'mellerud.se',
#  'mfd.se',
#  'mfof.se',
#  'mi.se',
#  'migrationsverket.se',
#  'miun.se',
#  'mjolby.se',
#  'modernamuseet.se',
#  'molndal.se',
#  'monsteras.se',
#  'morakommun.se',
#  'morbylanga.se',
#  'motala.se',
#  'mpf.se',
#  'mrinstitutet.se',
#  'mtfa.se',
#  'mtm.se',
#  'mucf.se',
#  'mullsjo.se',
#  'munkedal.se',
#  'munkfors.se',
#  'musikverket.se',
#  'myh.se',
#  'mynak.se',
#  'myndighetensst.se',
#  'nacka.se',
#  'namndenmotdiskriminering.se',
#  'nassjo.se',
#  'nationalmuseum.se',
#  'naturvardsverket.se',
#  'nfh.se',
#  'nora.se',
#  'norberg.se',
#  'nordanstig.se',
#  'nordmaling.se',
#  'norrkoping.se',
#  'norrtalje.se',
#  'norsjo.se',
#  'nrm.se',
#  'nybro.se',
#  'nykoping.se',
#  'nykvarn.se',
#  'nynashamn.se',
#  'ockelbo.se',
#  'ockero.se',
#  'odeshog.se',
#  'oks.se',
#  'olofstrom.se',
#  'onh.se',
#  'orebro.se',
#  'oredlighetsprovning.se',
#  'orkelljunga.se',
#  'ornskoldsvik.se',
#  'orsa.se',
#  'oru.se',
#  'orust.se',
#  'osby.se',
#  'oskarshamn.se',
#  'osteraker.se',
#  'ostersund.se',
#  'osthammar.se',
#  'ostragoinge.se',
#  'ovanaker.se',
#  'overkalix.se',
#  'overklagandenamnden.se',
#  'overtornea.se',
#  'oxelosund.se',
#  'pajala.se',
#  'partille.se',
#  'pensionsmyndigheten.se',
#  'perstorp.se',
#  'pitea.se',
#  'polar.se',
#  'polisen.se',
#  'prv.se',
#  'pts.se',
#  'raa.se',
#  'ragunda.se',
#  'rattshjalp.se',
#  'rattvik.se',
#  'regeringen.se',
#  'rekryteringsmyndigheten.se',
#  'revisorsinspektionen.se',
#  'riksarkivet.se',
#  'riksbank.se',
#  'riksdagen.se',
#  'riksgalden.se',
#  'riksrevisionen.se',
#  'rmv.se',
#  'robertsfors.se',
#  'ronneby.se',
#  'rymdstyrelsen.se',
#  'saffle.se',
#  'sakerhetspolisen.se',
#  'sakint.se',
#  'sala.se',
#  'salem.se',
#  'sameskolstyrelsen.se',
#  'sametinget.se',
#  'sandviken.se',
#  'sater.se',
#  'savsjo.se',
#  'sbu.se',
#  'scb.se',
#  'sfv.se',
#  'sgu.se',
#  'sh.se',
#  'shk.se',
#  'shm.se',
#  'si.se',
#  'sida.se',
#  'sieps.se',
#  'sigtuna.se',
#  'simrishamn.se',
#  'siun.se',
#  'sjobo.se',
#  'sjofartsverket.se',
#  'skara.se',
#  'skatterattsnamnden.se',
#  'skatteverket.se',
#  'skelleftea.se',
#  'skinnskatteberg.se',
#  'skogsstyrelsen.se',
#  'skolfi.se',
#  'skolinspektionen.se',
#  'skolverket.se',
#  'skovde.se',
#  'skurup.se',
#  'slu.se',
#  'slv.se',
#  'smedjebacken.se',
#  'smhi.se',
#  'socialstyrelsen.se',
#  'soderhamn.se',
#  'soderkoping.se',
#  'sodertalje.se',
#  'solleftea.se',
#  'sollentuna.se',
#  'solna.se',
#  'solvesborg.se',
#  'sorsele.se',
#  'sotenas.se',
#  'sprakochfolkminnen.se',
#  'spsm.se',
#  'spv.se',
#  'staffanstorp.se',
#  'stat-inst.se',
#  'statensansvarsnamnd.se',
#  'statenskonstrad.se',
#  'statensmuseermtf.se',
#  'statenssc.se',
#  'statskontoret.se',
#  'stenungsund.se',
#  'stockholm.se',
#  'storfors.se',
#  'storuman.se',
#  'stralsakerhetsmyndigheten.se',
#  'strangnas.se',
#  'stromstad.se',
#  'stromsund.se',
#  'su.se',
#  'sundbyberg.se',
#  'sundsvall.se',
#  'sunne.se',
#  'surahammar.se',
#  'sva.se',
#  'svalov.se',
#  'svedala.se',
#  'svenljunga.se',
#  'svenskafaokommitten.se',
#  'svenskailo-kommitten.se',
#  'svff.se',
#  'svk.se',
#  'swedac.se',
#  'swedgeo.se',
#  'taby.se',
#  'tanum.se',
#  'tibro.se',
#  'tidaholm.se',
#  'tierp.se',
#  'tillvaxtanalys.se',
#  'tillvaxtverket.se',
#  'timra.se',
#  'tingsryd.se',
#  'tjorn.se',
#  'tlv.se',
#  'tomelilla.se',
#  'toreboda.se',
#  'torsas.se',
#  'torsby.se',
#  'trafa.se',
#  'trafikverket.se',
#  'tranas.se',
#  'tranemo.se',
#  'transportstyrelsen.se',
#  'trelleborg.se',
#  'trollhattan.se',
#  'trosa.se',
#  'tullverket.se',
#  'tyreso.se',
#  'ubm.se',
#  'uddevalla.se',
#  'uhr.se',
#  'uka.se',
#  'ulricehamn.se',
#  'umea.se',
#  'umu.se',
#  'uniarts.se',
#  'upphandlingsmyndigheten.se',
#  'upplands-bro.se',
#  'upplandsvasby.se',
#  'uppsala.se',
#  'uppvidinge.se',
#  'uu.se',
#  'vadstena.se',
#  'vaggeryd.se',
#  'val.se',
#  'valdemarsvik.se',
#  'vallentuna.se',
#  'vanersborg.se',
#  'vannas.se',
#  'vansbro.se',
#  'vara.se',
#  'varberg.se',
#  'vardanalys.se',
#  'vargarda.se',
#  'varldskulturmuseerna.se',
#  'varmdo.se',
#  'varnamo.se',
#  'vasteras.se',
#  'vastervik.se',
#  'vaxholm.se',
#  'vaxjo.se',
#  'vellinge.se',
#  'vetansvar.se',
#  'vetlanda.se',
#  'vilhelmina.se',
#  'vimmerby.se',
#  'vindeln.se',
#  'vingaker.se',
#  'vinnova.se',
#  'vr.se',
#  'vti.se',
#  'ydre.se',
#  'ystad.se'}

# %%
import time
import re
import requests

def normalize_url_domain(url):
    url = url.lower()
    url = re.sub(r"^https?://", "", url)
    url = url.split("/")[0]
    url = re.sub(r"^www\.", "", url)
    return url

def fetch_exturlusage(lang, authority_domains, sleep=0.5):
    api = f"https://{lang}.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "list": "exturlusage",
        "euquery": ".se",
        "eulimit": "500",
        "format": "json"
    }

    while True:
        try:
            r = session.get(api, params=params, timeout=30)

            # HTTP-level failure
            if r.status_code != 200:
                print(f"[{lang}] HTTP {r.status_code}")
                break

            # JSON missing → HTML or empty response
            if not r.text.strip().startswith("{"):
                print(f"[{lang}] Non-JSON response (rate limit or HTML)")
                break

            data = r.json()

        except Exception as e:
            print(f"[{lang}] API error: {e}")
            break

        for e in data.get("query", {}).get("exturlusage", []):
            raw_url = e["url"]
            domain = normalize_url_domain(raw_url)

            if domain in authority_domains:
                yield {
                    "lang": lang,
                    "pageid": e["pageid"],
                    "title": e["title"],
                    "url": raw_url,
                    "domain": domain
                }

        if "continue" not in data:
            break

        params.update(data["continue"])
        time.sleep(sleep)

# %%
print("Antal språk:", len(df_lang_wikipedia))

results = []

for i, row in df_lang_wikipedia.iterrows():
    lang = row["lang_code"]
    lang_name = row["lang_name"]

    print(f"[{i+1}/{len(df_lang_wikipedia)}] {lang} – {lang_name}")

    before = len(results)

    try:
        for entry in fetch_exturlusage(lang, authority_domains):
            results.append(entry)
    except Exception as e:
        print(f"  {lang} aborted: {e}")
        continue

    links = len(results) - before
    print(f"  {lang}: {links} myndighetslänkar",i,row)
# Out:
# Antal språk: 184
# [1/184] aa – Qafár af
#   aa: 0 myndighetslänkar 0 lang_code                          aa
# lang_name                    Qafár af
# project                          None
# url          https://aa.wikipedia.org
# dbname                         aawiki
# site_name                   Wikipedia
# closed                          False
# Name: 0, dtype: object
# [6/184] ace – Acèh
#   ace: 0 myndighetslänkar 5 lang_code                          ace
# lang_name                         Acèh
# project                           None
# url          https://ace.wikipedia.org
# dbname                         acewiki
# site_name                    Wikipedia
# closed                           False
# Name: 5, dtype: object
# [8/184] af – Afrikaans
#   af: 0 myndighetslänkar 7 lang_code                          af
# lang_name                   Afrikaans
# project                          None
# url          https://af.wikipedia.org
# dbname                         afwiki
# site_name                   Wikipedia
# closed                          False
# Name: 7, dtype: object
# [12/184] ak – None
#   ak: 0 myndighetslänkar 11 lang_code                          ak
# lang_name                        None
# project                          None
# url          https://ak.wikipedia.org
# dbname                         akwiki
# site_name                   Wikipedia
# closed                          False
# Name: 11, dtype: object
# [19/184] ami – Pangcah
#   ami: 0 myndighetslänkar 18 lang_code                          ami
# lang_name                      Pangcah
# project                           None
# url          https://ami.wikipedia.org
# dbname                         amiwiki
# site_name                    Wikipedia
# closed                           False
# Name: 18, dtype: object
# [20/184] an – aragonés
#   an: 0 myndighetslänkar 19 lang_code                          an
# lang_name                    aragonés
# project                          None
# url          https://an.wikipedia.org
# dbname                         anwiki
# site_name                   Wikipedia
# closed                          False
# Name: 19, dtype: object
# [44/184] ast – asturianu
#   ast: 0 myndighetslänkar 43 lang_code                          ast
# lang_name                    asturianu
# project                           None
# url          https://ast.wikipedia.org
# dbname                         astwiki
# site_name                    Wikipedia
# closed                           False
# Name: 43, dtype: object
# [49/184] av – авар
#   av: 0 myndighetslänkar 48 lang_code                          av
# lang_name                        авар
# project                          None
# url          https://av.wikipedia.org
# dbname                         avwiki
# site_name                   Wikipedia
# closed                          False
# Name: 48, dtype: object
# [51/184] avk – Kotava
#   avk: 0 myndighetslänkar 50 lang_code                          avk
# lang_name                       Kotava
# project                           None
# url          https://avk.wikipedia.org
# dbname                         avkwiki
# site_name                    Wikipedia
# closed                           False
# Name: 50, dtype: object
# [53/184] ay – Aymar aru
#   ay: 0 myndighetslänkar 52 lang_code                          ay
# lang_name                   Aymar aru
# project                          None
# url          https://ay.wikipedia.org
# dbname                         aywiki
# site_name                   Wikipedia
# closed                          False
# Name: 52, dtype: object
# [66/184] bar – Boarisch
#   bar: 0 myndighetslänkar 65 lang_code                          bar
# lang_name                     Boarisch
# project                           None
# url          https://bar.wikipedia.org
# dbname                         barwiki
# site_name                    Wikipedia
# closed                           False
# Name: 65, dtype: object
# [67/184] bbc – Batak Toba
#   bbc: 0 myndighetslänkar 66 lang_code                          bbc
# lang_name                   Batak Toba
# project                           None
# url          https://bbc.wikipedia.org
# dbname                         bbcwiki
# site_name                    Wikipedia
# closed                           False
# Name: 66, dtype: object
# [68/184] bcl – Bikol Central
#   bcl: 0 myndighetslänkar 67 lang_code                          bcl
# lang_name                Bikol Central
# project                           None
# url          https://bcl.wikipedia.org
# dbname                         bclwiki
# site_name                    Wikipedia
# closed                           False
# Name: 67, dtype: object
# [89/184] bi – Bislama
#   bi: 0 myndighetslänkar 88 lang_code                          bi
# lang_name                     Bislama
# project                          None
# url          https://bi.wikipedia.org
# dbname                         biwiki
# site_name                   Wikipedia
# closed                          False
# Name: 88, dtype: object
# [97/184] bm – bamanankan
#   bm: 0 myndighetslänkar 96 lang_code                          bm
# lang_name                  bamanankan
# project                          None
# url          https://bm.wikipedia.org
# dbname                         bmwiki
# site_name                   Wikipedia
# closed                          False
# Name: 96, dtype: object
# [107/184] bo – བོད་ཡིག
#   bo: 0 myndighetslänkar 106 lang_code                          bo
# lang_name                     བོད་ཡིག
# project                          None
# url          https://bo.wikipedia.org
# dbname                         bowiki
# site_name                   Wikipedia
# closed                          False
# Name: 106, dtype: object
# [111/184] br – brezhoneg
#   br: 0 myndighetslänkar 110 lang_code                          br
# lang_name                   brezhoneg
# project                          None
# url          https://br.wikipedia.org
# dbname                         brwiki
# site_name                   Wikipedia
# closed                          False
# Name: 110, dtype: object
# [115/184] bs – bosanski
#   bs: 0 myndighetslänkar 114 lang_code                          bs
# lang_name                    bosanski
# project                          None
# url          https://bs.wikipedia.org
# dbname                         bswiki
# site_name                   Wikipedia
# closed                          False
# Name: 114, dtype: object
# [121/184] btm – Batak Mandailing
#   btm: 0 myndighetslänkar 120 lang_code                          btm
# lang_name             Batak Mandailing
# project                           None
# url          https://btm.wikipedia.org
# dbname                         btmwiki
# site_name                    Wikipedia
# closed                           False
# Name: 120, dtype: object
# [123/184] bug – Basa Ugi
#   bug: 0 myndighetslänkar 122 lang_code                          bug
# lang_name                     Basa Ugi
# project                           None
# url          https://bug.wikipedia.org
# dbname                         bugwiki
# site_name                    Wikipedia
# closed                           False
# Name: 122, dtype: object
# [124/184] bxr – буряад
#   bxr: 0 myndighetslänkar 123 lang_code                          bxr
# lang_name                       буряад
# project                           None
# url          https://bxr.wikipedia.org
# dbname                         bxrwiki
# site_name                    Wikipedia
# closed                           False
# Name: 123, dtype: object
# [131/184] cbk-zam – Chavacano de Zamboanga
#   cbk-zam: 0 myndighetslänkar 130 lang_code                          cbk-zam
# lang_name           Chavacano de Zamboanga
# project                               None
# url          https://cbk-zam.wikipedia.org
# dbname                         cbk_zamwiki
# site_name                        Wikipedia
# closed                               False
# Name: 130, dtype: object
# [132/184] cdo – 閩東語 / Mìng-dĕ̤ng-ngṳ̄
#   cdo: 0 myndighetslänkar 131 lang_code                          cdo
# lang_name        閩東語 / Mìng-dĕ̤ng-ngṳ̄
# project                           None
# url          https://cdo.wikipedia.org
# dbname                         cdowiki
# site_name                    Wikipedia
# closed                           False
# Name: 131, dtype: object
# [134/184] ceb – Cebuano
#   ceb: 0 myndighetslänkar 133 lang_code                          ceb
# lang_name                      Cebuano
# project                           None
# url          https://ceb.wikipedia.org
# dbname                         cebwiki
# site_name                    Wikipedia
# closed                           False
# Name: 133, dtype: object
# [135/184] ch – Chamoru
#   ch: 0 myndighetslänkar 134 lang_code                          ch
# lang_name                     Chamoru
# project                          None
# url          https://ch.wikipedia.org
# dbname                         chwiki
# site_name                   Wikipedia
# closed                          False
# Name: 134, dtype: object
# [138/184] cho – Chahta anumpa
#   cho: 0 myndighetslänkar 137 lang_code                          cho
# lang_name                Chahta anumpa
# project                           None
# url          https://cho.wikipedia.org
# dbname                         chowiki
# site_name                    Wikipedia
# closed                           False
# Name: 137, dtype: object
# [139/184] chr – ᏣᎳᎩ
#   chr: 0 myndighetslänkar 138 lang_code                          chr
# lang_name                          ᏣᎳᎩ
# project                           None
# url          https://chr.wikipedia.org
# dbname                         chrwiki
# site_name                    Wikipedia
# closed                           False
# Name: 138, dtype: object
# [144/184] co – corsu
#   co: 0 myndighetslänkar 143 lang_code                          co
# lang_name                       corsu
# project                          None
# url          https://co.wikipedia.org
# dbname                         cowiki
# site_name                   Wikipedia
# closed                          False
# Name: 143, dtype: object
# [148/184] cr – Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ
#   cr: 0 myndighetslänkar 147 lang_code                          cr
# lang_name       Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ
# project                          None
# url          https://cr.wikipedia.org
# dbname                         crwiki
# site_name                   Wikipedia
# closed                          False
# Name: 147, dtype: object
# [160/184] csb – kaszëbsczi
#   csb: 0 myndighetslänkar 159 lang_code                          csb
# lang_name                   kaszëbsczi
# project                           None
# url          https://csb.wikipedia.org
# dbname                         csbwiki
# site_name                    Wikipedia
# closed                           False
# Name: 159, dtype: object
# [170/184] da – dansk
#   da: 0 myndighetslänkar 169 lang_code                          da
# lang_name                       dansk
# project                          None
# url          https://da.wikipedia.org
# dbname                         dawiki
# site_name                   Wikipedia
# closed                          False
# Name: 169, dtype: object
# [176/184] de – Deutsch
#   de: 0 myndighetslänkar 175 lang_code                          de
# lang_name                     Deutsch
# project                          None
# url          https://de.wikipedia.org
# dbname                         dewiki
# site_name                   Wikipedia
# closed                          False
# Name: 175, dtype: object
# [185/184] din – Thuɔŋjäŋ
#   din: 0 myndighetslänkar 184 lang_code                          din
# lang_name                     Thuɔŋjäŋ
# project                           None
# url          https://din.wikipedia.org
# dbname                         dinwiki
# site_name                    Wikipedia
# closed                           False
# Name: 184, dtype: object
# [186/184] diq – Zazaki
#   diq: 0 myndighetslänkar 185 lang_code                          diq
# lang_name                       Zazaki
# project                           None
# url          https://diq.wikipedia.org
# dbname                         diqwiki
# site_name                    Wikipedia
# closed                           False
# Name: 185, dtype: object
# [189/184] dtp – Kadazandusun
#   dtp: 0 myndighetslänkar 188 lang_code                          dtp
# lang_name                 Kadazandusun
# project                           None
# url          https://dtp.wikipedia.org
# dbname                         dtpwiki
# site_name                    Wikipedia
# closed                           False
# Name: 188, dtype: object
# [193/184] dz – ཇོང་ཁ
#   dz: 0 myndighetslänkar 192 lang_code                          dz
# lang_name                       ཇོང་ཁ
# project                          None
# url          https://dz.wikipedia.org
# dbname                         dzwiki
# site_name                   Wikipedia
# closed                          False
# Name: 192, dtype: object
# [195/184] ee – eʋegbe
#   ee: 0 myndighetslänkar 194 lang_code                          ee
# lang_name                      eʋegbe
# project                          None
# url          https://ee.wikipedia.org
# dbname                         eewiki
# site_name                   Wikipedia
# closed                          False
# Name: 194, dtype: object
# [204/184] eml – emiliàn e rumagnòl
#   eml: 0 myndighetslänkar 203 lang_code                          eml
# lang_name           emiliàn e rumagnòl
# project                           None
# url          https://eml.wikipedia.org
# dbname                         emlwiki
# site_name                    Wikipedia
# closed                           False
# Name: 203, dtype: object
# [205/184] en – English
#   en: 0 myndighetslänkar 204 lang_code                          en
# lang_name                     English
# project                          None
# url          https://en.wikipedia.org
# dbname                         enwiki
# site_name                   Wikipedia
# closed                          False
# Name: 204, dtype: object
# [220/184] es – español
#   es: 0 myndighetslänkar 219 lang_code                          es
# lang_name                     español
# project                          None
# url          https://es.wikipedia.org
# dbname                         eswiki
# site_name                   Wikipedia
# closed                          False
# Name: 219, dtype: object
# [233/184] eu – euskara
#   eu: 0 myndighetslänkar 232 lang_code                          eu
# lang_name                     euskara
# project                          None
# url          https://eu.wikipedia.org
# dbname                         euwiki
# site_name                   Wikipedia
# closed                          False
# Name: 232, dtype: object
# [246/184] fat – mfantse
#   fat: 0 myndighetslänkar 245 lang_code                          fat
# lang_name                      mfantse
# project                           None
# url          https://fat.wikipedia.org
# dbname                         fatwiki
# site_name                    Wikipedia
# closed                           False
# Name: 245, dtype: object
# [247/184] ff – Fulfulde
#   ff: 0 myndighetslänkar 246 lang_code                          ff
# lang_name                    Fulfulde
# project                          None
# url          https://ff.wikipedia.org
# dbname                         ffwiki
# site_name                   Wikipedia
# closed                          False
# Name: 246, dtype: object
# [248/184] fi – suomi
#   fi: 0 myndighetslänkar 247 lang_code                          fi
# lang_name                       suomi
# project                          None
# url          https://fi.wikipedia.org
# dbname                         fiwiki
# site_name                   Wikipedia
# closed                          False
# Name: 247, dtype: object
# [256/184] fj – Na Vosa Vakaviti
#   fj: 0 myndighetslänkar 255 lang_code                          fj
# lang_name            Na Vosa Vakaviti
# project                          None
# url          https://fj.wikipedia.org
# dbname                         fjwiki
# site_name                   Wikipedia
# closed                          False
# Name: 255, dtype: object
# [258/184] fo – føroyskt
#   fo: 0 myndighetslänkar 257 lang_code                          fo
# lang_name                    føroyskt
# project                          None
# url          https://fo.wikipedia.org
# dbname                         fowiki
# site_name                   Wikipedia
# closed                          False
# Name: 257, dtype: object
# [271/184] frr – Nordfriisk
#   frr: 0 myndighetslänkar 270 lang_code                          frr
# lang_name                   Nordfriisk
# project                           None
# url          https://frr.wikipedia.org
# dbname                         frrwiki
# site_name                    Wikipedia
# closed                           False
# Name: 270, dtype: object
# [285/184] gl – galego
#   gl: 0 myndighetslänkar 284 lang_code                          gl
# lang_name                      galego
# project                          None
# url          https://gl.wikipedia.org
# dbname                         glwiki
# site_name                   Wikipedia
# closed                          False
# Name: 284, dtype: object
# [290/184] glk – گیلکی
#   glk: 0 myndighetslänkar 289 lang_code                          glk
# lang_name                        گیلکی
# project                           None
# url          https://glk.wikipedia.org
# dbname                         glkwiki
# site_name                    Wikipedia
# closed                           False
# Name: 289, dtype: object
# [296/184] gor – Bahasa Hulontalo
#   gor: 0 myndighetslänkar 295 lang_code                          gor
# lang_name             Bahasa Hulontalo
# project                           None
# url          https://gor.wikipedia.org
# dbname                         gorwiki
# site_name                    Wikipedia
# closed                           False
# Name: 295, dtype: object
# [299/184] got – 𐌲𐌿𐍄𐌹𐍃𐌺
#   got: 0 myndighetslänkar 298 lang_code                          got
# lang_name                       𐌲𐌿𐍄𐌹𐍃𐌺
# project                           None
# url          https://got.wikipedia.org
# dbname                         gotwiki
# site_name                    Wikipedia
# closed                           False
# Name: 298, dtype: object
# [301/184] gpe – Ghanaian Pidgin
#   gpe: 0 myndighetslänkar 300 lang_code                          gpe
# lang_name              Ghanaian Pidgin
# project                           None
# url          https://gpe.wikipedia.org
# dbname                         gpewiki
# site_name                    Wikipedia
# closed                           False
# Name: 300, dtype: object
# [302/184] gsw – Alemannisch
# [gsw] Non-JSON response (rate limit or HTML)
#   gsw: 0 myndighetslänkar 301 lang_code                          gsw
# lang_name                  Alemannisch
# project                           None
# url          https://als.wikipedia.org
# dbname                         alswiki
# site_name                    Wikipedia
# closed                           False
# Name: 301, dtype: object
# [310/184] guw – gungbe
#   guw: 0 myndighetslänkar 309 lang_code                          guw
# lang_name                       gungbe
# project                           None
# url          https://guw.wikipedia.org
# dbname                         guwwiki
# site_name                    Wikipedia
# closed                           False
# Name: 309, dtype: object
# [314/184] gv – Gaelg
#   gv: 0 myndighetslänkar 313 lang_code                          gv
# lang_name                       Gaelg
# project                          None
# url          https://gv.wikipedia.org
# dbname                         gvwiki
# site_name                   Wikipedia
# closed                          False
# Name: 313, dtype: object
# [316/184] ha – Hausa
#   ha: 0 myndighetslänkar 315 lang_code                          ha
# lang_name                       Hausa
# project                          None
# url          https://ha.wikipedia.org
# dbname                         hawiki
# site_name                   Wikipedia
# closed                          False
# Name: 315, dtype: object
# [318/184] hak – 客家語 / Hak-kâ-ngî
#   hak: 0 myndighetslänkar 317 lang_code                          hak
# lang_name             客家語 / Hak-kâ-ngî
# project                           None
# url          https://hak.wikipedia.org
# dbname                         hakwiki
# site_name                    Wikipedia
# closed                           False
# Name: 317, dtype: object
# [319/184] haw – Hawaiʻi
#   haw: 0 myndighetslänkar 318 lang_code                          haw
# lang_name                      Hawaiʻi
# project                           None
# url          https://haw.wikipedia.org
# dbname                         hawwiki
# site_name                    Wikipedia
# closed                           False
# Name: 318, dtype: object
# [334/184] hif – Fiji Hindi
#   hif: 0 myndighetslänkar 333 lang_code                          hif
# lang_name                   Fiji Hindi
# project                           None
# url          https://hif.wikipedia.org
# dbname                         hifwiki
# site_name                    Wikipedia
# closed                           False
# Name: 333, dtype: object
# [336/184] ho – Hiri Motu
#   ho: 0 myndighetslänkar 335 lang_code                          ho
# lang_name                   Hiri Motu
# project                          None
# url          https://ho.wikipedia.org
# dbname                         howiki
# site_name                   Wikipedia
# closed                          False
# Name: 335, dtype: object
# [358/184] hz – Otsiherero
#   hz: 0 myndighetslänkar 357 lang_code                          hz
# lang_name                  Otsiherero
# project                          None
# url          https://hz.wikipedia.org
# dbname                         hzwiki
# site_name                   Wikipedia
# closed                          False
# Name: 357, dtype: object
# [359/184] ia – interlingua
#   ia: 0 myndighetslänkar 358 lang_code                          ia
# lang_name                 interlingua
# project                          None
# url          https://ia.wikipedia.org
# dbname                         iawiki
# site_name                   Wikipedia
# closed                          False
# Name: 358, dtype: object
# [362/184] iba – Jaku Iban
#   iba: 0 myndighetslänkar 361 lang_code                          iba
# lang_name                    Jaku Iban
# project                           None
# url          https://iba.wikipedia.org
# dbname                         ibawiki
# site_name                    Wikipedia
# closed                           False
# Name: 361, dtype: object
# [363/184] id – Bahasa Indonesia
#   id: 0 myndighetslänkar 362 lang_code                          id
# lang_name            Bahasa Indonesia
# project                          None
# url          https://id.wikipedia.org
# dbname                         idwiki
# site_name                   Wikipedia
# closed                          False
# Name: 362, dtype: object
# [369/184] ie – Interlingue
#   ie: 0 myndighetslänkar 368 lang_code                          ie
# lang_name                 Interlingue
# project                          None
# url          https://ie.wikipedia.org
# dbname                         iewiki
# site_name                   Wikipedia
# closed                          False
# Name: 368, dtype: object
# [372/184] ig – Igbo
#   ig: 0 myndighetslänkar 371 lang_code                          ig
# lang_name                        Igbo
# project                          None
# url          https://ig.wikipedia.org
# dbname                         igwiki
# site_name                   Wikipedia
# closed                          False
# Name: 371, dtype: object
# [376/184] ii – ꆇꉙ
#   ii: 0 myndighetslänkar 375 lang_code                          ii
# lang_name                          ꆇꉙ
# project                          None
# url          https://ii.wikipedia.org
# dbname                         iiwiki
# site_name                   Wikipedia
# closed                          False
# Name: 375, dtype: object
# [377/184] ik – Iñupiatun
#   ik: 0 myndighetslänkar 376 lang_code                          ik
# lang_name                   Iñupiatun
# project                          None
# url          https://ik.wikipedia.org
# dbname                         ikwiki
# site_name                   Wikipedia
# closed                          False
# Name: 376, dtype: object
# [379/184] ilo – Ilokano
#   ilo: 0 myndighetslänkar 378 lang_code                          ilo
# lang_name                      Ilokano
# project                           None
# url          https://ilo.wikipedia.org
# dbname                         ilowiki
# site_name                    Wikipedia
# closed                           False
# Name: 378, dtype: object
# [383/184] is – íslenska
#   is: 0 myndighetslänkar 382 lang_code                          is
# lang_name                    íslenska
# project                          None
# url          https://is.wikipedia.org
# dbname                         iswiki
# site_name                   Wikipedia
# closed                          False
# Name: 382, dtype: object
# [388/184] it – italiano
#   it: 0 myndighetslänkar 387 lang_code                          it
# lang_name                    italiano
# project                          None
# url          https://it.wikipedia.org
# dbname                         itwiki
# site_name                   Wikipedia
# closed                          False
# Name: 387, dtype: object
# [398/184] ja – 日本語
#   ja: 0 myndighetslänkar 397 lang_code                          ja
# lang_name                         日本語
# project                          None
# url          https://ja.wikipedia.org
# dbname                         jawiki
# site_name                   Wikipedia
# closed                          False
# Name: 397, dtype: object
# [407/184] jbo – la .lojban.
#   jbo: 0 myndighetslänkar 406 lang_code                          jbo
# lang_name                  la .lojban.
# project                           None
# url          https://jbo.wikipedia.org
# dbname                         jbowiki
# site_name                    Wikipedia
# closed                           False
# Name: 406, dtype: object
# [417/184] kaa – Qaraqalpaqsha
#   kaa: 0 myndighetslänkar 416 lang_code                          kaa
# lang_name                Qaraqalpaqsha
# project                           None
# url          https://kaa.wikipedia.org
# dbname                         kaawiki
# site_name                    Wikipedia
# closed                           False
# Name: 416, dtype: object
# [419/184] kab – Taqbaylit
#   kab: 0 myndighetslänkar 418 lang_code                          kab
# lang_name                    Taqbaylit
# project                           None
# url          https://kab.wikipedia.org
# dbname                         kabwiki
# site_name                    Wikipedia
# closed                           False
# Name: 418, dtype: object
# [423/184] kcg – Tyap
#   kcg: 0 myndighetslänkar 422 lang_code                          kcg
# lang_name                         Tyap
# project                           None
# url          https://kcg.wikipedia.org
# dbname                         kcgwiki
# site_name                    Wikipedia
# closed                           False
# Name: 422, dtype: object
# [425/184] kg – Kongo
#   kg: 0 myndighetslänkar 424 lang_code                          kg
# lang_name                       Kongo
# project                          None
# url          https://kg.wikipedia.org
# dbname                         kgwiki
# site_name                   Wikipedia
# closed                          False
# Name: 424, dtype: object
# [427/184] ki – Gĩkũyũ
#   ki: 0 myndighetslänkar 426 lang_code                          ki
# lang_name                      Gĩkũyũ
# project                          None
# url          https://ki.wikipedia.org
# dbname                         kiwiki
# site_name                   Wikipedia
# closed                          False
# Name: 426, dtype: object
# [428/184] kj – Kwanyama
#   kj: 0 myndighetslänkar 427 lang_code                          kj
# lang_name                    Kwanyama
# project                          None
# url          https://kj.wikipedia.org
# dbname                         kjwiki
# site_name                   Wikipedia
# closed                          False
# Name: 427, dtype: object
# [433/184] kl – kalaallisut
#   kl: 0 myndighetslänkar 432 lang_code                          kl
# lang_name                 kalaallisut
# project                          None
# url          https://kl.wikipedia.org
# dbname                         klwiki
# site_name                   Wikipedia
# closed                          False
# Name: 432, dtype: object
# [443/184] knc – Yerwa Kanuri
#   knc: 0 myndighetslänkar 442 lang_code                          knc
# lang_name                 Yerwa Kanuri
# project                           None
# url          https://knc.wikipedia.org
# dbname                         kncwiki
# site_name                    Wikipedia
# closed                           False
# Name: 442, dtype: object
# [452/184] kr – kanuri
#   kr: 0 myndighetslänkar 451 lang_code                          kr
# lang_name                      kanuri
# project                          None
# url          https://kr.wikipedia.org
# dbname                         krwiki
# site_name                   Wikipedia
# closed                          False
# Name: 451, dtype: object
# [459/184] ksh – Ripoarisch
#   ksh: 0 myndighetslänkar 458 lang_code                          ksh
# lang_name                   Ripoarisch
# project                           None
# url          https://ksh.wikipedia.org
# dbname                         kshwiki
# site_name                    Wikipedia
# closed                           False
# Name: 458, dtype: object
# [465/184] kv – коми
#   kv: 0 myndighetslänkar 464 lang_code                          kv
# lang_name                        коми
# project                          None
# url          https://kv.wikipedia.org
# dbname                         kvwiki
# site_name                   Wikipedia
# closed                          False
# Name: 464, dtype: object
# [466/184] kw – kernowek
#   kw: 0 myndighetslänkar 465 lang_code                          kw
# lang_name                    kernowek
# project                          None
# url          https://kw.wikipedia.org
# dbname                         kwwiki
# site_name                   Wikipedia
# closed                          False
# Name: 465, dtype: object
# [479/184] lb – Lëtzebuergesch
#   lb: 0 myndighetslänkar 478 lang_code                          lb
# lang_name              Lëtzebuergesch
# project                          None
# url          https://lb.wikipedia.org
# dbname                         lbwiki
# site_name                   Wikipedia
# closed                          False
# Name: 478, dtype: object
# [486/184] lg – Luganda
#   lg: 0 myndighetslänkar 485 lang_code                          lg
# lang_name                     Luganda
# project                          None
# url          https://lg.wikipedia.org
# dbname                         lgwiki
# site_name                   Wikipedia
# closed                          False
# Name: 485, dtype: object
# [487/184] li – Limburgs
#   li: 0 myndighetslänkar 486 lang_code                          li
# lang_name                    Limburgs
# project                          None
# url          https://li.wikipedia.org
# dbname                         liwiki
# site_name                   Wikipedia
# closed                          False
# Name: 486, dtype: object
# [493/184] lij – Ligure
#   lij: 0 myndighetslänkar 492 lang_code                          lij
# lang_name                       Ligure
# project                           None
# url          https://lij.wikipedia.org
# dbname                         lijwiki
# site_name                    Wikipedia
# closed                           False
# Name: 492, dtype: object
# [495/184] lld – Ladin
#   lld: 0 myndighetslänkar 494 lang_code                          lld
# lang_name                        Ladin
# project                           None
# url          https://lld.wikipedia.org
# dbname                         lldwiki
# site_name                    Wikipedia
# closed                           False
# Name: 494, dtype: object
# [496/184] lmo – lombard
#   lmo: 0 myndighetslänkar 495 lang_code                          lmo
# lang_name                      lombard
# project                           None
# url          https://lmo.wikipedia.org
# dbname                         lmowiki
# site_name                    Wikipedia
# closed                           False
# Name: 495, dtype: object
# [498/184] ln – lingála
#   ln: 0 myndighetslänkar 497 lang_code                          ln
# lang_name                     lingála
# project                          None
# url          https://ln.wikipedia.org
# dbname                         lnwiki
# site_name                   Wikipedia
# closed                          False
# Name: 497, dtype: object
# [514/184] mad – Madhurâ
#   mad: 0 myndighetslänkar 513 lang_code                          mad
# lang_name                      Madhurâ
# project                           None
# url          https://mad.wikipedia.org
# dbname                         madwiki
# site_name                    Wikipedia
# closed                           False
# Name: 513, dtype: object
# [518/184] map-bms – Basa Banyumasan
#   map-bms: 0 myndighetslänkar 517 lang_code                          map-bms
# lang_name                  Basa Banyumasan
# project                               None
# url          https://map-bms.wikipedia.org
# dbname                         map_bmswiki
# site_name                        Wikipedia
# closed                               False
# Name: 517, dtype: object
# [520/184] mg – Malagasy
#   mg: 0 myndighetslänkar 519 lang_code                          mg
# lang_name                    Malagasy
# project                          None
# url          https://mg.wikipedia.org
# dbname                         mgwiki
# site_name                   Wikipedia
# closed                          False
# Name: 519, dtype: object
# [523/184] mh – Ebon
#   mh: 0 myndighetslänkar 522 lang_code                          mh
# lang_name                        Ebon
# project                          None
# url          https://mh.wikipedia.org
# dbname                         mhwiki
# site_name                   Wikipedia
# closed                          False
# Name: 522, dtype: object
# [526/184] mi – Māori
#   mi: 0 myndighetslänkar 525 lang_code                          mi
# lang_name                       Māori
# project                          None
# url          https://mi.wikipedia.org
# dbname                         miwiki
# site_name                   Wikipedia
# closed                          False
# Name: 525, dtype: object
# [529/184] min – Minangkabau
#   min: 0 myndighetslänkar 528 lang_code                          min
# lang_name                  Minangkabau
# project                           None
# url          https://min.wikipedia.org
# dbname                         minwiki
# site_name                    Wikipedia
# closed                           False
# Name: 528, dtype: object
# [556/184] ms – Bahasa Melayu
#   ms: 0 myndighetslänkar 555 lang_code                          ms
# lang_name               Bahasa Melayu
# project                          None
# url          https://ms.wikipedia.org
# dbname                         mswiki
# site_name                   Wikipedia
# closed                          False
# Name: 555, dtype: object
# [563/184] mus – Mvskoke
#   mus: 0 myndighetslänkar 562 lang_code                          mus
# lang_name                      Mvskoke
# project                           None
# url          https://mus.wikipedia.org
# dbname                         muswiki
# site_name                    Wikipedia
# closed                           False
# Name: 562, dtype: object
# [571/184] na – Dorerin Naoero
#   na: 0 myndighetslänkar 570 lang_code                          na
# lang_name              Dorerin Naoero
# project                          None
# url          https://na.wikipedia.org
# dbname                         nawiki
# site_name                   Wikipedia
# closed                          False
# Name: 570, dtype: object
# [578/184] nan – 閩南語 / Bân-lâm-gí
#   nan: 0 myndighetslänkar 577 lang_code                                 nan
# lang_name                    閩南語 / Bân-lâm-gí
# project                                  None
# url          https://zh-min-nan.wikipedia.org
# dbname                         zh_min_nanwiki
# site_name                           Wikipedia
# closed                                  False
# Name: 577, dtype: object
# [583/184] nap – Napulitano
#   nap: 0 myndighetslänkar 582 lang_code                          nap
# lang_name                   Napulitano
# project                           None
# url          https://nap.wikipedia.org
# dbname                         napwiki
# site_name                    Wikipedia
# closed                           False
# Name: 582, dtype: object
# [585/184] nds – Plattdüütsch
#   nds: 0 myndighetslänkar 584 lang_code                          nds
# lang_name                 Plattdüütsch
# project                           None
# url          https://nds.wikipedia.org
# dbname                         ndswiki
# site_name                    Wikipedia
# closed                           False
# Name: 584, dtype: object
# [589/184] nds-nl – Nedersaksies
#   nds-nl: 0 myndighetslänkar 588 lang_code                          nds-nl
# lang_name                    Nedersaksies
# project                              None
# url          https://nds-nl.wikipedia.org
# dbname                         nds_nlwiki
# site_name                       Wikipedia
# closed                              False
# Name: 588, dtype: object
# [593/184] new – नेपाल भाषा
#   new: 0 myndighetslänkar 592 lang_code                          new
# lang_name                   नेपाल भाषा
# project                           None
# url          https://new.wikipedia.org
# dbname                         newwiki
# site_name                    Wikipedia
# closed                           False
# Name: 592, dtype: object
# [594/184] ng – Oshiwambo
#   ng: 0 myndighetslänkar 593 lang_code                          ng
# lang_name                   Oshiwambo
# project                          None
# url          https://ng.wikipedia.org
# dbname                         ngwiki
# site_name                   Wikipedia
# closed                          False
# Name: 593, dtype: object
# [595/184] nia – Li Niha
#   nia: 0 myndighetslänkar 594 lang_code                          nia
# lang_name                      Li Niha
# project                           None
# url          https://nia.wikipedia.org
# dbname                         niawiki
# site_name                    Wikipedia
# closed                           False
# Name: 594, dtype: object
# [597/184] nl – Nederlands
#   nl: 0 myndighetslänkar 596 lang_code                          nl
# lang_name                  Nederlands
# project                          None
# url          https://nl.wikipedia.org
# dbname                         nlwiki
# site_name                   Wikipedia
# closed                          False
# Name: 596, dtype: object
# [604/184] nn – norsk nynorsk
#   nn: 0 myndighetslänkar 603 lang_code                          nn
# lang_name               norsk nynorsk
# project                          None
# url          https://nn.wikipedia.org
# dbname                         nnwiki
# site_name                   Wikipedia
# closed                          False
# Name: 603, dtype: object
# [607/184] no – norsk
#   no: 0 myndighetslänkar 606 lang_code                          no
# lang_name                       norsk
# project                          None
# url          https://no.wikipedia.org
# dbname                         nowiki
# site_name                   Wikipedia
# closed                          False
# Name: 606, dtype: object
# [613/184] nov – Novial
#   nov: 0 myndighetslänkar 612 lang_code                          nov
# lang_name                       Novial
# project                           None
# url          https://nov.wikipedia.org
# dbname                         novwiki
# site_name                    Wikipedia
# closed                           False
# Name: 612, dtype: object
# [616/184] nrm – Nouormand
#   nrm: 0 myndighetslänkar 615 lang_code                          nrm
# lang_name                    Nouormand
# project                           None
# url          https://nrm.wikipedia.org
# dbname                         nrmwiki
# site_name                    Wikipedia
# closed                           False
# Name: 615, dtype: object
# [617/184] nso – Sesotho sa Leboa
#   nso: 0 myndighetslänkar 616 lang_code                          nso
# lang_name             Sesotho sa Leboa
# project                           None
# url          https://nso.wikipedia.org
# dbname                         nsowiki
# site_name                    Wikipedia
# closed                           False
# Name: 616, dtype: object
# [618/184] nup – Nupe
#   nup: 0 myndighetslänkar 617 lang_code                          nup
# lang_name                         Nupe
# project                           None
# url          https://nup.wikipedia.org
# dbname                         nupwiki
# site_name                    Wikipedia
# closed                           False
# Name: 617, dtype: object
# [619/184] nv – Diné bizaad
#   nv: 0 myndighetslänkar 618 lang_code                          nv
# lang_name                 Diné bizaad
# project                          None
# url          https://nv.wikipedia.org
# dbname                         nvwiki
# site_name                   Wikipedia
# closed                          False
# Name: 618, dtype: object
# [620/184] ny – Chi-Chewa
#   ny: 0 myndighetslänkar 619 lang_code                          ny
# lang_name                   Chi-Chewa
# project                          None
# url          https://ny.wikipedia.org
# dbname                         nywiki
# site_name                   Wikipedia
# closed                          False
# Name: 619, dtype: object
# [625/184] om – Oromoo
#   om: 0 myndighetslänkar 624 lang_code                          om
# lang_name                      Oromoo
# project                          None
# url          https://om.wikipedia.org
# dbname                         omwiki
# site_name                   Wikipedia
# closed                          False
# Name: 624, dtype: object
# [635/184] pag – Pangasinan
#   pag: 0 myndighetslänkar 634 lang_code                          pag
# lang_name                   Pangasinan
# project                           None
# url          https://pag.wikipedia.org
# dbname                         pagwiki
# site_name                    Wikipedia
# closed                           False
# Name: 634, dtype: object
# [636/184] pam – Kapampangan
#   pam: 0 myndighetslänkar 635 lang_code                          pam
# lang_name                  Kapampangan
# project                           None
# url          https://pam.wikipedia.org
# dbname                         pamwiki
# site_name                    Wikipedia
# closed                           False
# Name: 635, dtype: object
# [637/184] pap – Papiamentu
#   pap: 0 myndighetslänkar 636 lang_code                          pap
# lang_name                   Papiamentu
# project                           None
# url          https://pap.wikipedia.org
# dbname                         papwiki
# site_name                    Wikipedia
# closed                           False
# Name: 636, dtype: object
# [638/184] pcd – Picard
#   pcd: 0 myndighetslänkar 637 lang_code                          pcd
# lang_name                       Picard
# project                           None
# url          https://pcd.wikipedia.org
# dbname                         pcdwiki
# site_name                    Wikipedia
# closed                           False
# Name: 637, dtype: object
# [639/184] pcm – Naijá
#   pcm: 0 myndighetslänkar 638 lang_code                          pcm
# lang_name                        Naijá
# project                           None
# url          https://pcm.wikipedia.org
# dbname                         pcmwiki
# site_name                    Wikipedia
# closed                           False
# Name: 638, dtype: object
# [641/184] pdc – Deitsch
#   pdc: 0 myndighetslänkar 640 lang_code                          pdc
# lang_name                      Deitsch
# project                           None
# url          https://pdc.wikipedia.org
# dbname                         pdcwiki
# site_name                    Wikipedia
# closed                           False
# Name: 640, dtype: object
# [642/184] pfl – Pälzisch
#   pfl: 0 myndighetslänkar 641 lang_code                          pfl
# lang_name                     Pälzisch
# project                           None
# url          https://pfl.wikipedia.org
# dbname                         pflwiki
# site_name                    Wikipedia
# closed                           False
# Name: 641, dtype: object
# [643/184] pi – पालि
#   pi: 0 myndighetslänkar 642 lang_code                          pi
# lang_name                        पालि
# project                          None
# url          https://pi.wikipedia.org
# dbname                         piwiki
# site_name                   Wikipedia
# closed                          False
# Name: 642, dtype: object
# [645/184] pih – Norfuk / Pitkern
#   pih: 0 myndighetslänkar 644 lang_code                          pih
# lang_name             Norfuk / Pitkern
# project                           None
# url          https://pih.wikipedia.org
# dbname                         pihwiki
# site_name                    Wikipedia
# closed                           False
# Name: 644, dtype: object
# [646/184] pl – polski
#   pl: 0 myndighetslänkar 645 lang_code                          pl
# lang_name                      polski
# project                          None
# url          https://pl.wikipedia.org
# dbname                         plwiki
# site_name                   Wikipedia
# closed                          False
# Name: 645, dtype: object
# [653/184] pms – Piemontèis
#   pms: 0 myndighetslänkar 652 lang_code                          pms
# lang_name                   Piemontèis
# project                           None
# url          https://pms.wikipedia.org
# dbname                         pmswiki
# site_name                    Wikipedia
# closed                           False
# Name: 652, dtype: object
# [670/184] pwn – pinayuanan
#   pwn: 0 myndighetslänkar 669 lang_code                          pwn
# lang_name                   pinayuanan
# project                           None
# url          https://pwn.wikipedia.org
# dbname                         pwnwiki
# site_name                    Wikipedia
# closed                           False
# Name: 669, dtype: object
# [671/184] qu – Runa Simi
#   qu: 0 myndighetslänkar 670 lang_code                          qu
# lang_name                   Runa Simi
# project                          None
# url          https://qu.wikipedia.org
# dbname                         quwiki
# site_name                   Wikipedia
# closed                          False
# Name: 670, dtype: object
# [676/184] rm – rumantsch
#   rm: 0 myndighetslänkar 675 lang_code                          rm
# lang_name                   rumantsch
# project                          None
# url          https://rm.wikipedia.org
# dbname                         rmwiki
# site_name                   Wikipedia
# closed                          False
# Name: 675, dtype: object
# [680/184] rn – ikirundi
#   rn: 0 myndighetslänkar 679 lang_code                          rn
# lang_name                    ikirundi
# project                          None
# url          https://rn.wikipedia.org
# dbname                         rnwiki
# site_name                   Wikipedia
# closed                          False
# Name: 679, dtype: object
# [682/184] ro – română
#   ro: 0 myndighetslänkar 681 lang_code                          ro
# lang_name                      română
# project                          None
# url          https://ro.wikipedia.org
# dbname                         rowiki
# site_name                   Wikipedia
# closed                          False
# Name: 681, dtype: object
# [689/184] roa-tara – tarandíne
#   roa-tara: 0 myndighetslänkar 688 lang_code                          roa-tara
# lang_name                         tarandíne
# project                                None
# url          https://roa-tara.wikipedia.org
# dbname                         roa_tarawiki
# site_name                         Wikipedia
# closed                                False
# Name: 688, dtype: object
# [700/184] rup – armãneashti
# [rup] Non-JSON response (rate limit or HTML)
#   rup: 0 myndighetslänkar 699 lang_code                              rup
# lang_name                      armãneashti
# project                               None
# url          https://roa-rup.wikipedia.org
# dbname                         roa_rupwiki
# site_name                        Wikipedia
# closed                               False
# Name: 699, dtype: object
# [702/184] rw – Ikinyarwanda
#   rw: 0 myndighetslänkar 701 lang_code                          rw
# lang_name                Ikinyarwanda
# project                          None
# url          https://rw.wikipedia.org
# ...
# lang_name                    sicilianu
# project                           None
# url          https://scn.wikipedia.org
# dbname                         scnwiki
# site_name                    Wikipedia
# closed                           False
# Name: 715, dtype: object
# [718/184] sco – Scots
#   sco: 0 myndighetslänkar 717 lang_code                          sco
# lang_name                        Scots
# project                           None
# url          https://sco.wikipedia.org
# dbname                         scowiki
# site_name                    Wikipedia
# closed                           False
# Name: 717, dtype: object
# [722/184] se – davvisámegiella
#   se: 0 myndighetslänkar 721 lang_code                          se
# lang_name             davvisámegiella
# project                          None
# url          https://se.wikipedia.org
# dbname                         sewiki
# site_name                   Wikipedia
# closed                          False
# Name: 721, dtype: object
# [724/184] sg – Sängö
#   sg: 0 myndighetslänkar 723 lang_code                          sg
# lang_name                       Sängö
# project                          None
# url          https://sg.wikipedia.org
# dbname                         sgwiki
# site_name                   Wikipedia
# closed                          False
# Name: 723, dtype: object
# [726/184] sgs – žemaitėška
#   sgs: 0 myndighetslänkar 725 lang_code                              sgs
# lang_name                       žemaitėška
# project                               None
# url          https://bat-smg.wikipedia.org
# dbname                         bat_smgwiki
# site_name                        Wikipedia
# closed                               False
# Name: 725, dtype: object
# [729/184] shi – Taclḥit
#   shi: 0 myndighetslänkar 728 lang_code                          shi
# lang_name                      Taclḥit
# project                           None
# url          https://shi.wikipedia.org
# dbname                         shiwiki
# site_name                    Wikipedia
# closed                           False
# Name: 728, dtype: object
# [739/184] simple – Simple English
#   simple: 0 myndighetslänkar 738 lang_code                          simple
# lang_name                  Simple English
# project                              None
# url          https://simple.wikipedia.org
# dbname                         simplewiki
# site_name                       Wikipedia
# closed                              False
# Name: 738, dtype: object
# [756/184] sm – Gagana Samoa
#   sm: 0 myndighetslänkar 755 lang_code                          sm
# lang_name                Gagana Samoa
# project                          None
# url          https://sm.wikipedia.org
# dbname                         smwiki
# site_name                   Wikipedia
# closed                          False
# Name: 755, dtype: object
# [758/184] smn – anarâškielâ
#   smn: 0 myndighetslänkar 757 lang_code                          smn
# lang_name                  anarâškielâ
# project                           None
# url          https://smn.wikipedia.org
# dbname                         smnwiki
# site_name                    Wikipedia
# closed                           False
# Name: 757, dtype: object
# [759/184] sn – chiShona
#   sn: 0 myndighetslänkar 758 lang_code                          sn
# lang_name                    chiShona
# project                          None
# url          https://sn.wikipedia.org
# dbname                         snwiki
# site_name                   Wikipedia
# closed                          False
# Name: 758, dtype: object
# [761/184] so – Soomaaliga
#   so: 0 myndighetslänkar 760 lang_code                          so
# lang_name                  Soomaaliga
# project                          None
# url          https://so.wikipedia.org
# dbname                         sowiki
# site_name                   Wikipedia
# closed                          False
# Name: 760, dtype: object
# [763/184] sq – shqip
#   sq: 0 myndighetslänkar 762 lang_code                          sq
# lang_name                       shqip
# project                          None
# url          https://sq.wikipedia.org
# dbname                         sqwiki
# site_name                   Wikipedia
# closed                          False
# Name: 762, dtype: object
# [774/184] srn – Sranantongo
#   srn: 0 myndighetslänkar 773 lang_code                          srn
# lang_name                  Sranantongo
# project                           None
# url          https://srn.wikipedia.org
# dbname                         srnwiki
# site_name                    Wikipedia
# closed                           False
# Name: 773, dtype: object
# [775/184] ss – SiSwati
#   ss: 0 myndighetslänkar 774 lang_code                          ss
# lang_name                     SiSwati
# project                          None
# url          https://ss.wikipedia.org
# dbname                         sswiki
# site_name                   Wikipedia
# closed                          False
# Name: 774, dtype: object
# [777/184] st – Sesotho
#   st: 0 myndighetslänkar 776 lang_code                          st
# lang_name                     Sesotho
# project                          None
# url          https://st.wikipedia.org
# dbname                         stwiki
# site_name                   Wikipedia
# closed                          False
# Name: 776, dtype: object
# [779/184] stq – Seeltersk
#   stq: 0 myndighetslänkar 778 lang_code                          stq
# lang_name                    Seeltersk
# project                           None
# url          https://stq.wikipedia.org
# dbname                         stqwiki
# site_name                    Wikipedia
# closed                           False
# Name: 778, dtype: object
# [780/184] su – Sunda
#   su: 0 myndighetslänkar 779 lang_code                          su
# lang_name                       Sunda
# project                          None
# url          https://su.wikipedia.org
# dbname                         suwiki
# site_name                   Wikipedia
# closed                          False
# Name: 779, dtype: object
# [785/184] sv – svenska
#   sv: 0 myndighetslänkar 784 lang_code                          sv
# lang_name                     svenska
# project                          None
# url          https://sv.wikipedia.org
# dbname                         svwiki
# site_name                   Wikipedia
# closed                          False
# Name: 784, dtype: object
# [793/184] sw – Kiswahili
#   sw: 0 myndighetslänkar 792 lang_code                          sw
# lang_name                   Kiswahili
# project                          None
# url          https://sw.wikipedia.org
# dbname                         swwiki
# site_name                   Wikipedia
# closed                          False
# Name: 792, dtype: object
# [797/184] szl – ślůnski
#   szl: 0 myndighetslänkar 796 lang_code                          szl
# lang_name                      ślůnski
# project                           None
# url          https://szl.wikipedia.org
# dbname                         szlwiki
# site_name                    Wikipedia
# closed                           False
# Name: 796, dtype: object
# [815/184] tet – tetun
#   tet: 0 myndighetslänkar 814 lang_code                          tet
# lang_name                        tetun
# project                           None
# url          https://tet.wikipedia.org
# dbname                         tetwiki
# site_name                    Wikipedia
# closed                           False
# Name: 814, dtype: object
# [832/184] tl – Tagalog
#   tl: 0 myndighetslänkar 831 lang_code                          tl
# lang_name                     Tagalog
# project                          None
# url          https://tl.wikipedia.org
# dbname                         tlwiki
# site_name                   Wikipedia
# closed                          False
# Name: 831, dtype: object
# [838/184] tn – Setswana
#   tn: 0 myndighetslänkar 837 lang_code                          tn
# lang_name                    Setswana
# project                          None
# url          https://tn.wikipedia.org
# dbname                         tnwiki
# site_name                   Wikipedia
# closed                          False
# Name: 837, dtype: object
# [840/184] to – lea faka-Tonga
#   to: 0 myndighetslänkar 839 lang_code                          to
# lang_name              lea faka-Tonga
# project                          None
# url          https://to.wikipedia.org
# dbname                         towiki
# site_name                   Wikipedia
# closed                          False
# Name: 839, dtype: object
# [843/184] tpi – Tok Pisin
#   tpi: 0 myndighetslänkar 842 lang_code                          tpi
# lang_name                    Tok Pisin
# project                           None
# url          https://tpi.wikipedia.org
# dbname                         tpiwiki
# site_name                    Wikipedia
# closed                           False
# Name: 842, dtype: object
# [853/184] ts – Xitsonga
#   ts: 0 myndighetslänkar 852 lang_code                          ts
# lang_name                    Xitsonga
# project                          None
# url          https://ts.wikipedia.org
# dbname                         tswiki
# site_name                   Wikipedia
# closed                          False
# Name: 852, dtype: object
# [855/184] tt – татарча / tatarça
#   tt: 0 myndighetslänkar 854 lang_code                          tt
# lang_name           татарча / tatarça
# project                          None
# url          https://tt.wikipedia.org
# dbname                         ttwiki
# site_name                   Wikipedia
# closed                          False
# Name: 854, dtype: object
# [859/184] tum – chiTumbuka
#   tum: 0 myndighetslänkar 858 lang_code                          tum
# lang_name                   chiTumbuka
# project                           None
# url          https://tum.wikipedia.org
# dbname                         tumwiki
# site_name                    Wikipedia
# closed                           False
# Name: 858, dtype: object
# [860/184] tw – Twi
#   tw: 0 myndighetslänkar 859 lang_code                          tw
# lang_name                         Twi
# project                          None
# url          https://tw.wikipedia.org
# dbname                         twwiki
# site_name                   Wikipedia
# closed                          False
# Name: 859, dtype: object
# [862/184] ty – reo tahiti
#   ty: 0 myndighetslänkar 861 lang_code                          ty
# lang_name                  reo tahiti
# project                          None
# url          https://ty.wikipedia.org
# dbname                         tywiki
# site_name                   Wikipedia
# closed                          False
# Name: 861, dtype: object
# [865/184] ug – ئۇيغۇرچە / Uyghurche
#   ug: 0 myndighetslänkar 864 lang_code                          ug
# lang_name        ئۇيغۇرچە / Uyghurche
# project                          None
# url          https://ug.wikipedia.org
# dbname                         ugwiki
# site_name                   Wikipedia
# closed                          False
# Name: 864, dtype: object
# [884/184] ve – Tshivenda
#   ve: 0 myndighetslänkar 883 lang_code                          ve
# lang_name                   Tshivenda
# project                          None
# url          https://ve.wikipedia.org
# dbname                         vewiki
# site_name                   Wikipedia
# closed                          False
# Name: 883, dtype: object
# [885/184] vec – vèneto
#   vec: 0 myndighetslänkar 884 lang_code                          vec
# lang_name                       vèneto
# project                           None
# url          https://vec.wikipedia.org
# dbname                         vecwiki
# site_name                    Wikipedia
# closed                           False
# Name: 884, dtype: object
# [889/184] vi – Tiếng Việt
#   vi: 0 myndighetslänkar 888 lang_code                          vi
# lang_name                  Tiếng Việt
# project                          None
# url          https://vi.wikipedia.org
# dbname                         viwiki
# site_name                   Wikipedia
# closed                          False
# Name: 888, dtype: object
# [895/184] vls – West-Vlams
#   vls: 0 myndighetslänkar 894 lang_code                          vls
# lang_name                   West-Vlams
# project                           None
# url          https://vls.wikipedia.org
# dbname                         vlswiki
# site_name                    Wikipedia
# closed                           False
# Name: 894, dtype: object
# [900/184] vro – võro
#   vro: 0 myndighetslänkar 899 lang_code                              vro
# lang_name                             võro
# project                               None
# url          https://fiu-vro.wikipedia.org
# dbname                         fiu_vrowiki
# site_name                        Wikipedia
# closed                               False
# Name: 899, dtype: object
# [901/184] wa – walon
#   wa: 0 myndighetslänkar 900 lang_code                          wa
# lang_name                       walon
# project                          None
# url          https://wa.wikipedia.org
# dbname                         wawiki
# site_name                   Wikipedia
# closed                          False
# Name: 900, dtype: object
# [905/184] war – Winaray
#   war: 0 myndighetslänkar 904 lang_code                          war
# lang_name                      Winaray
# project                           None
# url          https://war.wikipedia.org
# dbname                         warwiki
# site_name                    Wikipedia
# closed                           False
# Name: 904, dtype: object
# [906/184] wo – Wolof
#   wo: 0 myndighetslänkar 905 lang_code                          wo
# lang_name                       Wolof
# project                          None
# url          https://wo.wikipedia.org
# dbname                         wowiki
# site_name                   Wikipedia
# closed                          False
# Name: 905, dtype: object
# [910/184] xal – хальмг
#   xal: 0 myndighetslänkar 909 lang_code                          xal
# lang_name                       хальмг
# project                           None
# url          https://xal.wikipedia.org
# dbname                         xalwiki
# site_name                    Wikipedia
# closed                           False
# Name: 909, dtype: object
# [911/184] xh – isiXhosa
#   xh: 0 myndighetslänkar 910 lang_code                          xh
# lang_name                    isiXhosa
# project                          None
# url          https://xh.wikipedia.org
# dbname                         xhwiki
# site_name                   Wikipedia
# closed                          False
# Name: 910, dtype: object
# [918/184] yo – Yorùbá
#   yo: 0 myndighetslänkar 917 lang_code                          yo
# lang_name                      Yorùbá
# project                          None
# url          https://yo.wikipedia.org
# dbname                         yowiki
# site_name                   Wikipedia
# closed                          False
# Name: 917, dtype: object
# [923/184] za – Vahcuengh
#   za: 0 myndighetslänkar 922 lang_code                          za
# lang_name                   Vahcuengh
# project                          None
# url          https://za.wikipedia.org
# dbname                         zawiki
# site_name                   Wikipedia
# closed                          False
# Name: 922, dtype: object
# [927/184] zea – Zeêuws
#   zea: 0 myndighetslänkar 926 lang_code                          zea
# lang_name                       Zeêuws
# project                           None
# url          https://zea.wikipedia.org
# dbname                         zeawiki
# site_name                    Wikipedia
# closed                           False
# Name: 926, dtype: object
# [930/184] zh – 中文
#   zh: 0 myndighetslänkar 929 lang_code                          zh
# lang_name                          中文
# project                          None
# url          https://zh.wikipedia.org
# dbname                         zhwiki
# site_name                   Wikipedia
# closed                          False
# Name: 929, dtype: object
# [938/184] zu – isiZulu
#   zu: 0 myndighetslänkar 937 lang_code                          zu
# lang_name                     isiZulu
# project                          None
# url          https://zu.wikipedia.org
# dbname                         zuwiki
# site_name                   Wikipedia
# closed                          False
# Name: 937, dtype: object
